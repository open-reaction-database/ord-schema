# %% [markdown]
# # Example application of ORD datasets for downstream machine learning modeling

# %% [markdown]
# Reproducing neural network predictor of reaction yields from Granda et al. Nature 2018, 559, 377, DOI: 10.1038/s41586-018-0307-8.<br>
# Data from Perera et al. Science 2018, 359, 429, DOI: 10.1126/science.aap9112.<br>
# ORD dataset location: https://github.com/open-reaction-database/ord-data/tree/main/data/68<br>
# ORD dataset ID: ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203

# %%
# Import packages
import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2

import math
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import wget

from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from glob import glob

# %%
# Download data from ord-data pull request and load to Dataset message
url = 'https://github.com/open-reaction-database/ord-data/blob/main/data/68/ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203.pb.gz?raw=true'

# Check if .pb.gz has already been downloaded
suffixes = ('.pb.gz', '.pb', '.pbtxt.gz', '.pbtxt')
pbs = [pb for pb in glob(os.getcwd()+'/*') if pb.endswith(suffixes)]
if len(pbs) > 0:
    pb = pbs[0]
else:
    pb = wget.download(url)

# Load dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# %%
# Ensure dataset validates
valid_output = validations.validate_message(data)

# Check errors
valid_output.errors
# Out:
# []

# %%
# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, 
                                           drop_constant_columns=True)

# View dataframe
df
# Out:
#      inputs["Solvent_1"].components[0].identifiers[0].value  \
# 0                                                  CC#N
# 1                                                  CC#N
# 2                                                  CC#N
# 3                                                  CC#N
# 4                                                  CC#N
# ...                                                 ...
# 5755                                           CN(C)C=O
# 5756                                           CN(C)C=O
# 5757                                           CN(C)C=O
# 5758                                           CN(C)C=O
# 5759                                           CN(C)C=O
#
#      inputs["Boronate in Solvent"].components[0].identifiers[0].value  \
# 0                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 1                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 2                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 3                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 4                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# ...                                                 ...
# 5755               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5756               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5757               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5758               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5759               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
#
#      inputs["Boronate in Solvent"].components[1].identifiers[0].value  \
# 0                                              CN(C)C=O
# 1                                              CN(C)C=O
# 2                                              CN(C)C=O
# 3                                              CN(C)C=O
# 4                                              CN(C)C=O
# ...                                                 ...
# 5755                                           O=CN(C)C
# 5756                                           O=CN(C)C
# 5757                                           O=CN(C)C
# 5758                                           O=CN(C)C
# 5759                                           O=CN(C)C
#
#      inputs["Ligand in Solvent"].components[0].identifiers[0].value  \
# 0                           CC(C)(C)P(C(C)(C)C)C(C)(C)C
# 1                         c1ccc(cc1)P(c2ccccc2)c3ccccc3
# 2     CC(C)(C)P(C1=CC=C(C=C1)N(C)C)C(C)(C)C.CC(C)(C)...
# 3                         C1CCC(CC1)P(C2CCCCC2)C3CCCCC3
# 4                        Cc1ccccc1P(c2ccccc2C)c3ccccc3C
# ...                                                 ...
# 5755  CC(C)(C)P([C]1[CH][CH][CH][CH]1)C(C)(C)C.CC(C)...
# 5756  CC(C)c1cc(c(c(c1)C(C)C)c2ccccc2P(C3CCCCC3)C4CC...
# 5757  c1ccc(cc1)P([c-]2cccc2)c3ccccc3.c1ccc(cc1)P([c...
# 5758  CC1(c2cccc(c2Oc3c1cccc3P(c4ccccc4)c5ccccc5)P(c...
# 5759                                          Cc1ccccc1
#
#       inputs["Ligand in Solvent"].components[0].amount.moles.value  \
# 0                                                  0.05
# 1                                                  0.05
# 2                                                  0.05
# 3                                                  0.05
# 4                                                  0.05
# ...                                                 ...
# 5755                                               0.05
# 5756                                               0.05
# 5757                                               0.05
# 5758                                               0.05
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[0].amount.moles.units  \
# 0                                             MICROMOLE
# 1                                             MICROMOLE
# 2                                             MICROMOLE
# 3                                             MICROMOLE
# 4                                             MICROMOLE
# ...                                                 ...
# 5755                                          MICROMOLE
# 5756                                          MICROMOLE
# 5757                                          MICROMOLE
# 5758                                          MICROMOLE
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[0].reaction_role  \
# 0                                              CATALYST
# 1                                              CATALYST
# 2                                              CATALYST
# 3                                              CATALYST
# 4                                              CATALYST
# ...                                                 ...
# 5755                                           CATALYST
# 5756                                           CATALYST
# 5757                                           CATALYST
# 5758                                           CATALYST
# 5759                                            SOLVENT
#
#      inputs["Ligand in Solvent"].components[1].identifiers[0].type  \
# 0                                                SMILES
# 1                                                SMILES
# 2                                                SMILES
# 3                                                SMILES
# 4                                                SMILES
# ...                                                 ...
# 5755                                             SMILES
# 5756                                             SMILES
# 5757                                             SMILES
# 5758                                             SMILES
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[1].identifiers[0].value  \
# 0                                             Cc1ccccc1
# 1                                             Cc1ccccc1
# 2                                             Cc1ccccc1
# 3                                             Cc1ccccc1
# 4                                             Cc1ccccc1
# ...                                                 ...
# 5755                                          Cc1ccccc1
# 5756                                          Cc1ccccc1
# 5757                                          Cc1ccccc1
# 5758                                          Cc1ccccc1
# 5759                                                NaN
#
#       inputs["Ligand in Solvent"].components[1].amount.volume.value  ...  \
# 0                                                   1.0              ...
# 1                                                   1.0              ...
# 2                                                   1.0              ...
# 3                                                   1.0              ...
# 4                                                   1.0              ...
# ...                                                 ...              ...
# 5755                                                1.0              ...
# 5756                                                1.0              ...
# 5757                                                1.0              ...
# 5758                                                1.0              ...
# 5759                                                NaN              ...
#
#      inputs["Base in Solvent"].components[1].reaction_role  \
# 0                                               SOLVENT
# 1                                               SOLVENT
# 2                                               SOLVENT
# 3                                               SOLVENT
# 4                                               SOLVENT
# ...                                                 ...
# 5755                                            SOLVENT
# 5756                                            SOLVENT
# 5757                                            SOLVENT
# 5758                                            SOLVENT
# 5759                                            SOLVENT
#
#      inputs["Aryl Halide"].components[0].identifiers[0].value  \
# 0                                 ClC1=CC=C2N=CC=CC2=C1
# 1                                 ClC1=CC=C2N=CC=CC2=C1
# 2                                 ClC1=CC=C2N=CC=CC2=C1
# 3                                 ClC1=CC=C2N=CC=CC2=C1
# 4                                 ClC1=CC=C2N=CC=CC2=C1
# ...                                                 ...
# 5755                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5756                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5757                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5758                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5759                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
#
#      outcomes[0].products[0].measurements[0].percentage.value  \
# 0                                              4.760000
# 1                                              4.120000
# 2                                              2.580000
# 3                                              4.440000
# 4                                              1.950000
# ...                                                 ...
# 5755                                          47.209999
# 5756                                           0.000000
# 5757                                          31.440001
# 5758                                           0.000000
# 5759                                          54.200001
#
#      provenance.record_modified[1].time.value  \
# 0                  2021-03-04 13:56:15.292871
# 1                  2021-03-04 13:56:15.298402
# 2                  2021-03-04 13:56:15.303978
# 3                  2021-03-04 13:56:15.309572
# 4                  2021-03-04 13:56:15.315080
# ...                                       ...
# 5755               2021-03-04 13:56:49.737623
# 5756               2021-03-04 13:56:49.743574
# 5757               2021-03-04 13:56:49.749090
# 5758               2021-03-04 13:56:49.754742
# 5759               2021-03-04 13:56:49.759986
#
#                                reaction_id  \
# 0     ord-61b2819b15824f1fa131ed1b2ea1dae4
# 1     ord-f18c2b2d0bd04d2c96a3a16dfd8b8bef
# 2     ord-1061f43c594b4de68345c010b2aef94b
# 3     ord-e61614af430845179c392e478d958383
# 4     ord-3fede496f4284a5ea6656f083e2399ae
# ...                                    ...
# 5755  ord-b498385d41664713aaef79a290409614
# 5756  ord-2ef787f9faac4077bff2d903866aa209
# 5757  ord-654740d21331471cafdfda41ff19d57a
# 5758  ord-8e53efc193e548ba888b47da3e91ced5
# 5759  ord-0c525e5dde954d91b6dc2fe0bb849655
#
#      inputs["Ligand in Solvent"].components[0].amount.volume.value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                                1.0
#
#      inputs["Ligand in Solvent"].components[0].amount.volume.units  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                         MICROLITER
#
#      inputs["Ligand in Solvent"].components[0].amount.volume_includes_solutes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                               True
#
#      inputs["Base in Solvent"].components[0].amount.volume.value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                                NaN
#
#       inputs["Base in Solvent"].components[0].amount.volume.units
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                                NaN
#
# [5760 rows x 31 columns]

# %%
# View all columns with variation in the dataset
list(df.columns)
# Out:
# ['inputs["Solvent_1"].components[0].identifiers[0].value',
#  'inputs["Boronate in Solvent"].components[0].identifiers[0].value',
#  'inputs["Boronate in Solvent"].components[1].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[0].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[0].amount.moles.value',
#  'inputs["Ligand in Solvent"].components[0].amount.moles.units',
#  'inputs["Ligand in Solvent"].components[0].reaction_role',
#  'inputs["Ligand in Solvent"].components[1].identifiers[0].type',
#  'inputs["Ligand in Solvent"].components[1].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[1].amount.volume.value',
#  'inputs["Ligand in Solvent"].components[1].amount.volume.units',
#  'inputs["Ligand in Solvent"].components[1].amount.volume_includes_solutes',
#  'inputs["Ligand in Solvent"].components[1].reaction_role',
#  'inputs["Base in Solvent"].components[0].identifiers[0].value',
#  'inputs["Base in Solvent"].components[0].amount.moles.value',
#  'inputs["Base in Solvent"].components[0].amount.moles.units',
#  'inputs["Base in Solvent"].components[0].reaction_role',
#  'inputs["Base in Solvent"].components[1].identifiers[0].type',
#  'inputs["Base in Solvent"].components[1].identifiers[0].value',
#  'inputs["Base in Solvent"].components[1].amount.volume.value',
#  'inputs["Base in Solvent"].components[1].amount.volume.units',
#  'inputs["Base in Solvent"].components[1].reaction_role',
#  'inputs["Aryl Halide"].components[0].identifiers[0].value',
#  'outcomes[0].products[0].measurements[0].percentage.value',
#  'provenance.record_modified[1].time.value',
#  'reaction_id',
#  'inputs["Ligand in Solvent"].components[0].amount.volume.value',
#  'inputs["Ligand in Solvent"].components[0].amount.volume.units',
#  'inputs["Ligand in Solvent"].components[0].amount.volume_includes_solutes',
#  'inputs["Base in Solvent"].components[0].amount.volume.value',
#  'inputs["Base in Solvent"].components[0].amount.volume.units']

# %%
# Create new dataframe containing only columns to be used in modeling
model_cols = ['inputs["Aryl Halide"].components[0].identifiers[0].value',
              'inputs["Boronate in Solvent"].components[0].identifiers[0].value',
              'inputs["Ligand in Solvent"].components[0].identifiers[0].value',
              'inputs["Base in Solvent"].components[0].identifiers[0].value',
              'inputs["Solvent_1"].components[0].identifiers[0].value',
              'outcomes[0].products[0].measurements[0].percentage.value']
df = df[model_cols]
df
# Out:
#      inputs["Aryl Halide"].components[0].identifiers[0].value  \
# 0                                 ClC1=CC=C2N=CC=CC2=C1
# 1                                 ClC1=CC=C2N=CC=CC2=C1
# 2                                 ClC1=CC=C2N=CC=CC2=C1
# 3                                 ClC1=CC=C2N=CC=CC2=C1
# 4                                 ClC1=CC=C2N=CC=CC2=C1
# ...                                                 ...
# 5755                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5756                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5757                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5758                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5759                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
#
#      inputs["Boronate in Solvent"].components[0].identifiers[0].value  \
# 0                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 1                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 2                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 3                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 4                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# ...                                                 ...
# 5755               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5756               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5757               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5758               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5759               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
#
#      inputs["Ligand in Solvent"].components[0].identifiers[0].value  \
# 0                           CC(C)(C)P(C(C)(C)C)C(C)(C)C
# 1                         c1ccc(cc1)P(c2ccccc2)c3ccccc3
# 2     CC(C)(C)P(C1=CC=C(C=C1)N(C)C)C(C)(C)C.CC(C)(C)...
# 3                         C1CCC(CC1)P(C2CCCCC2)C3CCCCC3
# 4                        Cc1ccccc1P(c2ccccc2C)c3ccccc3C
# ...                                                 ...
# 5755  CC(C)(C)P([C]1[CH][CH][CH][CH]1)C(C)(C)C.CC(C)...
# 5756  CC(C)c1cc(c(c(c1)C(C)C)c2ccccc2P(C3CCCCC3)C4CC...
# 5757  c1ccc(cc1)P([c-]2cccc2)c3ccccc3.c1ccc(cc1)P([c...
# 5758  CC1(c2cccc(c2Oc3c1cccc3P(c4ccccc4)c5ccccc5)P(c...
# 5759                                          Cc1ccccc1
#
#      inputs["Base in Solvent"].components[0].identifiers[0].value  \
# 0                                           [OH-].[Na+]
# 1                                           [OH-].[Na+]
# 2                                           [OH-].[Na+]
# 3                                           [OH-].[Na+]
# 4                                           [OH-].[Na+]
# ...                                                 ...
# 5755                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5756                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5757                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5758                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5759                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
#
#      inputs["Solvent_1"].components[0].identifiers[0].value  \
# 0                                                  CC#N
# 1                                                  CC#N
# 2                                                  CC#N
# 3                                                  CC#N
# 4                                                  CC#N
# ...                                                 ...
# 5755                                           CN(C)C=O
# 5756                                           CN(C)C=O
# 5757                                           CN(C)C=O
# 5758                                           CN(C)C=O
# 5759                                           CN(C)C=O
#
#       outcomes[0].products[0].measurements[0].percentage.value
# 0                                              4.760000
# 1                                              4.120000
# 2                                              2.580000
# 3                                              4.440000
# 4                                              1.950000
# ...                                                 ...
# 5755                                          47.209999
# 5756                                           0.000000
# 5757                                          31.440001
# 5758                                           0.000000
# 5759                                          54.200001
#
# [5760 rows x 6 columns]

# %%
# Check for NaN values
print(f'number of NaN values: {df.isnull().sum().sum()}')

# Show column counts
df.info()
# Out:
# number of NaN values: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 6 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   inputs["Aryl Halide"].components[0].identifiers[0].value          5760 non-null   object
#  1   inputs["Boronate in Solvent"].components[0].identifiers[0].value  5760 non-null   object
#  2   inputs["Ligand in Solvent"].components[0].identifiers[0].value    5760 non-null   object
#  3   inputs["Base in Solvent"].components[0].identifiers[0].value      5760 non-null   object
#  4   inputs["Solvent_1"].components[0].identifiers[0].value            5760 non-null   object
#  5   outcomes[0].products[0].measurements[0].percentage.value          5760 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 270.1+ KB

# %%
# Show dataset statistics for numerical fields
df.describe()
# Out:
#        outcomes[0].products[0].measurements[0].percentage.value
# count                                        5760.000000
# mean                                           40.109446
# std                                            28.081087
# min                                             0.000000
# 25%                                            16.197501
# 50%                                            33.580000
# 75%                                            62.870001
# max                                           100.000000

# %%
# Convert reaction input labels to one-hot encoding
input_cols = model_cols[:-1]

# Assign names for each input
prefix = ['electrophile',
          'nucleophile',
          'ligand',
          'base',
          'solvent']

# Create one-hot encoded input dataset
ohe_df = pd.get_dummies(df[input_cols], prefix=prefix)

# Add yield column to ohe dataset
ohe_df['yield'] = df[model_cols[-1]]/100

# Shuffle dataset
ohe_df = ohe_df.sample(frac=1)

# View dataset
ohe_df
# Out:
#       electrophile_BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3  \
# 1039                                            0
# 3884                                            0
# 640                                             0
# 1697                                            0
# 189                                             0
# ...                                           ...
# 4004                                            0
# 339                                             0
# 2522                                            0
# 1663                                            0
# 5306                                            1
#
#       electrophile_BrC1=CC=C2N=CC=CC2=C1  electrophile_ClC1=CC=C2N=CC=CC2=C1  \
# 1039                                   0                                   0
# 3884                                   1                                   0
# 640                                    1                                   0
# 1697                                   0                                   0
# 189                                    0                                   1
# ...                                  ...                                 ...
# 4004                                   1                                   0
# 339                                    0                                   1
# 2522                                   1                                   0
# 1663                                   0                                   0
# 5306                                   0                                   0
#
#       electrophile_IC1=CC=C2N=CC=CC2=C1  \
# 1039                                  0
# 3884                                  0
# 640                                   0
# 1697                                  0
# 189                                   0
# ...                                 ...
# 4004                                  0
# 339                                   0
# 2522                                  0
# 1663                                  0
# 5306                                  0
#
#       electrophile_O=S(OC1=CC=C2N=CC=CC2=C1)(C(F)(F)F)=O  \
# 1039                                                  1
# 3884                                                  0
# 640                                                   0
# 1697                                                  1
# 189                                                   0
# ...                                                 ...
# 4004                                                  0
# 339                                                   0
# 2522                                                  0
# 1663                                                  1
# 5306                                                  0
#
#       nucleophile_B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O  \
# 1039                                            1
# 3884                                            0
# 640                                             1
# 1697                                            0
# 189                                             1
# ...                                           ...
# 4004                                            0
# 339                                             1
# 2522                                            0
# 1663                                            0
# 5306                                            0
#
#       nucleophile_CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C  \
# 1039                                                 0
# 3884                                                 0
# 640                                                  0
# 1697                                                 0
# 189                                                  0
# ...                                                ...
# 4004                                                 0
# 339                                                  0
# 2522                                                 0
# 1663                                                 0
# 5306                                                 0
#
#       nucleophile_Cc1ccc2n(C3CCCCO3)ncc2c1B4OC(C)(C)C(C)(C)O4  \
# 1039                                                  0
# 3884                                                  0
# 640                                                   0
# 1697                                                  1
# 189                                                   0
# ...                                                 ...
# 4004                                                  0
# 339                                                   0
# 2522                                                  1
# 1663                                                  1
# 5306                                                  0
#
#       nucleophile_F[B-](F)(C1=C(C)C=CC2=C1C=NN2C3CCCCO3)F.[K+]  \
# 1039                                                  0
# 3884                                                  1
# 640                                                   0
# 1697                                                  0
# 189                                                   0
# ...                                                 ...
# 4004                                                  1
# 339                                                   0
# 2522                                                  0
# 1663                                                  0
# 5306                                                  0
#
#       nucleophile_OB(C1=CC=C2N=CC=CC2=C1)O.[H]Cl  ...  base_[F-].[Cs+]  \
# 1039                                           0  ...                0
# 3884                                           0  ...                0
# 640                                            0  ...                0
# 1697                                           0  ...                0
# 189                                            0  ...                0
# ...                                          ...  ...              ...
# 4004                                           0  ...                0
# 339                                            0  ...                0
# 2522                                           0  ...                1
# 1663                                           0  ...                1
# 5306                                           0  ...                0
#
#       base_[Li+].CC(C)(C)[O-]  base_[O-]P(=O)([O-])[O-].[K+].[K+].[K+]  \
# 1039                        0                                        0
# 3884                        1                                        0
# 640                         1                                        0
# 1697                        1                                        0
# 189                         0                                        0
# ...                       ...                                      ...
# 4004                        0                                        0
# 339                         0                                        0
# 2522                        0                                        0
# 1663                        0                                        0
# 5306                        0                                        0
#
#       base_[OH-].[K+]  base_[OH-].[Na+]  solvent_C1CCOC1  solvent_CC#N  \
# 1039                0                 0                0             0
# 3884                0                 0                0             1
# 640                 0                 0                0             0
# 1697                0                 0                1             0
# 189                 0                 0                1             0
# ...               ...               ...              ...           ...
# 4004                0                 0                1             0
# 339                 1                 0                0             0
# 2522                0                 0                0             0
# 1663                0                 0                1             0
# 5306                1                 0                0             0
#
#       solvent_CN(C)C=O  solvent_CO   yield
# 1039                 1           0  0.3026
# 3884                 0           0  0.1678
# 640                  1           0  0.1687
# 1697                 0           0  0.1855
# 189                  0           0  0.2187
# ...                ...         ...     ...
# 4004                 0           0  0.3374
# 339                  0           1  0.3931
# 2522                 1           0  0.4627
# 1663                 0           0  0.5113
# 5306                 1           0  0.0000
#
# [5760 rows x 36 columns]

# %% [markdown]
# ## Create datasets

# %%
# Create numpy arrays for inputs and outputs 
inputs = ohe_df.drop(columns=['yield']).values
outputs = ohe_df['yield'].values

# Verify array shapes
print(inputs.shape, outputs.shape)
# Out:
# (5760, 35) (5760,)

# %%
# Set training and test set parameters
train_size = math.floor(0.6 * len(inputs))
valid_size = math.floor(0.1 * len(inputs))
test_size = len(inputs) - train_size - valid_size

# Split arrays
X_train = inputs[:train_size]
y_train = outputs[:train_size]
X_valid = inputs[train_size:train_size+valid_size]
y_valid = outputs[train_size:train_size+valid_size]
X_test = inputs[train_size+valid_size:]
y_test = outputs[train_size+valid_size:]

# Check lengths
print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])
# Out:
# (3456, 35) (3456,)
# (576, 35) (576,)
# (1728, 35) (1728,)
# True

# %%
# Create training, validation, and test sets as tf Datasets and batch
batch_size = 100
train_dataset = tf.data.Dataset.from_tensor_slices(
    (X_train, y_train)).batch(batch_size)
valid_dataset = tf.data.Dataset.from_tensor_slices(
    (X_valid, y_valid)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (X_test, y_test)).batch(batch_size)

# Check length (in batches)
print(train_dataset.cardinality().numpy())
print(valid_dataset.cardinality().numpy())
print(test_dataset.cardinality().numpy())
# Out:
# 35
# 6
# 18

# %% [markdown]
# ## Set up model using TensorFlow
# Using hyperparameters from Granda et al. Nature 2018, 559, 377, DOI: 10.1038/s41586-018-0307-8.

# %%
# Set model parameters
epochs = 300

# Construct model
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=X_train.shape[1]),
    tf.keras.layers.Dense(50, activation='sigmoid'),
    tf.keras.layers.Dense(7, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1),
])

# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(0.005),
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Setup callback to load weights from best epoch later on
# Saving model weights from epoch with lowest validation loss
checkpoint_folder = os.path.join(os.getcwd(), 'saved_model')
if not os.path.exists(checkpoint_folder):
    os.makedirs(checkpoint_folder)
checkpoint_filepath = os.path.join(checkpoint_folder, 'saved_model')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

# Train model
history = model.fit(train_dataset,
                    epochs=epochs,
                    callbacks=[model_checkpoint_callback],
                    validation_data=valid_dataset)
# Out:
# Epoch 1/300
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0913 - root_mean_squared_error: 0.3022 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2416
# Epoch 2/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0604 - root_mean_squared_error: 0.2457 - val_loss: 0.0427 - val_root_mean_squared_error: 0.2065
# Epoch 3/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0478 - root_mean_squared_error: 0.2186 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 4/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0443 - root_mean_squared_error: 0.2104 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 5/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1896
# Epoch 6/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0402 - root_mean_squared_error: 0.2004 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
# Epoch 7/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0387 - root_mean_squared_error: 0.1968 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# Epoch 8/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0387 - root_mean_squared_error: 0.1967 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1809
# Epoch 9/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0386 - root_mean_squared_error: 0.1963 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1815
# Epoch 10/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0370 - root_mean_squared_error: 0.1924 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1793
# Epoch 11/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0365 - root_mean_squared_error: 0.1911 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1784
# Epoch 12/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0369 - root_mean_squared_error: 0.1922 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1791
# Epoch 13/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0367 - root_mean_squared_error: 0.1916 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1778
# Epoch 14/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0313 - val_root_mean_squared_error: 0.1770
# Epoch 15/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0367 - root_mean_squared_error: 0.1916 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1753
# Epoch 16/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0362 - root_mean_squared_error: 0.1901 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1742
# Epoch 17/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1747
# Epoch 18/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0358 - root_mean_squared_error: 0.1891 - val_loss: 0.0309 - val_root_mean_squared_error: 0.1757
# Epoch 19/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0358 - root_mean_squared_error: 0.1892 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# Epoch 20/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0359 - root_mean_squared_error: 0.1894 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1743
# Epoch 21/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0347 - root_mean_squared_error: 0.1864 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1733
# Epoch 22/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0348 - root_mean_squared_error: 0.1866 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1728
# Epoch 23/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0352 - root_mean_squared_error: 0.1875 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1718
# Epoch 24/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0353 - root_mean_squared_error: 0.1878 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1731
# Epoch 25/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0342 - root_mean_squared_error: 0.1848 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1722
# Epoch 26/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0348 - root_mean_squared_error: 0.1865 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1720
# Epoch 27/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0343 - root_mean_squared_error: 0.1851 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1709
# Epoch 28/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0344 - root_mean_squared_error: 0.1854 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1724
# Epoch 29/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0346 - root_mean_squared_error: 0.1861 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1711
# Epoch 30/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0344 - root_mean_squared_error: 0.1855 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 31/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0339 - root_mean_squared_error: 0.1842 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 32/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0341 - root_mean_squared_error: 0.1847 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1705
# Epoch 33/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0340 - root_mean_squared_error: 0.1844 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 34/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0335 - root_mean_squared_error: 0.1831 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1691
# Epoch 35/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0334 - root_mean_squared_error: 0.1827 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 36/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0330 - root_mean_squared_error: 0.1817 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1691
# Epoch 37/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0332 - root_mean_squared_error: 0.1822 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1682
# Epoch 38/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0329 - root_mean_squared_error: 0.1813 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1689
# Epoch 39/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0332 - root_mean_squared_error: 0.1823 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1690
# Epoch 40/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0329 - root_mean_squared_error: 0.1813 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1701
# Epoch 41/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0328 - root_mean_squared_error: 0.1811 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1692
# Epoch 42/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1664
# Epoch 43/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0322 - root_mean_squared_error: 0.1795 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 44/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0320 - root_mean_squared_error: 0.1790 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1656
# Epoch 45/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0326 - root_mean_squared_error: 0.1806 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1655
# Epoch 46/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0315 - root_mean_squared_error: 0.1775 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1640
# Epoch 47/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1635
# Epoch 48/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0304 - root_mean_squared_error: 0.1744 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1625
# Epoch 49/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0310 - root_mean_squared_error: 0.1761 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 50/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1616
# Epoch 51/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0303 - root_mean_squared_error: 0.1742 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 52/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1600
# Epoch 53/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0292 - root_mean_squared_error: 0.1708 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1584
# Epoch 54/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 55/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0293 - root_mean_squared_error: 0.1712 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 56/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0281 - root_mean_squared_error: 0.1678 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1561
# Epoch 57/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0277 - root_mean_squared_error: 0.1664 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1550
# Epoch 58/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1535
# Epoch 59/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548
# Epoch 60/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1653 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1521
# Epoch 61/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0269 - root_mean_squared_error: 0.1640 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1523
# Epoch 62/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1510
# Epoch 63/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0269 - root_mean_squared_error: 0.1641 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1515
# Epoch 64/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1629 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1503
# Epoch 65/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0261 - root_mean_squared_error: 0.1614 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 66/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0258 - root_mean_squared_error: 0.1605 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 67/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0259 - root_mean_squared_error: 0.1609 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1481
# Epoch 68/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 69/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 70/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 71/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1478
# Epoch 72/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468
# Epoch 73/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1455
# Epoch 74/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 75/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1452
# Epoch 76/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0232 - root_mean_squared_error: 0.1523 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 77/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# Epoch 78/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1455
# Epoch 79/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# Epoch 80/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1422
# Epoch 81/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0227 - root_mean_squared_error: 0.1506 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 82/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1423
# Epoch 83/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0230 - root_mean_squared_error: 0.1515 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1431
# Epoch 84/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1424
# Epoch 85/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1402
# Epoch 86/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0223 - root_mean_squared_error: 0.1494 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1416
# Epoch 87/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1400
# Epoch 88/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0214 - root_mean_squared_error: 0.1464 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1404
# Epoch 89/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389
# Epoch 90/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1388
# Epoch 91/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0213 - root_mean_squared_error: 0.1461 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1398
# Epoch 92/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1391
# Epoch 93/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1388
# Epoch 94/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1369
# Epoch 95/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
# Epoch 96/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0212 - root_mean_squared_error: 0.1456 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1356
# Epoch 97/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1363
# Epoch 98/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347
# Epoch 99/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1359
# Epoch 100/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0198 - root_mean_squared_error: 0.1408 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1330
# Epoch 101/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0191 - root_mean_squared_error: 0.1384 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1308
# Epoch 102/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310
# Epoch 103/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 104/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 105/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 106/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1271
# Epoch 107/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 108/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1253
# Epoch 109/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1256
# Epoch 110/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0179 - root_mean_squared_error: 0.1338 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 111/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238
# Epoch 112/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0179 - root_mean_squared_error: 0.1336 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1237
# Epoch 113/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1243
# Epoch 114/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 115/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1229
# Epoch 116/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 117/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 118/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 119/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 120/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 121/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 122/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 123/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223
# Epoch 124/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1198
# Epoch 125/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1199
# Epoch 126/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 127/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 128/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 129/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 130/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1197
# Epoch 131/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 132/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 133/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1190
# Epoch 134/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179
# Epoch 135/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 136/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1185
# Epoch 137/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1184
# Epoch 138/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 139/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1173
# Epoch 140/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 141/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1185
# Epoch 142/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 143/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 144/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1181
# Epoch 145/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 146/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 147/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 148/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 149/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 150/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 151/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 152/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0142 - root_mean_squared_error: 0.1194 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 153/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0146 - root_mean_squared_error: 0.1206 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 154/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 155/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0138 - root_mean_squared_error: 0.1174 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 156/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1176
# Epoch 157/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 158/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 159/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 160/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# Epoch 161/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 162/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 163/300
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 164/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1151
# Epoch 165/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 166/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1151
# Epoch 167/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 168/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 169/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 170/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 171/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 172/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 173/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 174/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 175/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 176/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 177/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 178/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 179/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 180/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 181/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 182/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 183/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1134
# Epoch 184/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 185/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 186/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 187/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1150
# Epoch 188/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 189/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 190/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 191/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 192/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 193/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 194/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 195/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 196/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 197/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 198/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 199/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 200/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 201/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# Epoch 202/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 203/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 204/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 205/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 206/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 207/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 208/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 209/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 210/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 211/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 212/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 213/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 214/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 215/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 216/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 217/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 218/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 219/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 220/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 221/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 222/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 223/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 224/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 225/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 226/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 227/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 228/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 229/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 230/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 231/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1120
# Epoch 232/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 233/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 234/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 235/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 236/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 237/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0114 - root_mean_squared_error: 0.1065 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 238/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1120
# Epoch 239/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 240/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 241/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 242/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 243/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 244/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 245/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 246/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 247/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 248/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 249/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 250/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0105 - root_mean_squared_error: 0.1022 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1129
# Epoch 251/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 252/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 253/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 254/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 255/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 256/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 257/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 258/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1129
# Epoch 259/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 260/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 261/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 262/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 263/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0107 - root_mean_squared_error: 0.1037 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 264/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 265/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 266/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 267/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 268/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1129
# Epoch 269/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 270/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 271/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 272/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 273/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 274/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 275/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 276/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 277/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 278/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 279/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 280/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 281/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 282/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 283/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 284/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 285/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 286/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 287/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 288/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 289/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 290/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 291/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 292/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 293/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 294/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 295/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 296/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 297/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 298/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 299/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 300/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128

# %%
# Show best epoch
best_epoch = np.argmin(np.array(history.history['val_loss']))
best_epoch
# Out:
# 265

# %%
# Load model weights from best epoch
model.load_weights(checkpoint_filepath)

# Generate predictions for test set and measure test RMSE and R2
preds = model.predict(test_dataset)
evals = model.evaluate(x=test_dataset, return_dict=True)
r2 = r2_score(y_test, preds)
rmse = evals['root_mean_squared_error']
print(f'Test RMSE: {evals}')
print(f'Test R2: {r2}')

# Plot model performance
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,6))
fig.suptitle('Pfizer Suzuki HTE MLP Model Performance')

# Plot loss through training
ax1.plot(history.history['loss'], 'b', label='training loss')
ax1.plot(history.history['val_loss'], 'g', label='validation loss')
ax1.legend()
ax1.set_ylabel('loss (MSE)')
ax1.set_xlabel('epoch')
ax1.set_title('loss curves')

# Plot predictions vs ground truth
ax2.plot(y_test, preds, 'bo')
ax2.plot([0, 1], 'r')
ax2.set_ylabel('predicted yield')
ax2.set_xlabel('ground truth yield')
ax2.set_title('predictions vs ground truth')
ax2.text(0.6, 0, f'test_RMSE: {round(rmse, 3)}')
ax2.text(0.6, -0.05, f'test_R2: {round(r2, 3)}')

# Save and view performance plots
plt.savefig('ORD_Perera_HTE_yield_regression_MLP_performance.png', dpi=100)
plt.show()
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149
# Test RMSE: {'loss': 0.01321318931877613, 'root_mean_squared_error': 0.11494863778352737}
# Test R2: 0.833907302619911

# %%
# Show ground truth and predicted yield distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
fig.suptitle('Ground Truth and Predicted Yield Distributions')

# Plot ground truth histogram
ax1.hist(ohe_df['yield'], bins=20, rwidth=0.93, color='navy')
ax1.set_title('ground truth')
ax1.set_xlabel('yield')
ax1.set_ylabel('frequency (count)')

# Plot predicted histogram
ax2.hist(preds, bins=20, rwidth=0.93, color='navy')
ax2.set_title('predictions')
ax2.set_xlabel('yield')
ax2.set_ylabel('frequency (count)')

# Save and view distributions
plt.savefig('ORD_Perera_HTE_yield_regression_distributions.png', dpi=100)
plt.show()
