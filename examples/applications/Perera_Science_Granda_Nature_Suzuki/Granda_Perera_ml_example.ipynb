# %% [markdown]
# # Example application of ORD datasets for downstream machine learning modeling

# %% [markdown]
# Reproducing neural network predictor of reaction yields from Granda et al. Nature 2018, 559, 377, DOI: 10.1038/s41586-018-0307-8.<br>
# Data from Perera et al. Science 2018, 359, 429, DOI: 10.1126/science.aap9112.<br>
# ORD dataset location: https://github.com/open-reaction-database/ord-data/blob/main/data/68/ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203.pb.gz<br>
# ORD dataset ID: ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203

# %%
# Import modules
import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2

import math
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import wget

from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn import model_selection, metrics
from glob import glob

# %%
# Download dataset from ord-data
url = "https://github.com/open-reaction-database/ord-data/blob/main/data/68/ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203.pb.gz?raw=true"
pb = wget.download(url)
# Out:
# 100% [............................................................................] 269731 / 269731

# %%
# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# %%
# Ensure dataset validates
valid_output = validations.validate_message(data)

# %%
# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, drop_constant_columns=True)

# View dataframe
df
# Out:
#      inputs["Aryl Halide"].components[0].identifiers[0].value  \
# 0                                 ClC1=CC=C2N=CC=CC2=C1
# 1                                 ClC1=CC=C2N=CC=CC2=C1
# 2                                 ClC1=CC=C2N=CC=CC2=C1
# 3                                 ClC1=CC=C2N=CC=CC2=C1
# 4                                 ClC1=CC=C2N=CC=CC2=C1
# ...                                                 ...
# 5755                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5756                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5757                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5758                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5759                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
#
#      inputs["Solvent_1"].components[0].identifiers[0].value  \
# 0                                                  CC#N
# 1                                                  CC#N
# 2                                                  CC#N
# 3                                                  CC#N
# 4                                                  CC#N
# ...                                                 ...
# 5755                                           CN(C)C=O
# 5756                                           CN(C)C=O
# 5757                                           CN(C)C=O
# 5758                                           CN(C)C=O
# 5759                                           CN(C)C=O
#
#      inputs["Ligand in Solvent"].components[0].identifiers[0].value  \
# 0                           CC(C)(C)P(C(C)(C)C)C(C)(C)C
# 1                         c1ccc(cc1)P(c2ccccc2)c3ccccc3
# 2     CC(C)(C)P(C1=CC=C(C=C1)N(C)C)C(C)(C)C.CC(C)(C)...
# 3                         C1CCC(CC1)P(C2CCCCC2)C3CCCCC3
# 4                        Cc1ccccc1P(c2ccccc2C)c3ccccc3C
# ...                                                 ...
# 5755  CC(C)(C)P([C]1[CH][CH][CH][CH]1)C(C)(C)C.CC(C)...
# 5756  CC(C)c1cc(c(c(c1)C(C)C)c2ccccc2P(C3CCCCC3)C4CC...
# 5757  c1ccc(cc1)P([c-]2cccc2)c3ccccc3.c1ccc(cc1)P([c...
# 5758  CC1(c2cccc(c2Oc3c1cccc3P(c4ccccc4)c5ccccc5)P(c...
# 5759                                          Cc1ccccc1
#
#       inputs["Ligand in Solvent"].components[0].amount.moles.value  \
# 0                                                  0.05
# 1                                                  0.05
# 2                                                  0.05
# 3                                                  0.05
# 4                                                  0.05
# ...                                                 ...
# 5755                                               0.05
# 5756                                               0.05
# 5757                                               0.05
# 5758                                               0.05
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[0].amount.moles.units  \
# 0                                             MICROMOLE
# 1                                             MICROMOLE
# 2                                             MICROMOLE
# 3                                             MICROMOLE
# 4                                             MICROMOLE
# ...                                                 ...
# 5755                                          MICROMOLE
# 5756                                          MICROMOLE
# 5757                                          MICROMOLE
# 5758                                          MICROMOLE
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[0].reaction_role  \
# 0                                              CATALYST
# 1                                              CATALYST
# 2                                              CATALYST
# 3                                              CATALYST
# 4                                              CATALYST
# ...                                                 ...
# 5755                                           CATALYST
# 5756                                           CATALYST
# 5757                                           CATALYST
# 5758                                           CATALYST
# 5759                                            SOLVENT
#
#      inputs["Ligand in Solvent"].components[1].identifiers[0].type  \
# 0                                                SMILES
# 1                                                SMILES
# 2                                                SMILES
# 3                                                SMILES
# 4                                                SMILES
# ...                                                 ...
# 5755                                             SMILES
# 5756                                             SMILES
# 5757                                             SMILES
# 5758                                             SMILES
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[1].identifiers[0].value  \
# 0                                             Cc1ccccc1
# 1                                             Cc1ccccc1
# 2                                             Cc1ccccc1
# 3                                             Cc1ccccc1
# 4                                             Cc1ccccc1
# ...                                                 ...
# 5755                                          Cc1ccccc1
# 5756                                          Cc1ccccc1
# 5757                                          Cc1ccccc1
# 5758                                          Cc1ccccc1
# 5759                                                NaN
#
#       inputs["Ligand in Solvent"].components[1].amount.volume.value  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 5755                                                1.0
# 5756                                                1.0
# 5757                                                1.0
# 5758                                                1.0
# 5759                                                NaN
#
#      inputs["Ligand in Solvent"].components[1].amount.volume.units  ...  \
# 0                                            MICROLITER             ...
# 1                                            MICROLITER             ...
# 2                                            MICROLITER             ...
# 3                                            MICROLITER             ...
# 4                                            MICROLITER             ...
# ...                                                 ...             ...
# 5755                                         MICROLITER             ...
# 5756                                         MICROLITER             ...
# 5757                                         MICROLITER             ...
# 5758                                         MICROLITER             ...
# 5759                                                NaN             ...
#
#      inputs["Boronate in Solvent"].components[0].identifiers[0].value  \
# 0                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 1                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 2                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 3                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 4                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# ...                                                 ...
# 5755               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5756               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5757               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5758               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5759               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
#
#      inputs["Boronate in Solvent"].components[1].identifiers[0].value  \
# 0                                              CN(C)C=O
# 1                                              CN(C)C=O
# 2                                              CN(C)C=O
# 3                                              CN(C)C=O
# 4                                              CN(C)C=O
# ...                                                 ...
# 5755                                           O=CN(C)C
# 5756                                           O=CN(C)C
# 5757                                           O=CN(C)C
# 5758                                           O=CN(C)C
# 5759                                           O=CN(C)C
#
#      outcomes[0].products[0].measurements[0].percentage.value  \
# 0                                              4.760000
# 1                                              4.120000
# 2                                              2.580000
# 3                                              4.440000
# 4                                              1.950000
# ...                                                 ...
# 5755                                          47.209999
# 5756                                           0.000000
# 5757                                          31.440001
# 5758                                           0.000000
# 5759                                          54.200001
#
#       provenance.record_modified[1].time.value  \
# 0                   2021-03-04 13:56:15.292871
# 1                   2021-03-04 13:56:15.298402
# 2                   2021-03-04 13:56:15.303978
# 3                   2021-03-04 13:56:15.309572
# 4                   2021-03-04 13:56:15.315080
# ...                                        ...
# 5755                2021-03-04 13:56:49.737623
# 5756                2021-03-04 13:56:49.743574
# 5757                2021-03-04 13:56:49.749090
# 5758                2021-03-04 13:56:49.754742
# 5759                2021-03-04 13:56:49.759986
#
#                                reaction_id  \
# 0     ord-61b2819b15824f1fa131ed1b2ea1dae4
# 1     ord-f18c2b2d0bd04d2c96a3a16dfd8b8bef
# 2     ord-1061f43c594b4de68345c010b2aef94b
# 3     ord-e61614af430845179c392e478d958383
# 4     ord-3fede496f4284a5ea6656f083e2399ae
# ...                                    ...
# 5755  ord-b498385d41664713aaef79a290409614
# 5756  ord-2ef787f9faac4077bff2d903866aa209
# 5757  ord-654740d21331471cafdfda41ff19d57a
# 5758  ord-8e53efc193e548ba888b47da3e91ced5
# 5759  ord-0c525e5dde954d91b6dc2fe0bb849655
#
#      inputs["Ligand in Solvent"].components[0].amount.volume.value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                                1.0
#
#      inputs["Ligand in Solvent"].components[0].amount.volume.units  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                         MICROLITER
#
#      inputs["Ligand in Solvent"].components[0].amount.volume_includes_solutes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                               True
#
#       inputs["Base in Solvent"].components[0].amount.volume.value  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                                NaN
#
#      inputs["Base in Solvent"].components[0].amount.volume.units
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5755                                                NaN
# 5756                                                NaN
# 5757                                                NaN
# 5758                                                NaN
# 5759                                                NaN
#
# [5760 rows x 31 columns]

# %%
# View all columns with variation in the dataset
list(df.columns)
# Out:
# ['inputs["Aryl Halide"].components[0].identifiers[0].value',
#  'inputs["Solvent_1"].components[0].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[0].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[0].amount.moles.value',
#  'inputs["Ligand in Solvent"].components[0].amount.moles.units',
#  'inputs["Ligand in Solvent"].components[0].reaction_role',
#  'inputs["Ligand in Solvent"].components[1].identifiers[0].type',
#  'inputs["Ligand in Solvent"].components[1].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[1].amount.volume.value',
#  'inputs["Ligand in Solvent"].components[1].amount.volume.units',
#  'inputs["Ligand in Solvent"].components[1].amount.volume_includes_solutes',
#  'inputs["Ligand in Solvent"].components[1].reaction_role',
#  'inputs["Base in Solvent"].components[0].identifiers[0].value',
#  'inputs["Base in Solvent"].components[0].amount.moles.value',
#  'inputs["Base in Solvent"].components[0].amount.moles.units',
#  'inputs["Base in Solvent"].components[0].reaction_role',
#  'inputs["Base in Solvent"].components[1].identifiers[0].type',
#  'inputs["Base in Solvent"].components[1].identifiers[0].value',
#  'inputs["Base in Solvent"].components[1].amount.volume.value',
#  'inputs["Base in Solvent"].components[1].amount.volume.units',
#  'inputs["Base in Solvent"].components[1].reaction_role',
#  'inputs["Boronate in Solvent"].components[0].identifiers[0].value',
#  'inputs["Boronate in Solvent"].components[1].identifiers[0].value',
#  'outcomes[0].products[0].measurements[0].percentage.value',
#  'provenance.record_modified[1].time.value',
#  'reaction_id',
#  'inputs["Ligand in Solvent"].components[0].amount.volume.value',
#  'inputs["Ligand in Solvent"].components[0].amount.volume.units',
#  'inputs["Ligand in Solvent"].components[0].amount.volume_includes_solutes',
#  'inputs["Base in Solvent"].components[0].amount.volume.value',
#  'inputs["Base in Solvent"].components[0].amount.volume.units']

# %%
# Create new dataframe containing only columns to be used in modeling
model_cols = [
    'inputs["Aryl Halide"].components[0].identifiers[0].value',
    'inputs["Boronate in Solvent"].components[0].identifiers[0].value',
    'inputs["Ligand in Solvent"].components[0].identifiers[0].value',
    'inputs["Base in Solvent"].components[0].identifiers[0].value',
    'inputs["Solvent_1"].components[0].identifiers[0].value',
    "outcomes[0].products[0].measurements[0].percentage.value",
]
df = df[model_cols]
df
# Out:
#      inputs["Aryl Halide"].components[0].identifiers[0].value  \
# 0                                 ClC1=CC=C2N=CC=CC2=C1
# 1                                 ClC1=CC=C2N=CC=CC2=C1
# 2                                 ClC1=CC=C2N=CC=CC2=C1
# 3                                 ClC1=CC=C2N=CC=CC2=C1
# 4                                 ClC1=CC=C2N=CC=CC2=C1
# ...                                                 ...
# 5755                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5756                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5757                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5758                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5759                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
#
#      inputs["Boronate in Solvent"].components[0].identifiers[0].value  \
# 0                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 1                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 2                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 3                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 4                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# ...                                                 ...
# 5755               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5756               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5757               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5758               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5759               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
#
#      inputs["Ligand in Solvent"].components[0].identifiers[0].value  \
# 0                           CC(C)(C)P(C(C)(C)C)C(C)(C)C
# 1                         c1ccc(cc1)P(c2ccccc2)c3ccccc3
# 2     CC(C)(C)P(C1=CC=C(C=C1)N(C)C)C(C)(C)C.CC(C)(C)...
# 3                         C1CCC(CC1)P(C2CCCCC2)C3CCCCC3
# 4                        Cc1ccccc1P(c2ccccc2C)c3ccccc3C
# ...                                                 ...
# 5755  CC(C)(C)P([C]1[CH][CH][CH][CH]1)C(C)(C)C.CC(C)...
# 5756  CC(C)c1cc(c(c(c1)C(C)C)c2ccccc2P(C3CCCCC3)C4CC...
# 5757  c1ccc(cc1)P([c-]2cccc2)c3ccccc3.c1ccc(cc1)P([c...
# 5758  CC1(c2cccc(c2Oc3c1cccc3P(c4ccccc4)c5ccccc5)P(c...
# 5759                                          Cc1ccccc1
#
#      inputs["Base in Solvent"].components[0].identifiers[0].value  \
# 0                                           [OH-].[Na+]
# 1                                           [OH-].[Na+]
# 2                                           [OH-].[Na+]
# 3                                           [OH-].[Na+]
# 4                                           [OH-].[Na+]
# ...                                                 ...
# 5755                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5756                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5757                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5758                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5759                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
#
#      inputs["Solvent_1"].components[0].identifiers[0].value  \
# 0                                                  CC#N
# 1                                                  CC#N
# 2                                                  CC#N
# 3                                                  CC#N
# 4                                                  CC#N
# ...                                                 ...
# 5755                                           CN(C)C=O
# 5756                                           CN(C)C=O
# 5757                                           CN(C)C=O
# 5758                                           CN(C)C=O
# 5759                                           CN(C)C=O
#
#       outcomes[0].products[0].measurements[0].percentage.value
# 0                                              4.760000
# 1                                              4.120000
# 2                                              2.580000
# 3                                              4.440000
# 4                                              1.950000
# ...                                                 ...
# 5755                                          47.209999
# 5756                                           0.000000
# 5757                                          31.440001
# 5758                                           0.000000
# 5759                                          54.200001
#
# [5760 rows x 6 columns]

# %%
# Check for NaN values
print(f"number of NaN values: {df.isnull().sum().sum()}")

# Show column counts
df.info()
# Out:
# number of NaN values: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 6 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   inputs["Aryl Halide"].components[0].identifiers[0].value          5760 non-null   object
#  1   inputs["Boronate in Solvent"].components[0].identifiers[0].value  5760 non-null   object
#  2   inputs["Ligand in Solvent"].components[0].identifiers[0].value    5760 non-null   object
#  3   inputs["Base in Solvent"].components[0].identifiers[0].value      5760 non-null   object
#  4   inputs["Solvent_1"].components[0].identifiers[0].value            5760 non-null   object
#  5   outcomes[0].products[0].measurements[0].percentage.value          5760 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 270.1+ KB

# %%
# Show dataset statistics for numerical fields
df.describe()
# Out:
#        outcomes[0].products[0].measurements[0].percentage.value
# count                                        5760.000000
# mean                                           40.109446
# std                                            28.081087
# min                                             0.000000
# 25%                                            16.197501
# 50%                                            33.580000
# 75%                                            62.870001
# max                                           100.000000

# %%
# Convert reaction input labels to one-hot encoding
input_cols = model_cols[:-1]

# Assign names for each input
prefix = ["electrophile", "nucleophile", "ligand", "base", "solvent"]

# Create one-hot encoded input dataset
ohe_df = pd.get_dummies(df[input_cols], prefix=prefix)

# Add yield column to ohe dataset
ohe_df["yield"] = df[model_cols[-1]] / 100

# View dataset
ohe_df
# Out:
#       electrophile_BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 5755                                         True
# 5756                                         True
# 5757                                         True
# 5758                                         True
# 5759                                         True
#
#       electrophile_BrC1=CC=C2N=CC=CC2=C1  electrophile_ClC1=CC=C2N=CC=CC2=C1  \
# 0                                  False                                True
# 1                                  False                                True
# 2                                  False                                True
# 3                                  False                                True
# 4                                  False                                True
# ...                                  ...                                 ...
# 5755                               False                               False
# 5756                               False                               False
# 5757                               False                               False
# 5758                               False                               False
# 5759                               False                               False
#
#       electrophile_IC1=CC=C2N=CC=CC2=C1  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 5755                              False
# 5756                              False
# 5757                              False
# 5758                              False
# 5759                              False
#
#       electrophile_O=S(OC1=CC=C2N=CC=CC2=C1)(C(F)(F)F)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       nucleophile_B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
# ...                                           ...
# 5755                                        False
# 5756                                        False
# 5757                                        False
# 5758                                        False
# 5759                                        False
#
#       nucleophile_CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 5755                                              True
# 5756                                              True
# 5757                                              True
# 5758                                              True
# 5759                                              True
#
#       nucleophile_Cc1ccc2n(C3CCCCO3)ncc2c1B4OC(C)(C)C(C)(C)O4  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       nucleophile_F[B-](F)(C1=C(C)C=CC2=C1C=NN2C3CCCCO3)F.[K+]  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       nucleophile_OB(C1=CC=C2N=CC=CC2=C1)O.[H]Cl  ...  base_[F-].[Cs+]  \
# 0                                          False  ...            False
# 1                                          False  ...            False
# 2                                          False  ...            False
# 3                                          False  ...            False
# 4                                          False  ...            False
# ...                                          ...  ...              ...
# 5755                                       False  ...            False
# 5756                                       False  ...            False
# 5757                                       False  ...            False
# 5758                                       False  ...            False
# 5759                                       False  ...            False
#
#       base_[Li+].CC(C)(C)[O-]  base_[O-]P(=O)([O-])[O-].[K+].[K+].[K+]  \
# 0                       False                                    False
# 1                       False                                    False
# 2                       False                                    False
# 3                       False                                    False
# 4                       False                                    False
# ...                       ...                                      ...
# 5755                    False                                     True
# 5756                    False                                     True
# 5757                    False                                     True
# 5758                    False                                     True
# 5759                    False                                     True
#
#       base_[OH-].[K+]  base_[OH-].[Na+]  solvent_C1CCOC1  solvent_CC#N  \
# 0               False              True            False          True
# 1               False              True            False          True
# 2               False              True            False          True
# 3               False              True            False          True
# 4               False              True            False          True
# ...               ...               ...              ...           ...
# 5755            False             False            False         False
# 5756            False             False            False         False
# 5757            False             False            False         False
# 5758            False             False            False         False
# 5759            False             False            False         False
#
#       solvent_CN(C)C=O  solvent_CO   yield
# 0                False       False  0.0476
# 1                False       False  0.0412
# 2                False       False  0.0258
# 3                False       False  0.0444
# 4                False       False  0.0195
# ...                ...         ...     ...
# 5755              True       False  0.4721
# 5756              True       False  0.0000
# 5757              True       False  0.3144
# 5758              True       False  0.0000
# 5759              True       False  0.5420
#
# [5760 rows x 36 columns]

# %% [markdown]
# ## Create datasets

# %%
# Create numpy arrays for inputs and outputs
X = ohe_df.drop(columns=["yield"]).values
y = ohe_df["yield"].values

# Verify array shapes
print(X.shape, y.shape)
# Out:
# (5760, 35) (5760,)

# %%
# Set training, validation, and test sets with random_state for reproducibility
_X_train, X_test, _y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=0)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(
    _X_train, _y_train, test_size=(0.1 / 0.7), shuffle=False
)

# Check lengths
print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])
# Out:
# (3455, 35) (3455,)
# (577, 35) (577,)
# (1728, 35) (1728,)
# True

# %%
# Create training, validation, and test sets as tf Datasets and batch
batch_size = 100
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
valid_dataset = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# Check length (in batches)
print(train_dataset.cardinality().numpy())
print(valid_dataset.cardinality().numpy())
print(test_dataset.cardinality().numpy())
# Out:
# 35
# 6
# 18

# %% [markdown]
# ## Set up model using TensorFlow
# Using hyperparameters from Granda et al. Nature 2018, 559, 377, DOI: 10.1038/s41586-018-0307-8.

# %%
# Set model parameters
epochs = 300

# Construct model
model = tf.keras.Sequential(
    [
        tf.keras.Input((X_train.shape[1],)),
        tf.keras.layers.Dense(50, activation="sigmoid"),
        tf.keras.layers.Dense(7, activation="sigmoid"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1),
    ]
)

# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.005),
    loss=tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()],
)

# Setup callback to load weights from best epoch later on
# Saving model weights from epoch with lowest validation loss
checkpoint_filepath = os.path.join(os.getcwd(), "saved_model.keras")
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor="val_loss", mode="min", save_best_only=True
)

# Train model
history = model.fit(train_dataset, epochs=epochs, callbacks=[model_checkpoint_callback], validation_data=valid_dataset)
# Out:
# WARNING 2024-04-12 15:13:14,769 optimizer.py:70: At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/300
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1405 - root_mean_squared_error: 0.3749 - val_loss: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 2/300
# 35/35 [==============================] - 0s 756us/step - loss: 0.0721 - root_mean_squared_error: 0.2684 - val_loss: 0.0531 - val_root_mean_squared_error: 0.2304
# Epoch 3/300
# 35/35 [==============================] - 0s 674us/step - loss: 0.0593 - root_mean_squared_error: 0.2435 - val_loss: 0.0440 - val_root_mean_squared_error: 0.2099
# Epoch 4/300
# 35/35 [==============================] - 0s 627us/step - loss: 0.0512 - root_mean_squared_error: 0.2263 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1987
# Epoch 5/300
# 35/35 [==============================] - 0s 601us/step - loss: 0.0452 - root_mean_squared_error: 0.2127 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 6/300
# 35/35 [==============================] - 0s 642us/step - loss: 0.0445 - root_mean_squared_error: 0.2111 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 7/300
# 35/35 [==============================] - 0s 633us/step - loss: 0.0423 - root_mean_squared_error: 0.2056 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1880
# Epoch 8/300
# 35/35 [==============================] - 0s 648us/step - loss: 0.0402 - root_mean_squared_error: 0.2006 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
# Epoch 9/300
# 35/35 [==============================] - 0s 510us/step - loss: 0.0407 - root_mean_squared_error: 0.2016 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1856
# Epoch 10/300
# 35/35 [==============================] - 0s 649us/step - loss: 0.0391 - root_mean_squared_error: 0.1978 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
# Epoch 11/300
# 35/35 [==============================] - 0s 511us/step - loss: 0.0400 - root_mean_squared_error: 0.1999 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1847
# Epoch 12/300
# 35/35 [==============================] - 0s 493us/step - loss: 0.0382 - root_mean_squared_error: 0.1954 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1843
# Epoch 13/300
# 35/35 [==============================] - 0s 832us/step - loss: 0.0382 - root_mean_squared_error: 0.1955 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
# Epoch 14/300
# 35/35 [==============================] - 0s 698us/step - loss: 0.0378 - root_mean_squared_error: 0.1944 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
# Epoch 15/300
# 35/35 [==============================] - 0s 726us/step - loss: 0.0369 - root_mean_squared_error: 0.1921 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1825
# Epoch 16/300
# 35/35 [==============================] - 0s 639us/step - loss: 0.0370 - root_mean_squared_error: 0.1923 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1824
# Epoch 17/300
# 35/35 [==============================] - 0s 636us/step - loss: 0.0366 - root_mean_squared_error: 0.1914 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1814
# Epoch 18/300
# 35/35 [==============================] - 0s 640us/step - loss: 0.0367 - root_mean_squared_error: 0.1916 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1804
# Epoch 19/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0361 - root_mean_squared_error: 0.1901 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1809
# Epoch 20/300
# 35/35 [==============================] - 0s 494us/step - loss: 0.0361 - root_mean_squared_error: 0.1900 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1807
# Epoch 21/300
# 35/35 [==============================] - 0s 635us/step - loss: 0.0366 - root_mean_squared_error: 0.1913 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1797
# Epoch 22/300
# 35/35 [==============================] - 0s 447us/step - loss: 0.0365 - root_mean_squared_error: 0.1909 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1803
# Epoch 23/300
# 35/35 [==============================] - 0s 637us/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1795
# Epoch 24/300
# 35/35 [==============================] - 0s 604us/step - loss: 0.0351 - root_mean_squared_error: 0.1872 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1788
# Epoch 25/300
# 35/35 [==============================] - 0s 524us/step - loss: 0.0344 - root_mean_squared_error: 0.1855 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1788
# Epoch 26/300
# 35/35 [==============================] - 0s 650us/step - loss: 0.0350 - root_mean_squared_error: 0.1870 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1786
# Epoch 27/300
# 35/35 [==============================] - 0s 399us/step - loss: 0.0346 - root_mean_squared_error: 0.1860 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1789
# Epoch 28/300
# 35/35 [==============================] - 0s 650us/step - loss: 0.0336 - root_mean_squared_error: 0.1834 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1786
# Epoch 29/300
# 35/35 [==============================] - 0s 586us/step - loss: 0.0341 - root_mean_squared_error: 0.1847 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1785
# Epoch 30/300
# 35/35 [==============================] - 0s 607us/step - loss: 0.0335 - root_mean_squared_error: 0.1832 - val_loss: 0.0314 - val_root_mean_squared_error: 0.1771
# Epoch 31/300
# 35/35 [==============================] - 0s 732us/step - loss: 0.0336 - root_mean_squared_error: 0.1833 - val_loss: 0.0313 - val_root_mean_squared_error: 0.1768
# Epoch 32/300
# 35/35 [==============================] - 0s 610us/step - loss: 0.0340 - root_mean_squared_error: 0.1845 - val_loss: 0.0314 - val_root_mean_squared_error: 0.1773
# Epoch 33/300
# 35/35 [==============================] - 0s 946us/step - loss: 0.0340 - root_mean_squared_error: 0.1843 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1764
# Epoch 34/300
# 35/35 [==============================] - 0s 768us/step - loss: 0.0334 - root_mean_squared_error: 0.1829 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1755
# Epoch 35/300
# 35/35 [==============================] - 0s 787us/step - loss: 0.0332 - root_mean_squared_error: 0.1822 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1753
# Epoch 36/300
# 35/35 [==============================] - 0s 777us/step - loss: 0.0331 - root_mean_squared_error: 0.1819 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1746
# Epoch 37/300
# 35/35 [==============================] - 0s 740us/step - loss: 0.0330 - root_mean_squared_error: 0.1815 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 38/300
# 35/35 [==============================] - 0s 578us/step - loss: 0.0333 - root_mean_squared_error: 0.1825 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1744
# Epoch 39/300
# 35/35 [==============================] - 0s 632us/step - loss: 0.0327 - root_mean_squared_error: 0.1807 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1744
# Epoch 40/300
# 35/35 [==============================] - 0s 737us/step - loss: 0.0329 - root_mean_squared_error: 0.1815 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1735
# Epoch 41/300
# 35/35 [==============================] - 0s 747us/step - loss: 0.0320 - root_mean_squared_error: 0.1788 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1723
# Epoch 42/300
# 35/35 [==============================] - 0s 652us/step - loss: 0.0321 - root_mean_squared_error: 0.1791 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1722
# Epoch 43/300
# 35/35 [==============================] - 0s 627us/step - loss: 0.0318 - root_mean_squared_error: 0.1784 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1713
# Epoch 44/300
# 35/35 [==============================] - 0s 596us/step - loss: 0.0315 - root_mean_squared_error: 0.1776 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1706
# Epoch 45/300
# 35/35 [==============================] - 0s 617us/step - loss: 0.0312 - root_mean_squared_error: 0.1767 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1692
# Epoch 46/300
# 35/35 [==============================] - 0s 575us/step - loss: 0.0309 - root_mean_squared_error: 0.1759 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1690
# Epoch 47/300
# 35/35 [==============================] - 0s 634us/step - loss: 0.0307 - root_mean_squared_error: 0.1753 - val_loss: 0.0282 - val_root_mean_squared_error: 0.1680
# Epoch 48/300
# 35/35 [==============================] - 0s 636us/step - loss: 0.0307 - root_mean_squared_error: 0.1752 - val_loss: 0.0279 - val_root_mean_squared_error: 0.1672
# Epoch 49/300
# 35/35 [==============================] - 0s 698us/step - loss: 0.0299 - root_mean_squared_error: 0.1728 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1668
# Epoch 50/300
# 35/35 [==============================] - 0s 603us/step - loss: 0.0300 - root_mean_squared_error: 0.1733 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1664
# Epoch 51/300
# 35/35 [==============================] - 0s 642us/step - loss: 0.0298 - root_mean_squared_error: 0.1726 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1646
# Epoch 52/300
# 35/35 [==============================] - 0s 427us/step - loss: 0.0297 - root_mean_squared_error: 0.1723 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1650
# Epoch 53/300
# 35/35 [==============================] - 0s 736us/step - loss: 0.0290 - root_mean_squared_error: 0.1702 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1641
# Epoch 54/300
# 35/35 [==============================] - 0s 653us/step - loss: 0.0291 - root_mean_squared_error: 0.1706 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1638
# Epoch 55/300
# 35/35 [==============================] - 0s 686us/step - loss: 0.0295 - root_mean_squared_error: 0.1716 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1628
# Epoch 56/300
# 35/35 [==============================] - 0s 626us/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1613
# Epoch 57/300
# 35/35 [==============================] - 0s 460us/step - loss: 0.0283 - root_mean_squared_error: 0.1681 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1631
# Epoch 58/300
# 35/35 [==============================] - 0s 748us/step - loss: 0.0286 - root_mean_squared_error: 0.1691 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1605
# Epoch 59/300
# 35/35 [==============================] - 0s 682us/step - loss: 0.0283 - root_mean_squared_error: 0.1681 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1604
# Epoch 60/300
# 35/35 [==============================] - 0s 733us/step - loss: 0.0278 - root_mean_squared_error: 0.1666 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 61/300
# 35/35 [==============================] - 0s 792us/step - loss: 0.0282 - root_mean_squared_error: 0.1681 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1589
# Epoch 62/300
# 35/35 [==============================] - 0s 743us/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1583
# Epoch 63/300
# 35/35 [==============================] - 0s 757us/step - loss: 0.0274 - root_mean_squared_error: 0.1656 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1581
# Epoch 64/300
# 35/35 [==============================] - 0s 662us/step - loss: 0.0274 - root_mean_squared_error: 0.1654 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 65/300
# 35/35 [==============================] - 0s 584us/step - loss: 0.0278 - root_mean_squared_error: 0.1667 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1570
# Epoch 66/300
# 35/35 [==============================] - 0s 433us/step - loss: 0.0268 - root_mean_squared_error: 0.1638 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1572
# Epoch 67/300
# 35/35 [==============================] - 0s 635us/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1560
# Epoch 68/300
# 35/35 [==============================] - 0s 624us/step - loss: 0.0264 - root_mean_squared_error: 0.1625 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536
# Epoch 69/300
# 35/35 [==============================] - 0s 425us/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1542
# Epoch 70/300
# 35/35 [==============================] - 0s 625us/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1534
# Epoch 71/300
# 35/35 [==============================] - 0s 451us/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1538
# Epoch 72/300
# 35/35 [==============================] - 0s 649us/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1504
# Epoch 73/300
# 35/35 [==============================] - 0s 437us/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1518
# Epoch 74/300
# 35/35 [==============================] - 0s 622us/step - loss: 0.0251 - root_mean_squared_error: 0.1586 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 75/300
# 35/35 [==============================] - 0s 463us/step - loss: 0.0256 - root_mean_squared_error: 0.1599 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1503
# Epoch 76/300
# 35/35 [==============================] - 0s 652us/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 77/300
# 35/35 [==============================] - 0s 588us/step - loss: 0.0252 - root_mean_squared_error: 0.1586 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 78/300
# 35/35 [==============================] - 0s 594us/step - loss: 0.0248 - root_mean_squared_error: 0.1574 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 79/300
# 35/35 [==============================] - 0s 422us/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 80/300
# 35/35 [==============================] - 0s 668us/step - loss: 0.0251 - root_mean_squared_error: 0.1584 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 81/300
# 35/35 [==============================] - 0s 606us/step - loss: 0.0242 - root_mean_squared_error: 0.1556 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1464
# Epoch 82/300
# 35/35 [==============================] - 0s 603us/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1455
# Epoch 83/300
# 35/35 [==============================] - 0s 823us/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1419
# Epoch 84/300
# 35/35 [==============================] - 0s 830us/step - loss: 0.0236 - root_mean_squared_error: 0.1535 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1416
# Epoch 85/300
# 35/35 [==============================] - 0s 769us/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1401
# Epoch 86/300
# 35/35 [==============================] - 0s 770us/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1379
# Epoch 87/300
# 35/35 [==============================] - 0s 567us/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 88/300
# 35/35 [==============================] - 0s 612us/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1386
# Epoch 89/300
# 35/35 [==============================] - 0s 712us/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 90/300
# 35/35 [==============================] - 0s 743us/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 91/300
# 35/35 [==============================] - 0s 757us/step - loss: 0.0222 - root_mean_squared_error: 0.1491 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1350
# Epoch 92/300
# 35/35 [==============================] - 0s 787us/step - loss: 0.0224 - root_mean_squared_error: 0.1498 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1346
# Epoch 93/300
# 35/35 [==============================] - 0s 710us/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1326
# Epoch 94/300
# 35/35 [==============================] - 0s 555us/step - loss: 0.0212 - root_mean_squared_error: 0.1457 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1339
# Epoch 95/300
# 35/35 [==============================] - 0s 791us/step - loss: 0.0217 - root_mean_squared_error: 0.1472 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1322
# Epoch 96/300
# 35/35 [==============================] - 0s 733us/step - loss: 0.0213 - root_mean_squared_error: 0.1461 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1311
# Epoch 97/300
# 35/35 [==============================] - 0s 645us/step - loss: 0.0207 - root_mean_squared_error: 0.1440 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320
# Epoch 98/300
# 35/35 [==============================] - 0s 606us/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1314
# Epoch 99/300
# 35/35 [==============================] - 0s 563us/step - loss: 0.0202 - root_mean_squared_error: 0.1420 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1342
# Epoch 100/300
# 35/35 [==============================] - 0s 496us/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# Epoch 101/300
# 35/35 [==============================] - 0s 727us/step - loss: 0.0197 - root_mean_squared_error: 0.1405 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 102/300
# 35/35 [==============================] - 0s 757us/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 103/300
# 35/35 [==============================] - 0s 693us/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302
# Epoch 104/300
# 35/35 [==============================] - 0s 720us/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1296
# Epoch 105/300
# 35/35 [==============================] - 0s 655us/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292
# Epoch 106/300
# 35/35 [==============================] - 0s 658us/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1288
# Epoch 107/300
# 35/35 [==============================] - 0s 506us/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289
# Epoch 108/300
# 35/35 [==============================] - 0s 687us/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279
# Epoch 109/300
# 35/35 [==============================] - 0s 620us/step - loss: 0.0194 - root_mean_squared_error: 0.1393 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272
# Epoch 110/300
# 35/35 [==============================] - 0s 566us/step - loss: 0.0195 - root_mean_squared_error: 0.1396 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264
# Epoch 111/300
# 35/35 [==============================] - 0s 435us/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292
# Epoch 112/300
# 35/35 [==============================] - 0s 483us/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282
# Epoch 113/300
# 35/35 [==============================] - 0s 432us/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269
# Epoch 114/300
# 35/35 [==============================] - 0s 609us/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289
# Epoch 115/300
# 35/35 [==============================] - 0s 664us/step - loss: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 116/300
# 35/35 [==============================] - 0s 670us/step - loss: 0.0178 - root_mean_squared_error: 0.1336 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 117/300
# 35/35 [==============================] - 0s 429us/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
# Epoch 118/300
# 35/35 [==============================] - 0s 507us/step - loss: 0.0187 - root_mean_squared_error: 0.1366 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269
# Epoch 119/300
# 35/35 [==============================] - 0s 652us/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1243
# Epoch 120/300
# 35/35 [==============================] - 0s 464us/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270
# Epoch 121/300
# 35/35 [==============================] - 0s 470us/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 122/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
# Epoch 123/300
# 35/35 [==============================] - 0s 470us/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 124/300
# 35/35 [==============================] - 0s 482us/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 125/300
# 35/35 [==============================] - 0s 694us/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 126/300
# 35/35 [==============================] - 0s 464us/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1247
# Epoch 127/300
# 35/35 [==============================] - 0s 468us/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1239
# Epoch 128/300
# 35/35 [==============================] - 0s 453us/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245
# Epoch 129/300
# 35/35 [==============================] - 0s 643us/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 130/300
# 35/35 [==============================] - 0s 584us/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1242
# Epoch 131/300
# 35/35 [==============================] - 0s 478us/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1228
# Epoch 132/300
# 35/35 [==============================] - 0s 465us/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 133/300
# 35/35 [==============================] - 0s 448us/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 134/300
# 35/35 [==============================] - 0s 491us/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1241
# Epoch 135/300
# 35/35 [==============================] - 0s 663us/step - loss: 0.0163 - root_mean_squared_error: 0.1279 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 136/300
# 35/35 [==============================] - 0s 464us/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 137/300
# 35/35 [==============================] - 0s 462us/step - loss: 0.0163 - root_mean_squared_error: 0.1279 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 138/300
# 35/35 [==============================] - 0s 443us/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1229
# Epoch 139/300
# 35/35 [==============================] - 0s 659us/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 140/300
# 35/35 [==============================] - 0s 495us/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223
# Epoch 141/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0162 - root_mean_squared_error: 0.1275 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1227
# Epoch 142/300
# 35/35 [==============================] - 0s 460us/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254
# Epoch 143/300
# 35/35 [==============================] - 0s 479us/step - loss: 0.0163 - root_mean_squared_error: 0.1279 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1213
# Epoch 144/300
# 35/35 [==============================] - 0s 645us/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# Epoch 145/300
# 35/35 [==============================] - 0s 462us/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 146/300
# 35/35 [==============================] - 0s 567us/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 147/300
# 35/35 [==============================] - 0s 448us/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 148/300
# 35/35 [==============================] - 0s 630us/step - loss: 0.0157 - root_mean_squared_error: 0.1255 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1202
# Epoch 149/300
# 35/35 [==============================] - 0s 460us/step - loss: 0.0156 - root_mean_squared_error: 0.1250 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 150/300
# 35/35 [==============================] - 0s 443us/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 151/300
# 35/35 [==============================] - 0s 450us/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1206
# Epoch 152/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 153/300
# 35/35 [==============================] - 0s 486us/step - loss: 0.0157 - root_mean_squared_error: 0.1255 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 154/300
# 35/35 [==============================] - 0s 692us/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 155/300
# 35/35 [==============================] - 0s 460us/step - loss: 0.0154 - root_mean_squared_error: 0.1239 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 156/300
# 35/35 [==============================] - 0s 447us/step - loss: 0.0156 - root_mean_squared_error: 0.1250 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 157/300
# 35/35 [==============================] - 0s 467us/step - loss: 0.0150 - root_mean_squared_error: 0.1223 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 158/300
# 35/35 [==============================] - 0s 500us/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 159/300
# 35/35 [==============================] - 0s 628us/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179
# Epoch 160/300
# 35/35 [==============================] - 0s 707us/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1176
# Epoch 161/300
# 35/35 [==============================] - 0s 436us/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1185
# Epoch 162/300
# 35/35 [==============================] - 0s 452us/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 163/300
# 35/35 [==============================] - 0s 669us/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1174
# Epoch 164/300
# 35/35 [==============================] - 0s 455us/step - loss: 0.0149 - root_mean_squared_error: 0.1219 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 165/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179
# Epoch 166/300
# 35/35 [==============================] - 0s 472us/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 167/300
# 35/35 [==============================] - 0s 490us/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 168/300
# 35/35 [==============================] - 0s 512us/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1189
# Epoch 169/300
# 35/35 [==============================] - 0s 669us/step - loss: 0.0149 - root_mean_squared_error: 0.1220 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1168
# Epoch 170/300
# 35/35 [==============================] - 0s 629us/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 171/300
# 35/35 [==============================] - 0s 448us/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 172/300
# 35/35 [==============================] - 0s 537us/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 173/300
# 35/35 [==============================] - 0s 628us/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 174/300
# 35/35 [==============================] - 0s 796us/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1190
# Epoch 175/300
# 35/35 [==============================] - 0s 642us/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 176/300
# 35/35 [==============================] - 0s 563us/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 177/300
# 35/35 [==============================] - 0s 654us/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1174
# Epoch 178/300
# 35/35 [==============================] - 0s 611us/step - loss: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 179/300
# 35/35 [==============================] - 0s 572us/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1168
# Epoch 180/300
# 35/35 [==============================] - 0s 623us/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 181/300
# 35/35 [==============================] - 0s 517us/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 182/300
# 35/35 [==============================] - 0s 471us/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 183/300
# 35/35 [==============================] - 0s 486us/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 184/300
# 35/35 [==============================] - 0s 676us/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 185/300
# 35/35 [==============================] - 0s 673us/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 186/300
# 35/35 [==============================] - 0s 427us/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 187/300
# 35/35 [==============================] - 0s 591us/step - loss: 0.0138 - root_mean_squared_error: 0.1175 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 188/300
# 35/35 [==============================] - 0s 499us/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 189/300
# 35/35 [==============================] - 0s 445us/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 190/300
# 35/35 [==============================] - 0s 641us/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 191/300
# 35/35 [==============================] - 0s 630us/step - loss: 0.0133 - root_mean_squared_error: 0.1151 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 192/300
# 35/35 [==============================] - 0s 437us/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 193/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 194/300
# 35/35 [==============================] - 0s 631us/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1160
# Epoch 195/300
# 35/35 [==============================] - 0s 496us/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1151
# Epoch 196/300
# 35/35 [==============================] - 0s 431us/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 197/300
# 35/35 [==============================] - 0s 676us/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 198/300
# 35/35 [==============================] - 0s 480us/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# Epoch 199/300
# 35/35 [==============================] - 0s 470us/step - loss: 0.0138 - root_mean_squared_error: 0.1174 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1166
# Epoch 200/300
# 35/35 [==============================] - 0s 537us/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 201/300
# 35/35 [==============================] - 0s 513us/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 202/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1151
# Epoch 203/300
# 35/35 [==============================] - 0s 475us/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 204/300
# 35/35 [==============================] - 0s 490us/step - loss: 0.0137 - root_mean_squared_error: 0.1168 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 205/300
# 35/35 [==============================] - 0s 445us/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 206/300
# 35/35 [==============================] - 0s 574us/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1184
# Epoch 207/300
# 35/35 [==============================] - 0s 607us/step - loss: 0.0130 - root_mean_squared_error: 0.1142 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 208/300
# 35/35 [==============================] - 0s 498us/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 209/300
# 35/35 [==============================] - 0s 450us/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 210/300
# 35/35 [==============================] - 0s 422us/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 211/300
# 35/35 [==============================] - 0s 497us/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 212/300
# 35/35 [==============================] - 0s 535us/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 213/300
# 35/35 [==============================] - 0s 502us/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 214/300
# 35/35 [==============================] - 0s 480us/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 215/300
# 35/35 [==============================] - 0s 461us/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 216/300
# 35/35 [==============================] - 0s 472us/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 217/300
# 35/35 [==============================] - 0s 650us/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 218/300
# 35/35 [==============================] - 0s 570us/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1166
# Epoch 219/300
# 35/35 [==============================] - 0s 453us/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 220/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 221/300
# 35/35 [==============================] - 0s 477us/step - loss: 0.0124 - root_mean_squared_error: 0.1111 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 222/300
# 35/35 [==============================] - 0s 462us/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 223/300
# 35/35 [==============================] - 0s 512us/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 224/300
# 35/35 [==============================] - 0s 738us/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 225/300
# 35/35 [==============================] - 0s 512us/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 226/300
# 35/35 [==============================] - 0s 680us/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 227/300
# 35/35 [==============================] - 0s 453us/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1129
# Epoch 228/300
# 35/35 [==============================] - 0s 469us/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 229/300
# 35/35 [==============================] - 0s 743us/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 230/300
# 35/35 [==============================] - 0s 467us/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 231/300
# 35/35 [==============================] - 0s 483us/step - loss: 0.0126 - root_mean_squared_error: 0.1125 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 232/300
# 35/35 [==============================] - 0s 472us/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 233/300
# 35/35 [==============================] - 0s 494us/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 234/300
# 35/35 [==============================] - 0s 461us/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 235/300
# 35/35 [==============================] - 0s 430us/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 236/300
# 35/35 [==============================] - 0s 551us/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 237/300
# 35/35 [==============================] - 0s 458us/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 238/300
# 35/35 [==============================] - 0s 628us/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 239/300
# 35/35 [==============================] - 0s 430us/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 240/300
# 35/35 [==============================] - 0s 444us/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 241/300
# 35/35 [==============================] - 0s 446us/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 242/300
# 35/35 [==============================] - 0s 422us/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 243/300
# 35/35 [==============================] - 0s 624us/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 244/300
# 35/35 [==============================] - 0s 486us/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 245/300
# 35/35 [==============================] - 0s 533us/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 246/300
# 35/35 [==============================] - 0s 497us/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 247/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 248/300
# 35/35 [==============================] - 0s 467us/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 249/300
# 35/35 [==============================] - 0s 442us/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 250/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 251/300
# 35/35 [==============================] - 0s 447us/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 252/300
# 35/35 [==============================] - 0s 921us/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 253/300
# 35/35 [==============================] - 0s 675us/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 254/300
# 35/35 [==============================] - 0s 529us/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 255/300
# 35/35 [==============================] - 0s 465us/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 256/300
# 35/35 [==============================] - 0s 436us/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 257/300
# 35/35 [==============================] - 0s 470us/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 258/300
# 35/35 [==============================] - 0s 449us/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 259/300
# 35/35 [==============================] - 0s 606us/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 260/300
# 35/35 [==============================] - 0s 481us/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 261/300
# 35/35 [==============================] - 0s 471us/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111
# Epoch 262/300
# 35/35 [==============================] - 0s 479us/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 263/300
# 35/35 [==============================] - 0s 585us/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1107
# Epoch 264/300
# 35/35 [==============================] - 0s 491us/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111
# Epoch 265/300
# 35/35 [==============================] - 0s 647us/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 266/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 267/300
# 35/35 [==============================] - 0s 604us/step - loss: 0.0111 - root_mean_squared_error: 0.1051 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 268/300
# 35/35 [==============================] - 0s 441us/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1111
# Epoch 269/300
# 35/35 [==============================] - 0s 533us/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 270/300
# 35/35 [==============================] - 0s 616us/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 271/300
# 35/35 [==============================] - 0s 553us/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 272/300
# 35/35 [==============================] - 0s 565us/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 273/300
# 35/35 [==============================] - 0s 483us/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 274/300
# 35/35 [==============================] - 0s 484us/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 275/300
# 35/35 [==============================] - 0s 443us/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 276/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 277/300
# 35/35 [==============================] - 0s 459us/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 278/300
# 35/35 [==============================] - 0s 476us/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 279/300
# 35/35 [==============================] - 0s 595us/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 280/300
# 35/35 [==============================] - 0s 483us/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 281/300
# 35/35 [==============================] - 0s 420us/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 282/300
# 35/35 [==============================] - 0s 482us/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 283/300
# 35/35 [==============================] - 0s 458us/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1116
# Epoch 284/300
# 35/35 [==============================] - 0s 455us/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 285/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 286/300
# 35/35 [==============================] - 0s 535us/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 287/300
# 35/35 [==============================] - 0s 483us/step - loss: 0.0112 - root_mean_squared_error: 0.1059 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 288/300
# 35/35 [==============================] - 0s 435us/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 289/300
# 35/35 [==============================] - 0s 453us/step - loss: 0.0112 - root_mean_squared_error: 0.1061 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 290/300
# 35/35 [==============================] - 0s 442us/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 291/300
# 35/35 [==============================] - 0s 443us/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 292/300
# 35/35 [==============================] - 0s 445us/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 293/300
# 35/35 [==============================] - 0s 436us/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 294/300
# 35/35 [==============================] - 0s 441us/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 295/300
# 35/35 [==============================] - 0s 430us/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 296/300
# 35/35 [==============================] - 0s 435us/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1111
# Epoch 297/300
# 35/35 [==============================] - 0s 560us/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 298/300
# 35/35 [==============================] - 0s 474us/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 299/300
# 35/35 [==============================] - 0s 440us/step - loss: 0.0110 - root_mean_squared_error: 0.1051 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 300/300
# 35/35 [==============================] - 0s 438us/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1102

# %%
# Show best epoch
best_epoch = np.argmin(np.array(history.history["val_loss"]))
best_epoch
# Out:
# 266

# %%
# Load model weights from best epoch
model.load_weights(checkpoint_filepath)

# Generate predictions for test set and measure test RMSE and R2
preds = model.predict(test_dataset)
evals = model.evaluate(x=test_dataset, return_dict=True)
r2 = metrics.r2_score(y_test, preds)
rmse = evals["root_mean_squared_error"]
print(f"Test RMSE: {evals}")
print(f"Test R2: {r2}")

# Plot model performance
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle("Pfizer Suzuki HTE MLP Model Performance")

# Plot loss through training
ax1.plot(history.history["loss"], "b", label="training loss")
ax1.plot(history.history["val_loss"], "g", label="validation loss")
ax1.legend()
ax1.set_ylabel("loss (MSE)")
ax1.set_xlabel("epoch")
ax1.set_title("loss curves")

# Plot predictions vs ground truth
ax2.plot(y_test, preds, "bo")
ax2.plot([0, 1], "r")
ax2.set_ylabel("predicted yield")
ax2.set_xlabel("ground truth yield")
ax2.set_title("predictions vs ground truth")
ax2.text(0.6, 0, f"test_RMSE: {round(rmse, 3)}")
ax2.text(0.6, -0.05, f"test_R2: {round(r2, 3)}")

# View performance plots
plt.show()
# Out:
# 18/18 [==============================] - 0s 306us/step
# 18/18 [==============================] - 0s 312us/step - loss: 0.0120 - root_mean_squared_error: 0.1096
# Test RMSE: {'loss': 0.012003862299025059, 'root_mean_squared_error': 0.10956213623285294}
# Test R2: 0.8502255811673648

# %%
# Show ground truth and predicted yield distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle("Ground Truth and Predicted Yield Distributions")

# Plot ground truth histogram
ax1.hist(ohe_df["yield"], bins=20, rwidth=0.93, color="navy")
ax1.set_title("ground truth")
ax1.set_xlabel("yield")
ax1.set_ylabel("frequency (count)")

# Plot predicted histogram
ax2.hist(preds, bins=20, rwidth=0.93, color="navy")
ax2.set_title("predictions")
ax2.set_xlabel("yield")
ax2.set_ylabel("frequency (count)")

# View distributions
plt.show()
