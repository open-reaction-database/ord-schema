# %% [markdown]
# ## Nanomole-scale high-throughput chemistry for the synthesis of complex molecules

# %% [markdown]
# DOI: 10.1126/science.1259203

# %% [markdown]
# Alexander Buitrago Santanilla, Erik L. Regalado, Tony Pereira, Michael Shevlin, Kevin Bateman, Louis-Charles Campeau, Jonathan Schneeweis, Simon Berritt, Zhi-Cai Shi, Philippe Nantermet, Yong Liu, Roy Helmy, Christopher J. Welch, Petr Vachal, Ian W. Davies, Tim Cernak, Spencer D. Dreher *Science* **2015**, *347*, 6217, 49-53. https://www.sciencemag.org/lookup/doi/10.1126/science.1259203

# %% [markdown]
# Submission test by Michael R. Maser, Division of Chemistry and Chemical Engineering, California Institute of Technology, Pasadena, CA. mmaser@caltech.edu

# %% [markdown]
# Import schema and helper functions

# %%
from datetime import datetime

from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2, reaction_pb2
from ord_schema.units import UnitResolver

unit_resolver = UnitResolver()

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from rdkit import Chem

# %% [markdown]
# ## Load the dataset

# %%
# Create pandas dataframe
data = pd.read_excel("1259203_Datafiles.xlsx", "Data S2- Experiment 2")

# Drop NA rows
data = data.dropna(axis=0, how="all")
data = data.dropna(axis=1, how="all")

# View dataframe
data
# Out:
#      Plate Position Electrophile Electrophile charge Nucleophile  \
# 0                A1   bromide 22    250 nL (50 nmol)    amine S1
# 1                A2   bromide 22    250 nL (50 nmol)    amine S1
# 2                A3   bromide 22    250 nL (50 nmol)    amine S1
# 3                A4   bromide 22    250 nL (50 nmol)    amine S1
# 4                A5   bromide 22    250 nL (50 nmol)    amine S1
# ...             ...          ...                 ...         ...
# 1531           AF44   bromide 22    250 nL (50 nmol)  alkyne S16
# 1532           AF45   bromide 22    250 nL (50 nmol)  alkyne S16
# 1533           AF46   bromide 22    250 nL (50 nmol)  alkyne S16
# 1534           AF47   bromide 22    250 nL (50 nmol)  alkyne S16
# 1535           AF48   bromide 22    250 nL (50 nmol)  alkyne S16
#
#      Nucleophile charge              Catalyst   Catalyst charge     Base  \
# 0     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)   DBU 24
# 1     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  MTBD 25
# 2     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTMG 26
# 3     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BEMP 27
# 4     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTTP 28
# ...                 ...                   ...               ...      ...
# 1531  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  MTBD 25
# 1532  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTMG 26
# 1533  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BEMP 27
# 1534  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTTP 28
# 1535  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  P2Et 29
#
#               Base charge            IS          ArBr          Prod  \
# 0     250 nL (200 nmol)    240134.33032  1.206548e+06  0.000000e+00
# 1     250 nL (200 nmol)    238726.34177  1.130276e+06  0.000000e+00
# 2     250 nL (200 nmol)    235018.13944  1.099909e+06  0.000000e+00
# 3     250 nL (200 nmol)    238060.17048  1.111019e+06  3.268438e+04
# 4     250 nL (200 nmol)    232566.53610  1.116529e+06  0.000000e+00
# ...                   ...           ...           ...           ...
# 1531  250 nL (200 nmol)    178233.56101  0.000000e+00  3.046576e+06
# 1532  250 nL (200 nmol)    229583.53543  2.540502e+05  2.789535e+06
# 1533  250 nL (200 nmol)    202191.15883  8.155211e+05  4.537288e+05
# 1534  250 nL (200 nmol)    201367.67531  6.228828e+05  1.109048e+06
# 1535  250 nL (200 nmol)    197245.14055  5.156465e+05  4.682473e+05
#
#                 Nu      Pd/IS
# 0     2.638835e+06   0.000000
# 1     2.474074e+06   0.000000
# 2     2.387052e+06   0.000000
# 3     2.511884e+06   0.137295
# 4     2.576513e+06   0.000000
# ...            ...        ...
# 1531           NaN  17.093165
# 1532           NaN  12.150413
# 1533           NaN   2.244058
# 1534           NaN   5.507575
# 1535           NaN   2.373936
#
# [1536 rows x 14 columns]

# %% [markdown]
# ## Identify and replace coded reaction components

# %%
# Extract unique values for each reaction component
reagent_dict = {}
component_types = ["Electrophile", "Nucleophile", "Catalyst", "Base"]

# Create dictionary for each component set with names and SMILES
for component in component_types:
    component_dict = {}
    for unique in list(data[component].unique()):
        if pd.isna(unique):
            continue
        component_dict[unique] = "placeholder"
    reagent_dict[f"{component}s"] = component_dict

# Check length of each list
for reagent, uniques in reagent_dict.items():
    print(f"{reagent} count: {len(uniques)}")

reagent_dict
# Out:
# Electrophiles count: 1
# Nucleophiles count: 16
# Catalysts count: 16
# Bases count: 6
# {'Electrophiles': {'bromide 22': 'placeholder'},
#  'Nucleophiles': {'amine S1': 'placeholder',
#   'aniline S2': 'placeholder',
#   'amide S4': 'placeholder',
#   'sulfonamide S5': 'placeholder',
#   'aminopyridine S3': 'placeholder',
#   'amidine S6': 'placeholder',
#   'tBu carbamate S7': 'placeholder',
#   'indazole S8': 'placeholder',
#   'alcohol S9': 'placeholder',
#   'phenol S10': 'placeholder',
#   'thiophenol S11': 'placeholder',
#   'phosphine S12': 'placeholder',
#   'boronate S14/water': 'placeholder',
#   'malonate S13': 'placeholder',
#   'alkene S15': 'placeholder',
#   'alkyne S16': 'placeholder'},
#  'Catalysts': {'BINAP Pd G3 30': 'placeholder',
#   'DPPF Pd G3 31': 'placeholder',
#   'XantPhos Pd G2 32': 'placeholder',
#   'tBu3P Pd G2 33': 'placeholder',
#   'PPA Pd G3 34': 'placeholder',
#   'Aphos Pd G3 35': 'placeholder',
#   'Xphos Pd G3 36': 'placeholder',
#   'RuPhos Pd G2 37': 'placeholder',
#   'DTBPF Pd G3 38': 'placeholder',
#   'J009  Pd G3 39': 'placeholder',
#   'MorDalPhos Pd G3 40': 'placeholder',
#   'BrettPhos Pd G3 41': 'placeholder',
#   'tBuXPhos Pd G3  42': 'placeholder',
#   'tBuBrettPhos Pd G3 43': 'placeholder',
#   'RockPhos Pd G3 44': 'placeholder',
#   'AdBrettPhos Pd G3 45': 'placeholder'},
#  'Bases': {'DBU 24': 'placeholder',
#   'MTBD 25': 'placeholder',
#   'BTMG 26': 'placeholder',
#   'BEMP 27': 'placeholder',
#   'BTTP 28': 'placeholder',
#   'P2Et 29': 'placeholder'}}

# %%
# Add product identifier (dependent on nucleophile)
# Create nucleophile to product mapping
product_dict = {}
reagent_dict["Products"] = {}
for i, nucleophile in enumerate(reagent_dict["Nucleophiles"].keys()):
    # Create product for each nucleophile
    product_dict[nucleophile] = f"Product_{i}"

    # Add products to reagent_dict
    reagent_dict["Products"][f"Product_{i}"] = "placeholder"

# Add product column to dataframe using map
data["Product"] = data["Nucleophile"].map(product_dict)

# Add reaction type identifier (dependent on nucleophile)
reaction_type_dict = {
    "amine S1": "Buchwald-Hartwig amination",
    "aniline S2": "Buchwald-Hartwig amination",
    "amide S4": "Buchwald-Hartwig amination",
    "sulfonamide S5": "Buchwald-Hartwig amination",
    "aminopyridine S3": "Buchwald-Hartwig amination",
    "amidine S6": "Buchwald-Hartwig amination",
    "tBu carbamate S7": "Buchwald-Hartwig amination",
    "indazole S8": "Buchwald-Hartwig amination",
    "alcohol S9": "Buchwald-Hartwig etherification",
    "phenol S10": "Buchwald-Hartwig etherification",
    "thiophenol S11": "Buchwald-Hartwig thioetherification",
    "phosphine S12": "Buchwald-Hartwig phosphination",
    "boronate S14/water": "Suzuki-Miyaura coupling",
    "malonate S13": "Pd-catalyzed enolate arylation",
    "alkene S15": "Heck coupling",
    "alkyne S16": "Sonogashira coupling",
}

# Add reaction type column to dataframe using map
data["Reaction_type"] = data["Nucleophile"].map(reaction_type_dict)

# View changes
data
# Out:
#      Plate Position Electrophile Electrophile charge Nucleophile  \
# 0                A1   bromide 22    250 nL (50 nmol)    amine S1
# 1                A2   bromide 22    250 nL (50 nmol)    amine S1
# 2                A3   bromide 22    250 nL (50 nmol)    amine S1
# 3                A4   bromide 22    250 nL (50 nmol)    amine S1
# 4                A5   bromide 22    250 nL (50 nmol)    amine S1
# ...             ...          ...                 ...         ...
# 1531           AF44   bromide 22    250 nL (50 nmol)  alkyne S16
# 1532           AF45   bromide 22    250 nL (50 nmol)  alkyne S16
# 1533           AF46   bromide 22    250 nL (50 nmol)  alkyne S16
# 1534           AF47   bromide 22    250 nL (50 nmol)  alkyne S16
# 1535           AF48   bromide 22    250 nL (50 nmol)  alkyne S16
#
#      Nucleophile charge              Catalyst   Catalyst charge     Base  \
# 0     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)   DBU 24
# 1     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  MTBD 25
# 2     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTMG 26
# 3     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BEMP 27
# 4     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTTP 28
# ...                 ...                   ...               ...      ...
# 1531  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  MTBD 25
# 1532  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTMG 26
# 1533  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BEMP 27
# 1534  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTTP 28
# 1535  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  P2Et 29
#
#               Base charge            IS          ArBr          Prod  \
# 0     250 nL (200 nmol)    240134.33032  1.206548e+06  0.000000e+00
# 1     250 nL (200 nmol)    238726.34177  1.130276e+06  0.000000e+00
# 2     250 nL (200 nmol)    235018.13944  1.099909e+06  0.000000e+00
# 3     250 nL (200 nmol)    238060.17048  1.111019e+06  3.268438e+04
# 4     250 nL (200 nmol)    232566.53610  1.116529e+06  0.000000e+00
# ...                   ...           ...           ...           ...
# 1531  250 nL (200 nmol)    178233.56101  0.000000e+00  3.046576e+06
# 1532  250 nL (200 nmol)    229583.53543  2.540502e+05  2.789535e+06
# 1533  250 nL (200 nmol)    202191.15883  8.155211e+05  4.537288e+05
# 1534  250 nL (200 nmol)    201367.67531  6.228828e+05  1.109048e+06
# 1535  250 nL (200 nmol)    197245.14055  5.156465e+05  4.682473e+05
#
#                 Nu      Pd/IS     Product               Reaction_type
# 0     2.638835e+06   0.000000   Product_0  Buchwald-Hartwig amination
# 1     2.474074e+06   0.000000   Product_0  Buchwald-Hartwig amination
# 2     2.387052e+06   0.000000   Product_0  Buchwald-Hartwig amination
# 3     2.511884e+06   0.137295   Product_0  Buchwald-Hartwig amination
# 4     2.576513e+06   0.000000   Product_0  Buchwald-Hartwig amination
# ...            ...        ...         ...                         ...
# 1531           NaN  17.093165  Product_15        Sonogashira coupling
# 1532           NaN  12.150413  Product_15        Sonogashira coupling
# 1533           NaN   2.244058  Product_15        Sonogashira coupling
# 1534           NaN   5.507575  Product_15        Sonogashira coupling
# 1535           NaN   2.373936  Product_15        Sonogashira coupling
#
# [1536 rows x 16 columns]

# %%
# See updated reagent_dict
reagent_dict
# Out:
# {'Electrophiles': {'bromide 22': 'placeholder'},
#  'Nucleophiles': {'amine S1': 'placeholder',
#   'aniline S2': 'placeholder',
#   'amide S4': 'placeholder',
#   'sulfonamide S5': 'placeholder',
#   'aminopyridine S3': 'placeholder',
#   'amidine S6': 'placeholder',
#   'tBu carbamate S7': 'placeholder',
#   'indazole S8': 'placeholder',
#   'alcohol S9': 'placeholder',
#   'phenol S10': 'placeholder',
#   'thiophenol S11': 'placeholder',
#   'phosphine S12': 'placeholder',
#   'boronate S14/water': 'placeholder',
#   'malonate S13': 'placeholder',
#   'alkene S15': 'placeholder',
#   'alkyne S16': 'placeholder'},
#  'Catalysts': {'BINAP Pd G3 30': 'placeholder',
#   'DPPF Pd G3 31': 'placeholder',
#   'XantPhos Pd G2 32': 'placeholder',
#   'tBu3P Pd G2 33': 'placeholder',
#   'PPA Pd G3 34': 'placeholder',
#   'Aphos Pd G3 35': 'placeholder',
#   'Xphos Pd G3 36': 'placeholder',
#   'RuPhos Pd G2 37': 'placeholder',
#   'DTBPF Pd G3 38': 'placeholder',
#   'J009  Pd G3 39': 'placeholder',
#   'MorDalPhos Pd G3 40': 'placeholder',
#   'BrettPhos Pd G3 41': 'placeholder',
#   'tBuXPhos Pd G3  42': 'placeholder',
#   'tBuBrettPhos Pd G3 43': 'placeholder',
#   'RockPhos Pd G3 44': 'placeholder',
#   'AdBrettPhos Pd G3 45': 'placeholder'},
#  'Bases': {'DBU 24': 'placeholder',
#   'MTBD 25': 'placeholder',
#   'BTMG 26': 'placeholder',
#   'BEMP 27': 'placeholder',
#   'BTTP 28': 'placeholder',
#   'P2Et 29': 'placeholder'},
#  'Products': {'Product_0': 'placeholder',
#   'Product_1': 'placeholder',
#   'Product_2': 'placeholder',
#   'Product_3': 'placeholder',
#   'Product_4': 'placeholder',
#   'Product_5': 'placeholder',
#   'Product_6': 'placeholder',
#   'Product_7': 'placeholder',
#   'Product_8': 'placeholder',
#   'Product_9': 'placeholder',
#   'Product_10': 'placeholder',
#   'Product_11': 'placeholder',
#   'Product_12': 'placeholder',
#   'Product_13': 'placeholder',
#   'Product_14': 'placeholder',
#   'Product_15': 'placeholder'}}

# %% [markdown]
# ## Add SMILES representations for dataset molecules

# %% [markdown]
# ### SMILES testing for metal complexes
# RDKit SMILES parsing fails for ChemDraw-generated SMILES of plainly drawn metal complexes due to valence rules on N atoms. Using dative bonds in ChemDraw fixes this problem but generates charged species to satisfy valence rules. ChemDraw's syntax for ferrocene complexes leads to RDKit parsing failures. PubChem "canonical" SMILES for metal complexes treats each substructure as a separate component (e.g., metals, ligands, ions), leading to a salt-like representation of the compounds. Ultimately found that using ChemDraw to generate SMILES with neutral single bonds to ligands, generating dative '<-' bonds programmatically (see below), and drawing ferrocenes explicitly as cyclopentadienyl-anion-sandwiched Fe atoms led to the most reasonable representations. <br>
# See the discussion here for the shortcomings of SMILES in representing metallocenes: https://chemistry.stackexchange.com/questions/20486/what-would-be-smiles-notation-for-a-compound-with-delocalized-bonding<br>
# Structures are drawn in ./Santanilla_component_smiles.cdx and Chemdraw generated SMILES (non-canonical) are copied to ./experiment_2_molecules.csv

# %% [markdown]
# ### Add SMILES to dataset
# SMILES are imported in non-canonical format as generated by ChemDraw. SMILES are canonicalized by RDKit below before including in dataset

# %%
# Load SMILES info from Chemdraw .csv
smiles_data = pd.read_csv("experiment_2_molecules.csv")
smiles_data
# Out:
#              dataset_name                               non_canonical_smiles
# 0              bromide 22                                      BrC1=CN=CC=C1
# 1                amine S1                                 CC(N)CCC1=CC=CC=C1
# 2              aniline S2                                       NC1=CC=CC=C1
# 3                amide S4                                  NC(C1=CC=CC=C1)=O
# 4          sulfonamide S5                              NS(C1=CC=CC=C1)(=O)=O
# 5        aminopyridine S3                          NC1=NC=C(C2=CC=CC=C2)C=C1
# 6              amidine S6                                 NC(CC1=CC=CC=C1)=N
# 7        tBu carbamate S7                                    NC(OC(C)(C)C)=O
# 8             indazole S8                                  C12=CC=CC=C1NN=C2
# 9              alcohol S9                                    OCCCC1=CC=CC=C1
# 10             phenol S10                                       OC1=CC=CC=C1
# 11         thiophenol S11                                       SC1=CC=CC=C1
# 12          phosphine S12                          C1(PC2=CC=CC=C2)=CC=CC=C1
# 13     boronate S14/water         CC(C(C)(C)O1)(C)OB1C(C=N2)=CN2CC3=CC=CC=C3
# 14           malonate S13                                  O=C(CC(OCC)=O)OCC
# 15             alkene S15                           O=C(OCC)/C=C/C1=CC=CC=C1
# 16             alkyne S16                               CCCCC1=CC=C(C#C)C=C1
# 17         BINAP Pd G3 30  CS(O[Pd]1([P](C2=CC=CC=C2)(C3=CC=CC=C3)C4=C(C5...
# 18          DPPF Pd G3 31  CS(O[Pd]1([P](C2=CC=CC=C2)(C3=CC=CC=C3)C4=CC=C...
# 19      XantPhos Pd G2 32  Cl[Pd]1([P](C2=CC=CC=C2)(C3=CC=CC=C3)C4=C(OC(C...
# 20         tBu3P Pd G2 33  Cl[Pd]1([P](C(C)(C)C)(C(C)(C)C)C(C)(C)C)C2=CC=...
# 21           PPA Pd G3 34  CC(OC1(C)O2)(C3)OC(C)(C1)[P]([Pd]4(OS(C)(=O)=O...
# 22         Aphos Pd G3 35  NC(C=C1)=CC=C1[P]([Pd]2(OS(C)(=O)=O)C3=CC=CC=C...
# 23         Xphos Pd G3 36  CS(O[Pd]1([P](C2CCCCC2)(C3CCCCC3)C4=C(C5=C(C(C...
# 24        RuPhos Pd G2 37  Cl[Pd]1([P](C2CCCCC2)(C3CCCCC3)C4=C(C5=C(OC(C)...
# 25         DTBPF Pd G3 38  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=CC=CC2[Fe]...
# 26         J009  Pd G3 39  CC(P(C(C)(C)C)C(C)(C)C)C1=C(C([Fe]C2C=CC=C2)C=...
# 27    MorDalPhos Pd G3 40  CS(O[Pd]1([P](C23C[C@@H](C[C@H]4C3)C[C@@H](C4)...
# 28     BrettPhos Pd G3 41  CS(O[Pd]1([P](C2CCCCC2)(C3CCCCC3)C4=C(C5=C(C(C...
# 29     tBuXPhos Pd G3  42  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=C(C3=C(C(C...
# 30  tBuBrettPhos Pd G3 43  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=C(C3=C(C(C...
# 31      RockPhos Pd G3 44  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=C(C3=C(C(C...
# 32   AdBrettPhos Pd G3 45  CS(O[Pd]1([P](C23C[C@@H](C[C@H]4C3)C[C@@H](C4)...
# 33                 DBU 24                                   C12=NCCCN1CCCCC2
# 34                MTBD 25                                   CN1CCCN2C1=NCCC2
# 35                BTMG 26                          CN(C)/C(N(C)C)=N\C(C)(C)C
# 36                BEMP 27                  CN1P(N(CC)CC)(N(C)CCC1)=NC(C)(C)C
# 37                BTTP 28               CC(N=P(N1CCCC1)(N2CCCC2)N3CCCC3)(C)C
# 38                P2Et 29          CN(C)P(N(C)C)(N(C)C)=NP(N(C)C)(N(C)C)=NCC
# 39              Product_0                      CC(NC1=CN=CC=C1)CCC2=CC=CC=C2
# 40              Product_1                          C1(NC2=CN=CC=C2)=CC=CC=C1
# 41              Product_2                       O=C(NC1=CN=CC=C1)C2=CC=CC=C2
# 42              Product_3                   O=S(C1=CC=CC=C1)(NC2=CN=CC=C2)=O
# 43              Product_4             C1(C2=CC=CC=C2)=CN=C(NC3=CN=CC=C3)C=C1
# 44              Product_5                      N=C(NC1=CN=CC=C1)CC2=CC=CC=C2
# 45              Product_6                         O=C(NC1=CN=CC=C1)OC(C)(C)C
# 46              Product_7                     C12=CC=CC=C1N(C3=CN=CC=C3)N=C2
# 47              Product_8                       C1(CCCOC2=CN=CC=C2)=CC=CC=C1
# 48              Product_9                          C1(OC2=CN=CC=C2)=CC=CC=C1
# 49             Product_10                          C1(SC2=CN=CC=C2)=CC=CC=C1
# 50             Product_11             C1(P(C2=CN=CC=C2)C3=CC=CC=C3)=CC=CC=C1
# 51             Product_12               C1(CN2C=C(C3=CN=CC=C3)C=N2)=CC=CC=C1
# 52             Product_13                     O=C(C(C1=CN=CC=C1)C(OCC)=O)OCC
# 53             Product_14              O=C(OCC)/C=C(C1=CC=CC=C1)/C2=CC=CN=C2
# 54             Product_15                    CCCCC1=CC=C(C#CC2=CN=CC=C2)C=C1
# 55                   DMSO                                            CS(C)=O
# 56            acetic acid                                            CC(O)=O
# 57               biphenyl                           C1(C2=CC=CC=C2)=CC=CC=C1

# %% [markdown]
# ### Handle dative bonds in metal complexes
# From Greg Landrum at RDKit: https://www.rdkit.org/docs/Cookbook.html#organometallics-with-dative-bonds<br>
# Added phosphorous to dative atom list in set_dative_bonds and added new function has_transition_metal

# %%
def is_transition_metal(atom: Chem.Atom) -> bool:
    """
    Determines if an atom is a transition metal

    ARGUMENTS:
        (rdkit.Chem.rdchem.Atom)atom: atom object for the atom in question

    RETURNS:
        (bool): boolean describing whether atomic number of atom is in
                one of transition-metal ranges
    """
    n = atom.GetAtomicNum()
    return (n >= 22 and n <= 29) or (n >= 40 and n <= 47) or (n >= 72 and n <= 79)


def has_transition_metal(mol: Chem.Mol) -> bool:
    """
    Determines if a molecule has a transition metal

    ARGUMENTS:
        (rdkit.Chem.rdchem.Mol)mol: mol object for the molecule in question

    RETURNS:
        (bool): boolean describing whether molecule has an atom with
                atomic number in the transition-metal ranges
    """
    return any(is_transition_metal(atom) for atom in mol.GetAtoms())


def set_dative_bonds(
    mol: Chem.Mol, fromAtoms: tuple[int, ...] = (7, 8, 15)
) -> Chem.Mol:
    """
    Convert metal-ligand bonds to dative. Replaces some single bonds between
    metals and atoms with atomic numbers in fromAtoms with dative bonds.
    The replacement is only done if the atom has "too many" bonds

    ARGUMENTS:
        (rdkit.Chem.rdchem.Mol)mol: molecule to convert dative bonds
        (tuple)fromAtoms: atomic numbers corresponding to metal-bound atoms
                            that should have bonds converted to dative

    RETURNS:
        (rdkit.Chem.rdchem.Mol)rwmol: the modified molecule

    """
    pt = Chem.GetPeriodicTable()
    rwmol = Chem.RWMol(mol)
    rwmol.UpdatePropertyCache(strict=False)
    metals = [at for at in rwmol.GetAtoms() if is_transition_metal(at)]
    for metal in metals:
        for nbr in metal.GetNeighbors():
            if (
                nbr.GetAtomicNum() in fromAtoms
                and nbr.GetExplicitValence() > pt.GetDefaultValence(nbr.GetAtomicNum())
                and rwmol.GetBondBetweenAtoms(
                    nbr.GetIdx(), metal.GetIdx()
                ).GetBondType()
                == Chem.BondType.SINGLE
            ):
                rwmol.RemoveBond(nbr.GetIdx(), metal.GetIdx())
                rwmol.AddBond(nbr.GetIdx(), metal.GetIdx(), Chem.BondType.DATIVE)
    return rwmol

# %%
# Canonicalize component SMILES
canonical_smiles = []
for smiles in smiles_data["non_canonical_smiles"]:
    mol = Chem.MolFromSmiles(smiles, sanitize=False)
    if has_transition_metal(mol):
        mol = set_dative_bonds(mol)

    else:
        mol = Chem.MolFromSmiles(smiles)

    if mol is not None:
        can_smiles = Chem.MolToSmiles(mol)
        canonical_smiles.append(can_smiles)
    else:
        raise ValueError(
            f"Error, unable to canonicalize the following smiles: {smiles}, "
            f"non-canonical smiles added to final list instead"
        )
        canonical_smiles.append(smiles)

# Add canonical SMILES to SMILES dataframe
smiles_data["canonical_smiles"] = canonical_smiles

# View new SMILES dataframe
smiles_data
# Out:
#              dataset_name                               non_canonical_smiles  \
# 0              bromide 22                                      BrC1=CN=CC=C1
# 1                amine S1                                 CC(N)CCC1=CC=CC=C1
# 2              aniline S2                                       NC1=CC=CC=C1
# 3                amide S4                                  NC(C1=CC=CC=C1)=O
# 4          sulfonamide S5                              NS(C1=CC=CC=C1)(=O)=O
# 5        aminopyridine S3                          NC1=NC=C(C2=CC=CC=C2)C=C1
# 6              amidine S6                                 NC(CC1=CC=CC=C1)=N
# 7        tBu carbamate S7                                    NC(OC(C)(C)C)=O
# 8             indazole S8                                  C12=CC=CC=C1NN=C2
# 9              alcohol S9                                    OCCCC1=CC=CC=C1
# 10             phenol S10                                       OC1=CC=CC=C1
# 11         thiophenol S11                                       SC1=CC=CC=C1
# 12          phosphine S12                          C1(PC2=CC=CC=C2)=CC=CC=C1
# 13     boronate S14/water         CC(C(C)(C)O1)(C)OB1C(C=N2)=CN2CC3=CC=CC=C3
# 14           malonate S13                                  O=C(CC(OCC)=O)OCC
# 15             alkene S15                           O=C(OCC)/C=C/C1=CC=CC=C1
# 16             alkyne S16                               CCCCC1=CC=C(C#C)C=C1
# 17         BINAP Pd G3 30  CS(O[Pd]1([P](C2=CC=CC=C2)(C3=CC=CC=C3)C4=C(C5...
# 18          DPPF Pd G3 31  CS(O[Pd]1([P](C2=CC=CC=C2)(C3=CC=CC=C3)C4=CC=C...
# 19      XantPhos Pd G2 32  Cl[Pd]1([P](C2=CC=CC=C2)(C3=CC=CC=C3)C4=C(OC(C...
# 20         tBu3P Pd G2 33  Cl[Pd]1([P](C(C)(C)C)(C(C)(C)C)C(C)(C)C)C2=CC=...
# 21           PPA Pd G3 34  CC(OC1(C)O2)(C3)OC(C)(C1)[P]([Pd]4(OS(C)(=O)=O...
# 22         Aphos Pd G3 35  NC(C=C1)=CC=C1[P]([Pd]2(OS(C)(=O)=O)C3=CC=CC=C...
# 23         Xphos Pd G3 36  CS(O[Pd]1([P](C2CCCCC2)(C3CCCCC3)C4=C(C5=C(C(C...
# 24        RuPhos Pd G2 37  Cl[Pd]1([P](C2CCCCC2)(C3CCCCC3)C4=C(C5=C(OC(C)...
# 25         DTBPF Pd G3 38  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=CC=CC2[Fe]...
# 26         J009  Pd G3 39  CC(P(C(C)(C)C)C(C)(C)C)C1=C(C([Fe]C2C=CC=C2)C=...
# 27    MorDalPhos Pd G3 40  CS(O[Pd]1([P](C23C[C@@H](C[C@H]4C3)C[C@@H](C4)...
# 28     BrettPhos Pd G3 41  CS(O[Pd]1([P](C2CCCCC2)(C3CCCCC3)C4=C(C5=C(C(C...
# 29     tBuXPhos Pd G3  42  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=C(C3=C(C(C...
# 30  tBuBrettPhos Pd G3 43  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=C(C3=C(C(C...
# 31      RockPhos Pd G3 44  CS(O[Pd]1([P](C(C)(C)C)(C(C)(C)C)C2=C(C3=C(C(C...
# 32   AdBrettPhos Pd G3 45  CS(O[Pd]1([P](C23C[C@@H](C[C@H]4C3)C[C@@H](C4)...
# 33                 DBU 24                                   C12=NCCCN1CCCCC2
# 34                MTBD 25                                   CN1CCCN2C1=NCCC2
# 35                BTMG 26                          CN(C)/C(N(C)C)=N\C(C)(C)C
# 36                BEMP 27                  CN1P(N(CC)CC)(N(C)CCC1)=NC(C)(C)C
# 37                BTTP 28               CC(N=P(N1CCCC1)(N2CCCC2)N3CCCC3)(C)C
# 38                P2Et 29          CN(C)P(N(C)C)(N(C)C)=NP(N(C)C)(N(C)C)=NCC
# 39              Product_0                      CC(NC1=CN=CC=C1)CCC2=CC=CC=C2
# 40              Product_1                          C1(NC2=CN=CC=C2)=CC=CC=C1
# 41              Product_2                       O=C(NC1=CN=CC=C1)C2=CC=CC=C2
# 42              Product_3                   O=S(C1=CC=CC=C1)(NC2=CN=CC=C2)=O
# 43              Product_4             C1(C2=CC=CC=C2)=CN=C(NC3=CN=CC=C3)C=C1
# 44              Product_5                      N=C(NC1=CN=CC=C1)CC2=CC=CC=C2
# 45              Product_6                         O=C(NC1=CN=CC=C1)OC(C)(C)C
# 46              Product_7                     C12=CC=CC=C1N(C3=CN=CC=C3)N=C2
# 47              Product_8                       C1(CCCOC2=CN=CC=C2)=CC=CC=C1
# 48              Product_9                          C1(OC2=CN=CC=C2)=CC=CC=C1
# 49             Product_10                          C1(SC2=CN=CC=C2)=CC=CC=C1
# 50             Product_11             C1(P(C2=CN=CC=C2)C3=CC=CC=C3)=CC=CC=C1
# 51             Product_12               C1(CN2C=C(C3=CN=CC=C3)C=N2)=CC=CC=C1
# 52             Product_13                     O=C(C(C1=CN=CC=C1)C(OCC)=O)OCC
# 53             Product_14              O=C(OCC)/C=C(C1=CC=CC=C1)/C2=CC=CN=C2
# 54             Product_15                    CCCCC1=CC=C(C#CC2=CN=CC=C2)C=C1
# 55                   DMSO                                            CS(C)=O
# 56            acetic acid                                            CC(O)=O
# 57               biphenyl                           C1(C2=CC=CC=C2)=CC=CC=C1
#
#                                      canonical_smiles
# 0                                          Brc1cccnc1
# 1                                     CC(N)CCc1ccccc1
# 2                                           Nc1ccccc1
# 3                                      NC(=O)c1ccccc1
# 4                                  NS(=O)(=O)c1ccccc1
# 5                                Nc1ccc(-c2ccccc2)cn1
# 6                                     N=C(N)Cc1ccccc1
# 7                                     CC(C)(C)OC(N)=O
# 8                                    c1ccc2[nH]ncc2c1
# 9                                        OCCCc1ccccc1
# 10                                          Oc1ccccc1
# 11                                          Sc1ccccc1
# 12                                c1ccc(Pc2ccccc2)cc1
# 13                CC1(C)OB(c2cnn(Cc3ccccc3)c2)OC1(C)C
# 14                                  CCOC(=O)CC(=O)OCC
# 15                              CCOC(=O)/C=C/c1ccccc1
# 16                                  C#Cc1ccc(CCCC)cc1
# 17  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 18  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 19  CC1(C)C2=CC=CC(P(C3=CC=CC=C3)(C3=CC=CC=C3)->[P...
# 20  CC(C)(C)P(C(C)(C)C)(C(C)(C)C)->[Pd]1(Cl)<-NC2=...
# 21  CC12CC3(C)OC(C)(CC(C)(O1)P3(C1=CC=CC=C1)->[Pd]...
# 22  CC(C)(C)P(C1=CC=C(N)C=C1)(C(C)(C)C)->[Pd]1(OS(...
# 23  CC(C)C1=CC(C(C)C)=C(C2=C(P(C3CCCCC3)(C3CCCCC3)...
# 24  CC(C)OC1=CC=CC(OC(C)C)=C1C1=C(P(C2CCCCC2)(C2CC...
# 25  CC(C)(C)P(C1=CC=CC1[Fe]C1C=CC=C1P(C(C)(C)C)(C(...
# 26  CC(C1=C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(OS(C)(=O)...
# 27  CS(=O)(=O)O[Pd]1(<-P(C2=C(N3CCOCC3)C=CC=C2)(C2...
# 28  COC1=CC=C(OC)C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(OS...
# 29  CC(C)C1=CC(C(C)C)=C(C2=C(P(C(C)(C)C)(C(C)(C)C)...
# 30  COC1=CC=C(OC)C(P(C(C)(C)C)(C(C)(C)C)->[Pd]2(OS...
# 31  COC1=CC=C(C)C(C2=C(C(C)C)C=C(C(C)C)C=C2C(C)C)=...
# 32  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 33                                   C1CCC2=NCCCN2CC1
# 34                                   CN1CCCN2CCCN=C12
# 35                            CN(C)C(=NC(C)(C)C)N(C)C
# 36                    CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C
# 37               CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1
# 38          CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C
# 39                            CC(CCc1ccccc1)Nc1cccnc1
# 40                                c1ccc(Nc2cccnc2)cc1
# 41                             O=C(Nc1cccnc1)c1ccccc1
# 42                         O=S(=O)(Nc1cccnc1)c1ccccc1
# 43                     c1ccc(-c2ccc(Nc3cccnc3)nc2)cc1
# 44                            N=C(Cc1ccccc1)Nc1cccnc1
# 45                            CC(C)(C)OC(=O)Nc1cccnc1
# 46                           c1cncc(-n2ncc3ccccc32)c1
# 47                             c1ccc(CCCOc2cccnc2)cc1
# 48                                c1ccc(Oc2cccnc2)cc1
# 49                                c1ccc(Sc2cccnc2)cc1
# 50                      c1ccc(P(c2ccccc2)c2cccnc2)cc1
# 51                      c1ccc(Cn2cc(-c3cccnc3)cn2)cc1
# 52                        CCOC(=O)C(C(=O)OCC)c1cccnc1
# 53                    CCOC(=O)/C=C(\c1ccccc1)c1cccnc1
# 54                          CCCCc1ccc(C#Cc2cccnc2)cc1
# 55                                            CS(C)=O
# 56                                            CC(=O)O
# 57                                c1ccc(-c2ccccc2)cc1

# %% [markdown]
# ### Check dative bonds drawn on metal complexes

# %%
# Create list of mol objects
catalyst_mols = [
    Chem.MolFromSmiles(smiles) for smiles in smiles_data.loc[17:32, "canonical_smiles"]
]
for mol in catalyst_mols:
    Chem.rdDepictor.Compute2DCoords(mol)

# Create grid drawing
# Can see neutral N, P, and Pd atoms with dative bonds from N and P to Pd
Chem.Draw.MolsToGridImage(
    catalyst_mols, molsPerRow=8, useSVG=True, subImgSize=(400, 400)
)

# %% [markdown]
# ## Add canonicalized SMILES to reagent_dict and create compound to SMILES mapping

# %%
# View current dictionary
reagent_dict
# Out:
# {'Electrophiles': {'bromide 22': 'placeholder'},
#  'Nucleophiles': {'amine S1': 'placeholder',
#   'aniline S2': 'placeholder',
#   'amide S4': 'placeholder',
#   'sulfonamide S5': 'placeholder',
#   'aminopyridine S3': 'placeholder',
#   'amidine S6': 'placeholder',
#   'tBu carbamate S7': 'placeholder',
#   'indazole S8': 'placeholder',
#   'alcohol S9': 'placeholder',
#   'phenol S10': 'placeholder',
#   'thiophenol S11': 'placeholder',
#   'phosphine S12': 'placeholder',
#   'boronate S14/water': 'placeholder',
#   'malonate S13': 'placeholder',
#   'alkene S15': 'placeholder',
#   'alkyne S16': 'placeholder'},
#  'Catalysts': {'BINAP Pd G3 30': 'placeholder',
#   'DPPF Pd G3 31': 'placeholder',
#   'XantPhos Pd G2 32': 'placeholder',
#   'tBu3P Pd G2 33': 'placeholder',
#   'PPA Pd G3 34': 'placeholder',
#   'Aphos Pd G3 35': 'placeholder',
#   'Xphos Pd G3 36': 'placeholder',
#   'RuPhos Pd G2 37': 'placeholder',
#   'DTBPF Pd G3 38': 'placeholder',
#   'J009  Pd G3 39': 'placeholder',
#   'MorDalPhos Pd G3 40': 'placeholder',
#   'BrettPhos Pd G3 41': 'placeholder',
#   'tBuXPhos Pd G3  42': 'placeholder',
#   'tBuBrettPhos Pd G3 43': 'placeholder',
#   'RockPhos Pd G3 44': 'placeholder',
#   'AdBrettPhos Pd G3 45': 'placeholder'},
#  'Bases': {'DBU 24': 'placeholder',
#   'MTBD 25': 'placeholder',
#   'BTMG 26': 'placeholder',
#   'BEMP 27': 'placeholder',
#   'BTTP 28': 'placeholder',
#   'P2Et 29': 'placeholder'},
#  'Products': {'Product_0': 'placeholder',
#   'Product_1': 'placeholder',
#   'Product_2': 'placeholder',
#   'Product_3': 'placeholder',
#   'Product_4': 'placeholder',
#   'Product_5': 'placeholder',
#   'Product_6': 'placeholder',
#   'Product_7': 'placeholder',
#   'Product_8': 'placeholder',
#   'Product_9': 'placeholder',
#   'Product_10': 'placeholder',
#   'Product_11': 'placeholder',
#   'Product_12': 'placeholder',
#   'Product_13': 'placeholder',
#   'Product_14': 'placeholder',
#   'Product_15': 'placeholder'}}

# %%
# Fill in placeholder SMILES in reagent_dict with canonical SMILES
# and create mapping from dataset name to canonical SMILES
smiles_map = {}
for subclass, components in reagent_dict.items():
    for name in components:
        # Two names are not caught due to extra spaces
        if name == "J009  Pd G3 39":
            can_smiles = smiles_data.loc[26, "canonical_smiles"]
        elif name == "tBuXPhos Pd G3  42":
            can_smiles = smiles_data.loc[29, "canonical_smiles"]
        else:
            values = smiles_data.loc[
                smiles_data["dataset_name"] == name, "canonical_smiles"
            ].to_numpy()
            if not values:
                raise ValueError((reagent_dict, subclass, components, name))
            can_smiles = values[0]
        smiles_map[name] = can_smiles
        components[name] = can_smiles

# View completed dictionary
reagent_dict
# Out:
# {'Electrophiles': {'bromide 22': 'Brc1cccnc1'},
#  'Nucleophiles': {'amine S1': 'CC(N)CCc1ccccc1',
#   'aniline S2': 'Nc1ccccc1',
#   'amide S4': 'NC(=O)c1ccccc1',
#   'sulfonamide S5': 'NS(=O)(=O)c1ccccc1',
#   'aminopyridine S3': 'Nc1ccc(-c2ccccc2)cn1',
#   'amidine S6': 'N=C(N)Cc1ccccc1',
#   'tBu carbamate S7': 'CC(C)(C)OC(N)=O',
#   'indazole S8': 'c1ccc2[nH]ncc2c1',
#   'alcohol S9': 'OCCCc1ccccc1',
#   'phenol S10': 'Oc1ccccc1',
#   'thiophenol S11': 'Sc1ccccc1',
#   'phosphine S12': 'c1ccc(Pc2ccccc2)cc1',
#   'boronate S14/water': 'CC1(C)OB(c2cnn(Cc3ccccc3)c2)OC1(C)C',
#   'malonate S13': 'CCOC(=O)CC(=O)OCC',
#   'alkene S15': 'CCOC(=O)/C=C/c1ccccc1',
#   'alkyne S16': 'C#Cc1ccc(CCCC)cc1'},
#  'Catalysts': {'BINAP Pd G3 30': 'CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)C2=C(C3=C(P(C4=CC=CC=C4)C4=CC=CC=C4)C=CC4=C3C=CC=C4)C3=C(C=CC=C3)C=C2)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#   'DPPF Pd G3 31': 'CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)C2=CC=CC2[Fe]C2C=CC=C2P(C2=CC=CC=C2)C2=CC=CC=C2)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#   'XantPhos Pd G2 32': 'CC1(C)C2=CC=CC(P(C3=CC=CC=C3)(C3=CC=CC=C3)->[Pd]3(Cl)<-NC4=C(C=CC=C4)C4=CC=CC=C43)=C2OC2=C1C=CC=C2P(C1=CC=CC=C1)C1=CC=CC=C1',
#   'tBu3P Pd G2 33': 'CC(C)(C)P(C(C)(C)C)(C(C)(C)C)->[Pd]1(Cl)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#   'PPA Pd G3 34': 'CC12CC3(C)OC(C)(CC(C)(O1)P3(C1=CC=CC=C1)->[Pd]1(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C31)O2',
#   'Aphos Pd G3 35': 'CC(C)(C)P(C1=CC=C(N)C=C1)(C(C)(C)C)->[Pd]1(OS(C)(=O)=O)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#   'Xphos Pd G3 36': 'CC(C)C1=CC(C(C)C)=C(C2=C(P(C3CCCCC3)(C3CCCCC3)->[Pd]3(OS(C)(=O)=O)<-NC4=C(C=CC=C4)C4=CC=CC=C43)C=CC=C2)C(C(C)C)=C1',
#   'RuPhos Pd G2 37': 'CC(C)OC1=CC=CC(OC(C)C)=C1C1=C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(Cl)<-NC3=C(C=CC=C3)C3=CC=CC=C32)C=CC=C1',
#   'DTBPF Pd G3 38': 'CC(C)(C)P(C1=CC=CC1[Fe]C1C=CC=C1P(C(C)(C)C)(C(C)(C)C)->[Pd]1(OS(C)(=O)=O)<-NC2=C(C=CC=C2)C2=CC=CC=C21)C(C)(C)C',
#   'J009  Pd G3 39': 'CC(C1=C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)C([Fe]C2C=CC=C2)C=C1)P(C(C)(C)C)C(C)(C)C',
#   'MorDalPhos Pd G3 40': 'CS(=O)(=O)O[Pd]1(<-P(C2=C(N3CCOCC3)C=CC=C2)(C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#   'BrettPhos Pd G3 41': 'COC1=CC=C(OC)C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)=C1C1=C(C(C)C)C=C(C(C)C)C=C1C(C)C',
#   'tBuXPhos Pd G3  42': 'CC(C)C1=CC(C(C)C)=C(C2=C(P(C(C)(C)C)(C(C)(C)C)->[Pd]3(OS(C)(=O)=O)<-NC4=C(C=CC=C4)C4=CC=CC=C43)C=CC=C2)C(C(C)C)=C1',
#   'tBuBrettPhos Pd G3 43': 'COC1=CC=C(OC)C(P(C(C)(C)C)(C(C)(C)C)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)=C1C1=C(C(C)C)C=C(C(C)C)C=C1C(C)C',
#   'RockPhos Pd G3 44': 'COC1=CC=C(C)C(C2=C(C(C)C)C=C(C(C)C)C=C2C(C)C)=C1P(C(C)(C)C)(C(C)(C)C)->[Pd]1(OS(C)(=O)=O)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#   'AdBrettPhos Pd G3 45': 'COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)(C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)=C1C1=C(C(C)C)C=C(C(C)C)C=C1C(C)C'},
#  'Bases': {'DBU 24': 'C1CCC2=NCCCN2CC1',
#   'MTBD 25': 'CN1CCCN2CCCN=C12',
#   'BTMG 26': 'CN(C)C(=NC(C)(C)C)N(C)C',
#   'BEMP 27': 'CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C',
#   'BTTP 28': 'CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1',
#   'P2Et 29': 'CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C'},
#  'Products': {'Product_0': 'CC(CCc1ccccc1)Nc1cccnc1',
#   'Product_1': 'c1ccc(Nc2cccnc2)cc1',
#   'Product_2': 'O=C(Nc1cccnc1)c1ccccc1',
#   'Product_3': 'O=S(=O)(Nc1cccnc1)c1ccccc1',
#   'Product_4': 'c1ccc(-c2ccc(Nc3cccnc3)nc2)cc1',
#   'Product_5': 'N=C(Cc1ccccc1)Nc1cccnc1',
#   'Product_6': 'CC(C)(C)OC(=O)Nc1cccnc1',
#   'Product_7': 'c1cncc(-n2ncc3ccccc32)c1',
#   'Product_8': 'c1ccc(CCCOc2cccnc2)cc1',
#   'Product_9': 'c1ccc(Oc2cccnc2)cc1',
#   'Product_10': 'c1ccc(Sc2cccnc2)cc1',
#   'Product_11': 'c1ccc(P(c2ccccc2)c2cccnc2)cc1',
#   'Product_12': 'c1ccc(Cn2cc(-c3cccnc3)cn2)cc1',
#   'Product_13': 'CCOC(=O)C(C(=O)OCC)c1cccnc1',
#   'Product_14': 'CCOC(=O)/C=C(\\c1ccccc1)c1cccnc1',
#   'Product_15': 'CCCCc1ccc(C#Cc2cccnc2)cc1'}}

# %%
# View SMILES mapping
smiles_map
# Out:
# {'bromide 22': 'Brc1cccnc1',
#  'amine S1': 'CC(N)CCc1ccccc1',
#  'aniline S2': 'Nc1ccccc1',
#  'amide S4': 'NC(=O)c1ccccc1',
#  'sulfonamide S5': 'NS(=O)(=O)c1ccccc1',
#  'aminopyridine S3': 'Nc1ccc(-c2ccccc2)cn1',
#  'amidine S6': 'N=C(N)Cc1ccccc1',
#  'tBu carbamate S7': 'CC(C)(C)OC(N)=O',
#  'indazole S8': 'c1ccc2[nH]ncc2c1',
#  'alcohol S9': 'OCCCc1ccccc1',
#  'phenol S10': 'Oc1ccccc1',
#  'thiophenol S11': 'Sc1ccccc1',
#  'phosphine S12': 'c1ccc(Pc2ccccc2)cc1',
#  'boronate S14/water': 'CC1(C)OB(c2cnn(Cc3ccccc3)c2)OC1(C)C',
#  'malonate S13': 'CCOC(=O)CC(=O)OCC',
#  'alkene S15': 'CCOC(=O)/C=C/c1ccccc1',
#  'alkyne S16': 'C#Cc1ccc(CCCC)cc1',
#  'BINAP Pd G3 30': 'CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)C2=C(C3=C(P(C4=CC=CC=C4)C4=CC=CC=C4)C=CC4=C3C=CC=C4)C3=C(C=CC=C3)C=C2)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#  'DPPF Pd G3 31': 'CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)C2=CC=CC2[Fe]C2C=CC=C2P(C2=CC=CC=C2)C2=CC=CC=C2)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#  'XantPhos Pd G2 32': 'CC1(C)C2=CC=CC(P(C3=CC=CC=C3)(C3=CC=CC=C3)->[Pd]3(Cl)<-NC4=C(C=CC=C4)C4=CC=CC=C43)=C2OC2=C1C=CC=C2P(C1=CC=CC=C1)C1=CC=CC=C1',
#  'tBu3P Pd G2 33': 'CC(C)(C)P(C(C)(C)C)(C(C)(C)C)->[Pd]1(Cl)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#  'PPA Pd G3 34': 'CC12CC3(C)OC(C)(CC(C)(O1)P3(C1=CC=CC=C1)->[Pd]1(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C31)O2',
#  'Aphos Pd G3 35': 'CC(C)(C)P(C1=CC=C(N)C=C1)(C(C)(C)C)->[Pd]1(OS(C)(=O)=O)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#  'Xphos Pd G3 36': 'CC(C)C1=CC(C(C)C)=C(C2=C(P(C3CCCCC3)(C3CCCCC3)->[Pd]3(OS(C)(=O)=O)<-NC4=C(C=CC=C4)C4=CC=CC=C43)C=CC=C2)C(C(C)C)=C1',
#  'RuPhos Pd G2 37': 'CC(C)OC1=CC=CC(OC(C)C)=C1C1=C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(Cl)<-NC3=C(C=CC=C3)C3=CC=CC=C32)C=CC=C1',
#  'DTBPF Pd G3 38': 'CC(C)(C)P(C1=CC=CC1[Fe]C1C=CC=C1P(C(C)(C)C)(C(C)(C)C)->[Pd]1(OS(C)(=O)=O)<-NC2=C(C=CC=C2)C2=CC=CC=C21)C(C)(C)C',
#  'J009  Pd G3 39': 'CC(C1=C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)C([Fe]C2C=CC=C2)C=C1)P(C(C)(C)C)C(C)(C)C',
#  'MorDalPhos Pd G3 40': 'CS(=O)(=O)O[Pd]1(<-P(C2=C(N3CCOCC3)C=CC=C2)(C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#  'BrettPhos Pd G3 41': 'COC1=CC=C(OC)C(P(C2CCCCC2)(C2CCCCC2)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)=C1C1=C(C(C)C)C=C(C(C)C)C=C1C(C)C',
#  'tBuXPhos Pd G3  42': 'CC(C)C1=CC(C(C)C)=C(C2=C(P(C(C)(C)C)(C(C)(C)C)->[Pd]3(OS(C)(=O)=O)<-NC4=C(C=CC=C4)C4=CC=CC=C43)C=CC=C2)C(C(C)C)=C1',
#  'tBuBrettPhos Pd G3 43': 'COC1=CC=C(OC)C(P(C(C)(C)C)(C(C)(C)C)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)=C1C1=C(C(C)C)C=C(C(C)C)C=C1C(C)C',
#  'RockPhos Pd G3 44': 'COC1=CC=C(C)C(C2=C(C(C)C)C=C(C(C)C)C=C2C(C)C)=C1P(C(C)(C)C)(C(C)(C)C)->[Pd]1(OS(C)(=O)=O)<-NC2=C(C=CC=C2)C2=CC=CC=C21',
#  'AdBrettPhos Pd G3 45': 'COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)(C23C[C@H]4C[C@@H](C2)C[C@@H](C3)C4)->[Pd]2(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C32)=C1C1=C(C(C)C)C=C(C(C)C)C=C1C(C)C',
#  'DBU 24': 'C1CCC2=NCCCN2CC1',
#  'MTBD 25': 'CN1CCCN2CCCN=C12',
#  'BTMG 26': 'CN(C)C(=NC(C)(C)C)N(C)C',
#  'BEMP 27': 'CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C',
#  'BTTP 28': 'CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1',
#  'P2Et 29': 'CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C',
#  'Product_0': 'CC(CCc1ccccc1)Nc1cccnc1',
#  'Product_1': 'c1ccc(Nc2cccnc2)cc1',
#  'Product_2': 'O=C(Nc1cccnc1)c1ccccc1',
#  'Product_3': 'O=S(=O)(Nc1cccnc1)c1ccccc1',
#  'Product_4': 'c1ccc(-c2ccc(Nc3cccnc3)nc2)cc1',
#  'Product_5': 'N=C(Cc1ccccc1)Nc1cccnc1',
#  'Product_6': 'CC(C)(C)OC(=O)Nc1cccnc1',
#  'Product_7': 'c1cncc(-n2ncc3ccccc32)c1',
#  'Product_8': 'c1ccc(CCCOc2cccnc2)cc1',
#  'Product_9': 'c1ccc(Oc2cccnc2)cc1',
#  'Product_10': 'c1ccc(Sc2cccnc2)cc1',
#  'Product_11': 'c1ccc(P(c2ccccc2)c2cccnc2)cc1',
#  'Product_12': 'c1ccc(Cn2cc(-c3cccnc3)cn2)cc1',
#  'Product_13': 'CCOC(=O)C(C(=O)OCC)c1cccnc1',
#  'Product_14': 'CCOC(=O)/C=C(\\c1ccccc1)c1cccnc1',
#  'Product_15': 'CCCCc1ccc(C#Cc2cccnc2)cc1'}

# %% [markdown]
# ## Add component SMILES and yield columns to data

# %%
# Make list of columns to be mapped to corresponding SMILES
subclasses = ["Electrophile", "Nucleophile", "Catalyst", "Base", "Product"]

# Create new columns using smiles_map
for subclass in subclasses:
    data[f"{subclass}_SMILES"] = data[subclass].map(smiles_map)

# View changes
data
# Out:
#      Plate Position Electrophile Electrophile charge Nucleophile  \
# 0                A1   bromide 22    250 nL (50 nmol)    amine S1
# 1                A2   bromide 22    250 nL (50 nmol)    amine S1
# 2                A3   bromide 22    250 nL (50 nmol)    amine S1
# 3                A4   bromide 22    250 nL (50 nmol)    amine S1
# 4                A5   bromide 22    250 nL (50 nmol)    amine S1
# ...             ...          ...                 ...         ...
# 1531           AF44   bromide 22    250 nL (50 nmol)  alkyne S16
# 1532           AF45   bromide 22    250 nL (50 nmol)  alkyne S16
# 1533           AF46   bromide 22    250 nL (50 nmol)  alkyne S16
# 1534           AF47   bromide 22    250 nL (50 nmol)  alkyne S16
# 1535           AF48   bromide 22    250 nL (50 nmol)  alkyne S16
#
#      Nucleophile charge              Catalyst   Catalyst charge     Base  \
# 0     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)   DBU 24
# 1     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  MTBD 25
# 2     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTMG 26
# 3     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BEMP 27
# 4     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTTP 28
# ...                 ...                   ...               ...      ...
# 1531  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  MTBD 25
# 1532  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTMG 26
# 1533  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BEMP 27
# 1534  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTTP 28
# 1535  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  P2Et 29
#
#               Base charge            IS  ...          Prod            Nu  \
# 0     250 nL (200 nmol)    240134.33032  ...  0.000000e+00  2.638835e+06
# 1     250 nL (200 nmol)    238726.34177  ...  0.000000e+00  2.474074e+06
# 2     250 nL (200 nmol)    235018.13944  ...  0.000000e+00  2.387052e+06
# 3     250 nL (200 nmol)    238060.17048  ...  3.268438e+04  2.511884e+06
# 4     250 nL (200 nmol)    232566.53610  ...  0.000000e+00  2.576513e+06
# ...                   ...           ...  ...           ...           ...
# 1531  250 nL (200 nmol)    178233.56101  ...  3.046576e+06           NaN
# 1532  250 nL (200 nmol)    229583.53543  ...  2.789535e+06           NaN
# 1533  250 nL (200 nmol)    202191.15883  ...  4.537288e+05           NaN
# 1534  250 nL (200 nmol)    201367.67531  ...  1.109048e+06           NaN
# 1535  250 nL (200 nmol)    197245.14055  ...  4.682473e+05           NaN
#
#           Pd/IS     Product               Reaction_type Electrophile_SMILES  \
# 0      0.000000   Product_0  Buchwald-Hartwig amination          Brc1cccnc1
# 1      0.000000   Product_0  Buchwald-Hartwig amination          Brc1cccnc1
# 2      0.000000   Product_0  Buchwald-Hartwig amination          Brc1cccnc1
# 3      0.137295   Product_0  Buchwald-Hartwig amination          Brc1cccnc1
# 4      0.000000   Product_0  Buchwald-Hartwig amination          Brc1cccnc1
# ...         ...         ...                         ...                 ...
# 1531  17.093165  Product_15        Sonogashira coupling          Brc1cccnc1
# 1532  12.150413  Product_15        Sonogashira coupling          Brc1cccnc1
# 1533   2.244058  Product_15        Sonogashira coupling          Brc1cccnc1
# 1534   5.507575  Product_15        Sonogashira coupling          Brc1cccnc1
# 1535   2.373936  Product_15        Sonogashira coupling          Brc1cccnc1
#
#      Nucleophile_SMILES                                    Catalyst_SMILES  \
# 0       CC(N)CCc1ccccc1  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 1       CC(N)CCc1ccccc1  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 2       CC(N)CCc1ccccc1  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 3       CC(N)CCc1ccccc1  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 4       CC(N)CCc1ccccc1  CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# ...                 ...                                                ...
# 1531  C#Cc1ccc(CCCC)cc1  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1532  C#Cc1ccc(CCCC)cc1  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1533  C#Cc1ccc(CCCC)cc1  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1534  C#Cc1ccc(CCCC)cc1  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1535  C#Cc1ccc(CCCC)cc1  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
#
#                                     Base_SMILES             Product_SMILES
# 0                              C1CCC2=NCCCN2CC1    CC(CCc1ccccc1)Nc1cccnc1
# 1                              CN1CCCN2CCCN=C12    CC(CCc1ccccc1)Nc1cccnc1
# 2                       CN(C)C(=NC(C)(C)C)N(C)C    CC(CCc1ccccc1)Nc1cccnc1
# 3               CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C    CC(CCc1ccccc1)Nc1cccnc1
# 4          CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1    CC(CCc1ccccc1)Nc1cccnc1
# ...                                         ...                        ...
# 1531                           CN1CCCN2CCCN=C12  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1532                    CN(C)C(=NC(C)(C)C)N(C)C  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1533            CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1534       CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1535  CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C  CCCCc1ccc(C#Cc2cccnc2)cc1
#
# [1536 rows x 21 columns]

# %%
# Check yield distributions
data.describe()
# Out:
#                  IS          ArBr          Prod            Nu        Pd/IS
# count  1.536000e+03  1.536000e+03  1.536000e+03  6.720000e+02  1531.000000
# mean   2.387198e+05  8.901066e+05  4.282438e+05  2.058694e+06     2.057352
# std    1.145788e+05  3.836603e+05  9.515332e+05  7.573593e+05     4.755104
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
# 25%    1.931701e+05  7.479278e+05  0.000000e+00  1.623828e+06     0.000000
# 50%    2.191729e+05  1.023685e+06  0.000000e+00  2.175684e+06     0.000000
# 75%    2.396104e+05  1.126468e+06  2.587670e+05  2.597350e+06     1.159855
# max    1.274687e+06  2.181530e+06  6.411983e+06  5.094171e+06    39.811353

# %%
# Above table indicates there are missing values; find where
# Below table indicates 'Nu' and 'Pd/IS' absorption measurments are missing
# from many reactions
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1536 entries, 0 to 1535
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Plate Position       1536 non-null   object
#  1   Electrophile         1536 non-null   object
#  2   Electrophile charge  1536 non-null   object
#  3   Nucleophile          1536 non-null   object
#  4   Nucleophile charge   1536 non-null   object
#  5   Catalyst             1536 non-null   object
#  6   Catalyst charge      1536 non-null   object
#  7   Base                 1536 non-null   object
#  8   Base charge          1536 non-null   object
#  9   IS                   1536 non-null   float64
#  10  ArBr                 1536 non-null   float64
#  11  Prod                 1536 non-null   float64
#  12  Nu                   672 non-null    float64
#  13  Pd/IS                1531 non-null   float64
#  14  Product              1536 non-null   object
#  15  Reaction_type        1536 non-null   object
#  16  Electrophile_SMILES  1536 non-null   object
#  17  Nucleophile_SMILES   1536 non-null   object
#  18  Catalyst_SMILES      1536 non-null   object
#  19  Base_SMILES          1536 non-null   object
#  20  Product_SMILES       1536 non-null   object
# dtypes: float64(5), object(16)
# memory usage: 264.0+ KB

# %%
# Going to assume missing values are undetected, i.e., 0 absorbtion
# Fill in missing values with 0 for 'IS', 'ArBr', 'Prod', 'Nu', 'Pd/IS'
for column in ["IS", "ArBr", "Prod", "Nu", "Pd/IS"]:
    data[column] = data[column].fillna(0)

# Add explicit yield columns, dividing 'IS' by .03 as procedure claims
# final IS loading is 3 mol % relative to ArBr. Paper uses Pd/IS to directly
# compare performance of each reaction conditions, but is not actually a
# reaction yield measurement
data["Product_yield"] = round(((data["Prod"] / (data["IS"] / 0.03)) * 100), 2)
data["ArBr_yield"] = round(((data["ArBr"] / (data["IS"] / 0.03)) * 100), 2)
data["Nu_yield"] = round(((data["Nu"] / (data["IS"] / 0.03)) * 100), 2)

# Handle any cases where 'IS' = 0 and 0 division failed
for column in ["Product_yield", "ArBr_yield", "Nu_yield"]:
    data[column] = data[column].fillna(0)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1536 entries, 0 to 1535
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Plate Position       1536 non-null   object
#  1   Electrophile         1536 non-null   object
#  2   Electrophile charge  1536 non-null   object
#  3   Nucleophile          1536 non-null   object
#  4   Nucleophile charge   1536 non-null   object
#  5   Catalyst             1536 non-null   object
#  6   Catalyst charge      1536 non-null   object
#  7   Base                 1536 non-null   object
#  8   Base charge          1536 non-null   object
#  9   IS                   1536 non-null   float64
#  10  ArBr                 1536 non-null   float64
#  11  Prod                 1536 non-null   float64
#  12  Nu                   1536 non-null   float64
#  13  Pd/IS                1536 non-null   float64
#  14  Product              1536 non-null   object
#  15  Reaction_type        1536 non-null   object
#  16  Electrophile_SMILES  1536 non-null   object
#  17  Nucleophile_SMILES   1536 non-null   object
#  18  Catalyst_SMILES      1536 non-null   object
#  19  Base_SMILES          1536 non-null   object
#  20  Product_SMILES       1536 non-null   object
#  21  Product_yield        1536 non-null   float64
#  22  ArBr_yield           1536 non-null   float64
#  23  Nu_yield             1536 non-null   float64
# dtypes: float64(8), object(16)
# memory usage: 300.0+ KB

# %%
# View final dataset
data
# Out:
#      Plate Position Electrophile Electrophile charge Nucleophile  \
# 0                A1   bromide 22    250 nL (50 nmol)    amine S1
# 1                A2   bromide 22    250 nL (50 nmol)    amine S1
# 2                A3   bromide 22    250 nL (50 nmol)    amine S1
# 3                A4   bromide 22    250 nL (50 nmol)    amine S1
# 4                A5   bromide 22    250 nL (50 nmol)    amine S1
# ...             ...          ...                 ...         ...
# 1531           AF44   bromide 22    250 nL (50 nmol)  alkyne S16
# 1532           AF45   bromide 22    250 nL (50 nmol)  alkyne S16
# 1533           AF46   bromide 22    250 nL (50 nmol)  alkyne S16
# 1534           AF47   bromide 22    250 nL (50 nmol)  alkyne S16
# 1535           AF48   bromide 22    250 nL (50 nmol)  alkyne S16
#
#      Nucleophile charge              Catalyst   Catalyst charge     Base  \
# 0     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)   DBU 24
# 1     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  MTBD 25
# 2     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTMG 26
# 3     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BEMP 27
# 4     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTTP 28
# ...                 ...                   ...               ...      ...
# 1531  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  MTBD 25
# 1532  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTMG 26
# 1533  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BEMP 27
# 1534  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTTP 28
# 1535  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  P2Et 29
#
#               Base charge            IS  ...     Product  \
# 0     250 nL (200 nmol)    240134.33032  ...   Product_0
# 1     250 nL (200 nmol)    238726.34177  ...   Product_0
# 2     250 nL (200 nmol)    235018.13944  ...   Product_0
# 3     250 nL (200 nmol)    238060.17048  ...   Product_0
# 4     250 nL (200 nmol)    232566.53610  ...   Product_0
# ...                   ...           ...  ...         ...
# 1531  250 nL (200 nmol)    178233.56101  ...  Product_15
# 1532  250 nL (200 nmol)    229583.53543  ...  Product_15
# 1533  250 nL (200 nmol)    202191.15883  ...  Product_15
# 1534  250 nL (200 nmol)    201367.67531  ...  Product_15
# 1535  250 nL (200 nmol)    197245.14055  ...  Product_15
#
#                    Reaction_type  Electrophile_SMILES  Nucleophile_SMILES  \
# 0     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 1     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 2     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 3     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 4     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# ...                          ...                  ...                 ...
# 1531        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1532        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1533        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1534        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1535        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
#
#                                         Catalyst_SMILES  \
# 0     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 1     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 2     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 3     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 4     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# ...                                                 ...
# 1531  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1532  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1533  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1534  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1535  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
#
#                                     Base_SMILES             Product_SMILES  \
# 0                              C1CCC2=NCCCN2CC1    CC(CCc1ccccc1)Nc1cccnc1
# 1                              CN1CCCN2CCCN=C12    CC(CCc1ccccc1)Nc1cccnc1
# 2                       CN(C)C(=NC(C)(C)C)N(C)C    CC(CCc1ccccc1)Nc1cccnc1
# 3               CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C    CC(CCc1ccccc1)Nc1cccnc1
# 4          CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1    CC(CCc1ccccc1)Nc1cccnc1
# ...                                         ...                        ...
# 1531                           CN1CCCN2CCCN=C12  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1532                    CN(C)C(=NC(C)(C)C)N(C)C  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1533            CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1534       CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1535  CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C  CCCCc1ccc(C#Cc2cccnc2)cc1
#
#      Product_yield ArBr_yield Nu_yield
# 0             0.00      15.07    32.97
# 1             0.00      14.20    31.09
# 2             0.00      14.04    30.47
# 3             0.41      14.00    31.65
# 4             0.00      14.40    33.24
# ...            ...        ...      ...
# 1531         51.28       0.00     0.00
# 1532         36.45       3.32     0.00
# 1533          6.73      12.10     0.00
# 1534         16.52       9.28     0.00
# 1535          7.12       7.84     0.00
#
# [1536 rows x 24 columns]

# %%
# Show final dataset statistics
data.describe()
# Out:
#                  IS          ArBr          Prod            Nu        Pd/IS  \
# count  1.536000e+03  1.536000e+03  1.536000e+03  1.536000e+03  1536.000000
# mean   2.387198e+05  8.901066e+05  4.282438e+05  9.006787e+05     2.050654
# std    1.145788e+05  3.836603e+05  9.515332e+05  1.137724e+06     4.748800
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
# 25%    1.931701e+05  7.479278e+05  0.000000e+00  0.000000e+00     0.000000
# 50%    2.191729e+05  1.023685e+06  0.000000e+00  0.000000e+00     0.000000
# 75%    2.396104e+05  1.126468e+06  2.587670e+05  2.093107e+06     1.130823
# max    1.274687e+06  2.181530e+06  6.411983e+06  5.094171e+06    39.811353
#
#        Product_yield   ArBr_yield     Nu_yield
# count    1536.000000  1536.000000  1536.000000
# mean        6.152031    12.522422    10.991686
# std        14.246570     7.543525    14.342438
# min         0.000000     0.000000     0.000000
# 25%         0.000000     8.247500     0.000000
# 50%         0.000000    13.560000     0.000000
# 75%         3.392500    16.390000    25.692500
# max       119.430000    92.860000    86.120000

# %% [markdown]
# # Define a single reaction
#
# This experiment details the screening of cross-coupling reactions between one aryl halide with 16 nucleophiles using 16 different precatalysts and 6 bases (1536 reactions)
#
# The general procedure from the SI is as follows:
#
# "**Experiment 2. 1536-Well Plate Screening of Pd Cross-Coupling Reactions of 3- Bromopyridine 22 with 16 Nucleophiles (16 Precatalysts, 6 Bases)**
#
# A 1536-well plate experiment examining the reactivity of 3-bromopyridine 22 with 16 different classes of nucleophiles under 96 Pd cross-coupling reaction conditions was run at 100 nanomolar scale by dosing from a 384-well plate containing stock solutions of the starting materials and reagents into a 1536-Well Plate by Mosquito.<br>
#
# **Procedure.** Stock solutions of each of the reaction components were prepared as follows: Pd- precatalysts (**30-45**, 0.04 M in DMSO), aryl halide (**22**, 0.4 M in DMSO), nucleophiles (**S1-S16**, 0.6 M in DMSO), and base (**24-29**, 0.8 M in DMSO). Each of the solutions was dispensed in 75 uL charges to a 384-well plate (source plate map is shown in Figure S8, components listed in Table S2).<br>
#
# The Mosquito was used to combine the source plate solutions by multi-aspiration of 250 nL of each of the four reaction components and then to dose the resulting reaction mixture (1 uL) into a 1536-well plate. Once the 1536-well plate was fully dosed the plate was covered by a PFA film and clamped to minimize low-level component volatility. The plate was then allowed to sit at room temperature for 22 hours. Using the Mosquito, the plate was then quenched with 3 uL of a DMSO stock solution of acetic 5% acid and biphenyl (to give 3 mol% biphenyl relative to **22**), which was transferred from a 384-well source plate. The Mosquito then sampled 1 uL from the quenched reaction plate into 4 x 384-well plates containing 75 uL of DMSO per well. The Mosquito mixing feature was used three times per aspiration and dispense steps in order to ensure homogeneity of the analytical sample. The 384-well plate was then heat-sealed and subjected to chromatographic analysis by a Waters UPLC Instrument. The ratio of the LC area counts of product over internal standard was used to directly compare the relative performance of these reactions."

# %%
# Calculate stoichiometry
# List component stock solution concentrations (in M or nmol/nL)
electrophile_stock_conc = 0.4
nucleophile_stock_conc = 0.6
base_stock_conc = 0.8
catalyst_stock_conc = 0.04

# Calculate nmol of each component added
electrophile_nmol = electrophile_stock_conc * 250
nucleophile_nmol = nucleophile_stock_conc * 250
base_nmol = base_stock_conc * 250
catalyst_nmol = catalyst_stock_conc * 250

# Show values
print(electrophile_nmol, nucleophile_nmol, base_nmol, catalyst_nmol)
# Out:
# 100.0 150.0 200.0 10.0

# %% [markdown]
# ### Set up reaction in flow of Reaction message
# 1. Define reaction
# 2. Add identifiers
# 3. Add inputs
# 4. Describe setup
# 5. Describe conditions
# 6. Add notes
# 7. Add observations
# 8. Describe workup
# 9. Describe outcomes
# 10. Add provenance

# %% [markdown]
# #### 1. Define reaction

# %%
# Initialize Reaction
reaction = reaction_pb2.Reaction()

# %% [markdown]
# #### 2. Add identifiers

# %%
reaction.identifiers.add(value=r"placeholder", type="REACTION_TYPE")
# Out:
# type: NAME
# value: "placeholder"

# %% [markdown]
# #### 3. Add inputs

# %%
# Reactant 1
reaction.inputs["electrophile"].addition_order = 1
solute = reaction.inputs["electrophile"].components.add()
solvent = reaction.inputs["electrophile"].components.add()
solute.CopyFrom(
    message_helpers.build_compound(
        name="placeholder",
        smiles="placeholder",
        role="reactant",
        amount="100 nmol",
        prep=None,
        is_limiting=True,
        prep_details=None,
    )
)
solvent.CopyFrom(
    message_helpers.build_compound(
        name="DMSO",
        smiles="CS(C)=O",
        role="solvent",
        amount="250 nL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.amount.volume_includes_solutes = True

# Reactant 2
reaction.inputs["nucleophile"].addition_order = 1
solute = reaction.inputs["nucleophile"].components.add()
solvent = reaction.inputs["nucleophile"].components.add()
solute.CopyFrom(
    message_helpers.build_compound(
        name="placeholder",
        smiles="placeholder",
        role="reactant",
        amount="150 nmol",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.CopyFrom(
    message_helpers.build_compound(
        name="DMSO",
        smiles="CS(C)=O",
        role="solvent",
        amount="250 nL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.amount.volume_includes_solutes = True

# Reagent 1 = Base
reaction.inputs["base"].addition_order = 1
solute = reaction.inputs["base"].components.add()
solvent = reaction.inputs["base"].components.add()
solute.CopyFrom(
    message_helpers.build_compound(
        name="placeholder",
        smiles="placeholder",
        role="reagent",
        amount="200 nmol",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.CopyFrom(
    message_helpers.build_compound(
        name="DMSO",
        smiles="CS(C)=O",
        role="solvent",
        amount="250 nL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.amount.volume_includes_solutes = True

# Catalyst
reaction.inputs["catalyst"].addition_order = 1
solute = reaction.inputs["catalyst"].components.add()
solvent = reaction.inputs["catalyst"].components.add()
solute.CopyFrom(
    message_helpers.build_compound(
        name="placeholder",
        smiles="placeholder",
        role="reagent",
        amount="10 nmol",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.CopyFrom(
    message_helpers.build_compound(
        name="DMSO",
        smiles="CS(C)=O",
        role="solvent",
        amount="250 nL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.amount.volume_includes_solutes = True

# %% [markdown]
# #### 4. Describe setup
# From the SI: "All reactions, including parallel synthesis, were performed inside an MBraun glovebox operating with a constant N2-purge (oxygen typically <5 ppm). The experimental design was accomplished using Free-Slate Library Studio."<br>
# "**Nanomolar Scale Chemistry Experiments**. Nanoscale reactions (50-100 nmol) were run using Corning® 1536-well plates (Corning EchoTM qualified, Cat. No. 3730, Cyclic Olefin-Copolymer COC, 12.5 μL-wells, flat bottom, clear) as reaction plates, and typically with AdvantageTM 384- well plates (Analytical-Sales, Cat. No. 38120, polypropylene, 120 μL-wells, flat bottom, clear) used as solution source plates for stock solutions and for analytical plates on UPLC-MS or HPLC-MS equipment. Dosing of reaction components into the 384- and 1536-well plates was accomplished in the glovebox using a Mosquito® HTS liquid handling robot (Figure S1, TTP Labtech, 4.5 mm pitch tip spool) with no special modifications, and using the TTP Labtech native software. Upon dosing, the 1536-well plates were covered by a perfluoroalkoxy alkane (PFA) mat (Analytical-Sales, Cat. No. 96981), followed by a silicon rubber mat (Analytical- Sales, Cat. No. 96982) and then secured with a clamp (Arctic White, Cat. No. AWSC-051001)."

# %%
# Reactions performed in 1536-well plate
reaction.setup.vessel.CopyFrom(
    reaction_pb2.Vessel(
        type="WELL_PLATE",
        details="Corning Echo qualified, Cat. No. 3730",
        material={"type": "PLASTIC", "details": "Cyclic Olefin-Copolymer"},
        volume=unit_resolver.resolve("12.5 uL"),
    )
)

# Add vessel attachments
reaction.setup.vessel.attachments.add(
    type="MAT",
    details=(
        r"perfluoroalkoxy alkane (PFA)" r" mat (Analytical-Sales, Cat. No. 96981)"
    ),
)

reaction.setup.vessel.attachments.add(
    type="MAT", details=(r"silicon rubber mat (Analytical-Sales, Cat. No. 96982)")
)

reaction.setup.vessel.attachments.add(
    type="CUSTOM", details=(r"clamp (Arctic White, Cat. No. AWSC-051001)")
)

# Specify reaction environment
reaction.setup.environment.CopyFrom(
    reaction_pb2.ReactionSetup.ReactionEnvironment(
        type="GLOVE_BOX",
        details=(
            r"MBraun glovebox operating with"
            r" a constant N2-purge (oxygen typically <5 ppm)"
        ),
    )
)

# Specify automation
reaction.setup.is_automated = True
reaction.setup.automation_platform = (
    r"Mosquito(R) HTS liquid handling robot;"
    r" TTP Labtech native software;"
    r" Free-Slate Library Studio"
)

# %% [markdown]
# #### 5. Describe conditions

# %%
# Reactions allowed to sit ambiently for 22 hours
reaction.conditions.temperature.CopyFrom(
    reaction_pb2.TemperatureConditions(
        control=(
            {
                "type": "AMBIENT",
                "details": (
                    r"The plate was then allowed to sit at"
                    r" room temperature for 22 hours"
                ),
            }
        )
    )
)

# Experiment run at atmospheric pressure, plate sealed with silicon mats
reaction.conditions.pressure.CopyFrom(
    reaction_pb2.PressureConditions(
        control=(
            {
                "type": "SEALED",
                "details": (
                    r"The 1536-well plates were covered by a"
                    r" perfluoroalkoxy alkane (PFA) mat (Analytical-Sales,"
                    r" Cat. No. 96981), followed by a silicon rubber mat"
                    r" (Analytical- Sales, Cat. No. 96982) and then secured"
                    r" with a clamp (Arctic White, Cat. No. AWSC-051001)"
                ),
            }
        ),
        atmosphere=({"type": "NITROGEN"}),
    )
)

# No stirring used
reaction.conditions.stirring.CopyFrom(reaction_pb2.StirringConditions(type="NONE"))

# %% [markdown]
# #### 6. Add notes

# %%
# Reaction prepared in glove box, presumed sensitivity
reaction.notes.is_sensitive_to_moisture = True
reaction.notes.is_sensitive_to_oxygen = True

# Authors note reactions are homogeneous
reaction.notes.is_heterogeneous = False

# No safety notes
reaction.notes.safety_notes = ""

# Additional sentence explaining how the components are dosed (aspiration)
reaction.notes.procedure_details = (
    r"The Mosquito was used to combine the"
    r" source plate solutions by multi-aspiration of 250 nL of each of the"
    r" four reaction components and then to dose the resulting reaction"
    r" mixture (1 uL) into a 1536-well plate"
)

# %% [markdown]
# #### 7. Add observations
# Images included in the SI showing reaction plate setup.

# %%
# Create data messages for the included images
dosed_plate = message_helpers.build_data("dosed_plate.png", "fully dosed plate")
sealed_plate = message_helpers.build_data("sealed_plate.png", "sealed plate")

# Add images as observations
reaction.observations.add(
    time=({"value": 0, "units": "HOUR"}),
    comment="fully dosed 1536 reaction well plate",
    image=dosed_plate,
)
reaction.observations.add(
    time=({"value": 0, "units": "HOUR"}),
    comment="clamped 1536-wp - perspective view",
    image=sealed_plate,
)
# Out:
# time {
#   value: 0.0
#   units: HOUR
# }
# comment: "clamped 1536-wp - perspective view"
# image {
#   bytes_value: "\211PNG\r\n\032\n\000\000\000\rIHDR\000\000\002\274\000\000\001\263\010\006\000\000\000\315\004\304\013\000\000\000\001sRGB\000\256\316\034\351\000\000\000\tpHYs\000\000\027\022\000\000\027\022\001g\237\322R\000\000@\000IDATx\001\304\275I\223$Iz\246g\341\036\036KfVUV\025\320X\010\200C\n@\202\030R\204\007^)\344\205\007\376m^Fx\345\010\311\021\0222\300\000\203\356Fw\327\226K\354\036\301\347y_Us\217\254\314\256\306\010f\250\021f\272}\372m\372\351jj\346\'\013\356\325\237\376\317\377\333\371\371\313\257\376\362\277\377\037\227\327\177\360\237/\177\364/\377\247\345v9_\376\341\315\351\362\356\356ly\317\265\177X\226\373\307\223\345\345\366d\331l\226e\373p\273,O\373\345bC\306\tA\322\366\'\'\313\r\221\247\247ey\330\237.\217\304\367\340?\335\234,\247\370\027\'O\346\022\336[d\271[\356\271\223\006\374\311#\351\017\017\344=.\227\'\267\313\317>\337,_\277\336-\177\366G\257r\375\027\177\002\237/\227\345\362L|\313\262y\202>n\033L`y\222\202\216L\235\004\206{x|X\236\036\036\227\373\'|\350\334\336\301\327#<>n\244\276<>m\227;X\371\376\375\351\362\303\233\307\345\377\3707\327\313\337\377\352f\371\371?\276_\336?\"?\327\303\3119\234\235.\017\240\177\n\356Ag\277\013\025\361?!\327=\232\333?=\202s\217\374O\224SB\234e\266\367\224}\\n6\267\313\343\026\275\275\272[6\027w\313\305\357]/\'g\357\226\355\213\277\205\247_\242g\256\207o\227\307\307o\320\313\r\005\301\240|\020>\331\354\202\352iS\035\212:\371\320\222\316\0230\362\367\200\356\321T\3626\017\327f,\333\223-q\322\251G\335\323\335\203\322S\323\217\313\213G\374\207\247\345K\350|\201>\376\362\342g\313\227\'\027\313\037\334^.\027w\233e\367\355\375\262#\375\367^~\265\234\237\277X._}\276\354..\226\313?\370\375\345\364\263W\313\346\345+\370\277XN._,\017\247\350\004\372\233\335\031\374Rv{Z\361Ov\324\333~9\303\2306\324\305\331\323;\352\376j\331\356o\226\357\276\371%\327/\226\177\365\277\377\253\345\327\277\372\325\362\327\377\366\037\226\037\336\275_\336\276\275C\'\310s\263A\247\260\016\237\";\331Q\363\233\355\262AD\252s\271\217\021\235@{Y~\363\247/\227\373\317\317\226?\372\257\377\005<\236/\367?{\211\276O\226\357\367\327\261\201klw\017\375\307{pUk\370\206u\352\014[n\255qO\355%-\372E.\265\267!\242\014\013:;\321\340\371\177\200\206\215\343Q\206\217\334\t\366\237?M\006!\264\301G\205\331s\341\304\365\210\355\213#(\260a\264\227\370&\306f\031Z\022e0\237\325\311\207\366\377\345\325\351rN\003\374\223/\377p\371\331\353\257\227\377\365\177\370_\226\257?\377j\371o\377\370/\226W\273\027\313\313\345Ex>\005\247\024\225I\322\372\033\020\312\326\tu[\'V\343\215\375\370^\014\321\327Iu\265\354\261k\352\345\356\016\375\336\335-\277\372\326\272\374\315\362o\376\357\377ky\367\356\355\362\253_\376|y\361\362\305\362\331\253\027\313\237\377\305_,\177\376\347\177\276|\365\345\227\313\331nG\273{\340\272_\376\365\277\376?\251\353w\313\337\376\355\277[\256oo\223\276E\327\2733\332\236\372\302f.^\274X^`s_\177\375\365r\206\177~~\016\377\3667\007f\325\363\351\331\216>b\263\234\237\235/\347/.\3513.\227\355\356\024;\244\355\330y\234`\223\304Oh\017[\343\224y\23484(\2345\240\243V\202\377i\277\'M\330\203\263^?\346\254\337\203\203#\212\331\317\034\247\036\362\033\372\260\214\300\210\206k\371\330\217\364I\263\316t\223\347)?\335N\234\364fYu\250-=\315L|i\355\265\'\2346!\322\315)p\203^U\241u$ky\3006\245Q\376O\226\263St$,\365o{\274\271\271\003\337#\365v\203)<\000_Xm\314\372\321\rS_\353\212\0362\351\353\r6\252\266\366S\'\224{qyA\037r\212\235\234\321.\030[\356\3507\351\270\337\275\273\202\036t\356\221\001y\254\231\351\034kN\220e\272\231\263\205WY\331\355\250Y\002\033\354\3036\365(\236\007\375=MY\256\250)\024\030\333\020W\324S|\263MlH\354%\236\223e\213\315\264v\037\261U0`+\302Z\364\201\260N[Q+v\031\216\233\246\337\242\267o\277\375v\371\346\333_-\277\372\346\327\313\355\325\365r\205\016\037-\203\276O\320s(;X\341\266[\332(x\255\273\340Ba\332\251\362\244O\201\373{\372t\353z\037\034\224\221\td=\323\256a\312<\365\274\247=Q2Lj\037!\244\274$IF\337\242\366GT\001x\250\017\333\025\355\3453\332\325\331\351\226\366DI\332\220\\n(\244\316^\274z\265\234\235 ...
#   description: "sealed plate"
#   format: "png"
# }

# %% [markdown]
# #### 8. Describe workup
# From the SI: "Using the Mosquito, the plate was then quenched with 3 uL of a DMSO stock solution of acetic 5% acid and biphenyl (to give 3 mol% biphenyl relative to 22), which was transferred from a 384-well source plate. The Mosquito then sampled 1 uL from the quenched reaction plate into 4 x 384-well plates containing 75 uL of DMSO per well. The Mosquito mixing feature was used three times per aspiration and dispense steps in order to ensure homogeneity of the analytical sample."

# %%
# Create quench solution as workup input
workup = reaction.workups.add(
    type="ADDITION",
    stirring={
        "type": "AGITATION",
        "details": "The Mosquito mixing feature was used three times",
    },
    is_automated=True,
)

# Add components (assuming biphenyl to be 100 nmol * 3 mol % = 3 nmol)
workup.input.components.add().CopyFrom(
    message_helpers.build_compound(
        name="acetic acid",
        smiles="CC(=O)O",
        role="workup",
        amount="150 nL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
workup.input.components.add().CopyFrom(
    message_helpers.build_compound(
        name="biphenyl",
        smiles="c1ccc(-c2ccccc2)cc1",
        role="internal_standard",
        amount="3 nmol",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent = workup.input.components.add()
solvent.CopyFrom(
    message_helpers.build_compound(
        name="DMSO",
        smiles="CS(C)=O",
        role="workup",
        amount="2.85 uL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)
solvent.amount.volume_includes_solutes = True

# Add aliquot step
aliquot = reaction.workups.add(
    type="ALIQUOT",
    stirring={
        "type": "AGITATION",
        "details": "The Mosquito mixing feature was used three times",
    },
    is_automated=True,
    amount=reaction_pb2.Amount(volume=reaction_pb2.Volume(value=1, units="MICROLITER")),
)

# Create dilution solvent as workup input
dilution = reaction.workups.add(
    type="ADDITION",
    stirring={
        "type": "AGITATION",
        "details": "The Mosquito mixing feature was used three times",
    },
    is_automated=True,
)

# Add DMSO component
dilution.input.components.add().CopyFrom(
    message_helpers.build_compound(
        name="DMSO",
        smiles="CS(C)=O",
        role="workup",
        amount="75 uL",
        prep=None,
        is_limiting=False,
        prep_details=None,
    )
)

# %% [markdown]
# #### 9. Describe outcomes
# From the SI: "The plate was then allowed to sit at room temperature for 22 hours."<br>
# "The 384-well plate was then heat-sealed and subjected to chromatographic analysis by a Waters UPLC Instrument. The ratio of the LC area counts of product over internal standard was used to directly compare the relative performance of these reactions." <br>
# **The authors do not directly report reaction yields, but compare their relative performances by ratios of "LC area counts of product over internal standard". We calculate reaction yields here with the assumption that the internal standard is present in 3 mol % as they note, and that the product and internal standard have equivalent response factors under the absorption method used. This may not be true, and some yields are > 100%, but there is no other direct quantitative reaction performance metric provided.**

# %%
# Add outcome
outcome = reaction.outcomes.add(
    reaction_time=unit_resolver.resolve("22 hours"),
)

# Add analyses
# UPLC
outcome.analyses["UPLC"].type = reaction_pb2.Analysis.LC
outcome.analyses["UPLC"].details = (
    r"Column: Acquity UPLC BEH C18 1.7um 2.1x50mm (Part # 186002350),"
    r" pH 3.5 Stock Solution: 12.6g ammonium formate + 7.9ml formic acid"
    r" to 1L water, Mobile Phase A: 40ml pH 3.5 stock solution + 3960ml Water,"
    r" Mobile Phase B: 40ml pH 3.5 stock solution + 360ml Water + 3600ml ACN,"
    r" Strong Wash: 300ml IPA + 693ml ACN + 7ml pH 3.5 stock solution,"
    r" Weak Wash: 99ml ACN + 891ml Water + 10ml pH 3.5 stock solution."
    r" The instrument was equipped with an SQD detector with electrospray"
    r" ionization (ESI) source in the positive mode. High throughput data"
    r" analysis to produce Excel spreadsheets was done with"
    r" Virscidian Analytical StudioTM software."
)
outcome.analyses["UPLC"].instrument_manufacturer = "Waters"
# Authentic standards were made for product identification
# (i.e., chromatogram comparison), not assay calibration/quantification
# Also, still ambiguous about which species uses_authentic_standard applies to
# (three are analyzed here), assuming all are known/identified properly
# Add data from LC traces
outcome.analyses["UPLC"].data["product LC area count"].float_value = 0  # placeholder
outcome.analyses["UPLC"].data[
    "electrophile LC area count"
].float_value = 0  # placeholder
outcome.analyses["UPLC"].data[
    "nucleophile LC area count"
].float_value = 0  # placeholder
outcome.analyses["UPLC"].data[
    "internal_standard LC area count"
].float_value = 0  # placeholder

# Create reaction products
# Desired product
product = outcome.products.add()
product.identifiers.add(value=r"placeholder", type="SMILES")
product.is_desired_product = True
product.reaction_role = reaction_pb2.ReactionRole.PRODUCT

product.measurements.add(
    type="IDENTITY", analysis_key="UPLC", uses_authentic_standard=True
)
product.measurements.add(type="AREA", analysis_key="UPLC", uses_authentic_standard=True)
product.measurements.add(
    type="AREA",
    analysis_key="UPLC",
    uses_authentic_standard=True,
    uses_internal_standard=True,
    is_normalized=True,
)

# Remaining starting material (electrophile or ArBr)
electrophile = outcome.products.add(is_desired_product=False)
electrophile.identifiers.add(value=r"placeholder", type="SMILES")
electrophile.measurements.add(
    type="IDENTITY", analysis_key="UPLC", uses_authentic_standard=True
)
electrophile.measurements.add(
    type="AREA", analysis_key="UPLC", uses_authentic_standard=True
)
electrophile.measurements.add(
    type="AREA",
    analysis_key="UPLC",
    uses_authentic_standard=True,
    uses_internal_standard=True,
    is_normalized=True,
)
electrophile.reaction_role = reaction_pb2.ReactionRole.REACTANT

# Remaining coupling partner (nucleophile)
nucleophile = outcome.products.add(is_desired_product=False)
nucleophile.identifiers.add(value=r"placeholder", type="SMILES")
nucleophile.measurements.add(
    type="IDENTITY", analysis_key="UPLC", uses_authentic_standard=True
)
nucleophile.measurements.add(
    type="AREA", analysis_key="UPLC", uses_authentic_standard=True
)
nucleophile.measurements.add(
    type="AREA",
    analysis_key="UPLC",
    uses_authentic_standard=True,
    uses_internal_standard=True,
    is_normalized=True,
)
nucleophile.reaction_role = reaction_pb2.ReactionRole.REACTANT

istd = outcome.products.add(is_desired_product=False)
istd.identifiers.add(type="NAME", value="biphenyl")
istd.identifiers.add(type="SMILES", value="c1ccc(-c2ccccc2)cc1")
istd.measurements.add(type="AREA", analysis_key="UPLC", uses_authentic_standard=True)
istd.reaction_role = reaction_pb2.ReactionRole.INTERNAL_STANDARD

# %% [markdown]
# #### 10. Add provenance

# %%
# Reaction provenance
reaction.provenance.city = r"Rahway, NJ"
reaction.provenance.doi = r"10.1126/science.1259203"
reaction.provenance.publication_url = (
    r"https://science.sciencemag.org/content/347/6217/49"
)
reaction.provenance.record_created.time.value = (
    datetime.now().astimezone().strftime("%m/%d/%Y, %H:%M:%S")
)
reaction.provenance.record_created.person.CopyFrom(
    reaction_pb2.Person(
        name="Michael R. Maser",
        organization="Caltech",
        orcid="0000-0001-7895-7804",
        email="mmaser@caltech.edu",
    )
)

# %% [markdown]
# Validate and examine this final prototypical reaction entry

# %%
# Validation fails with 'placeholder' SMILES
# validations.validate_message(reaction)

# Just print
print(reaction)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Full HTE Data Set

# %%
# Check current dataset
data
# Out:
#      Plate Position Electrophile Electrophile charge Nucleophile  \
# 0                A1   bromide 22    250 nL (50 nmol)    amine S1
# 1                A2   bromide 22    250 nL (50 nmol)    amine S1
# 2                A3   bromide 22    250 nL (50 nmol)    amine S1
# 3                A4   bromide 22    250 nL (50 nmol)    amine S1
# 4                A5   bromide 22    250 nL (50 nmol)    amine S1
# ...             ...          ...                 ...         ...
# 1531           AF44   bromide 22    250 nL (50 nmol)  alkyne S16
# 1532           AF45   bromide 22    250 nL (50 nmol)  alkyne S16
# 1533           AF46   bromide 22    250 nL (50 nmol)  alkyne S16
# 1534           AF47   bromide 22    250 nL (50 nmol)  alkyne S16
# 1535           AF48   bromide 22    250 nL (50 nmol)  alkyne S16
#
#      Nucleophile charge              Catalyst   Catalyst charge     Base  \
# 0     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)   DBU 24
# 1     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  MTBD 25
# 2     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTMG 26
# 3     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BEMP 27
# 4     250 nL (100 nmol)        BINAP Pd G3 30  250 nL (10 nmol)  BTTP 28
# ...                 ...                   ...               ...      ...
# 1531  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  MTBD 25
# 1532  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTMG 26
# 1533  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BEMP 27
# 1534  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  BTTP 28
# 1535  250 nL (100 nmol)  AdBrettPhos Pd G3 45  250 nL (10 nmol)  P2Et 29
#
#               Base charge            IS  ...     Product  \
# 0     250 nL (200 nmol)    240134.33032  ...   Product_0
# 1     250 nL (200 nmol)    238726.34177  ...   Product_0
# 2     250 nL (200 nmol)    235018.13944  ...   Product_0
# 3     250 nL (200 nmol)    238060.17048  ...   Product_0
# 4     250 nL (200 nmol)    232566.53610  ...   Product_0
# ...                   ...           ...  ...         ...
# 1531  250 nL (200 nmol)    178233.56101  ...  Product_15
# 1532  250 nL (200 nmol)    229583.53543  ...  Product_15
# 1533  250 nL (200 nmol)    202191.15883  ...  Product_15
# 1534  250 nL (200 nmol)    201367.67531  ...  Product_15
# 1535  250 nL (200 nmol)    197245.14055  ...  Product_15
#
#                    Reaction_type  Electrophile_SMILES  Nucleophile_SMILES  \
# 0     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 1     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 2     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 3     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# 4     Buchwald-Hartwig amination           Brc1cccnc1     CC(N)CCc1ccccc1
# ...                          ...                  ...                 ...
# 1531        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1532        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1533        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1534        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
# 1535        Sonogashira coupling           Brc1cccnc1   C#Cc1ccc(CCCC)cc1
#
#                                         Catalyst_SMILES  \
# 0     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 1     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 2     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 3     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# 4     CS(=O)(=O)O[Pd]1(<-P(C2=CC=CC=C2)(C2=CC=CC=C2)...
# ...                                                 ...
# 1531  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1532  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1533  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1534  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
# 1535  COC1=CC=C(OC)C(P(C23C[C@H]4C[C@@H](C2)C[C@@H](...
#
#                                     Base_SMILES             Product_SMILES  \
# 0                              C1CCC2=NCCCN2CC1    CC(CCc1ccccc1)Nc1cccnc1
# 1                              CN1CCCN2CCCN=C12    CC(CCc1ccccc1)Nc1cccnc1
# 2                       CN(C)C(=NC(C)(C)C)N(C)C    CC(CCc1ccccc1)Nc1cccnc1
# 3               CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C    CC(CCc1ccccc1)Nc1cccnc1
# 4          CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1    CC(CCc1ccccc1)Nc1cccnc1
# ...                                         ...                        ...
# 1531                           CN1CCCN2CCCN=C12  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1532                    CN(C)C(=NC(C)(C)C)N(C)C  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1533            CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1534       CC(C)(C)N=P(N1CCCC1)(N1CCCC1)N1CCCC1  CCCCc1ccc(C#Cc2cccnc2)cc1
# 1535  CCN=P(N=P(N(C)C)(N(C)C)N(C)C)(N(C)C)N(C)C  CCCCc1ccc(C#Cc2cccnc2)cc1
#
#      Product_yield ArBr_yield Nu_yield
# 0             0.00      15.07    32.97
# 1             0.00      14.20    31.09
# 2             0.00      14.04    30.47
# 3             0.41      14.00    31.65
# 4             0.00      14.40    33.24
# ...            ...        ...      ...
# 1531         51.28       0.00     0.00
# 1532         36.45       3.32     0.00
# 1533          6.73      12.10     0.00
# 1534         16.52       9.28     0.00
# 1535          7.12       7.84     0.00
#
# [1536 rows x 24 columns]

# %%
reactions = []
for _, row in tqdm(data.iterrows()):
    new_reaction = reaction_pb2.Reaction()
    new_reaction.CopyFrom(reaction)

    # Update name
    new_reaction.identifiers[0].value = row["Reaction_type"]

    # Update electrophile name & SMILES
    new_reaction.inputs["electrophile"].components[0].identifiers[0].value = row[
        "Electrophile_SMILES"
    ]
    new_reaction.inputs["electrophile"].components[0].identifiers[1].value = row[
        "Electrophile"
    ]

    # Update nucleophile name & SMILES
    new_reaction.inputs["nucleophile"].components[0].identifiers[0].value = row[
        "Nucleophile_SMILES"
    ]
    new_reaction.inputs["nucleophile"].components[0].identifiers[1].value = row[
        "Nucleophile"
    ]

    # Add water as reactant if using boronate S14 nucleophile
    if row["Nucleophile"] == "boronate S14/water":
        water = new_reaction.inputs["nucleophile"].components.add()
        water.CopyFrom(
            message_helpers.build_compound(
                name="water",
                smiles="O",
                role="reactant",
                amount="400 nmol",
                prep=None,
                is_limiting=False,
                prep_details=None,
            )
        )

    # Update base
    new_reaction.inputs["base"].components[0].identifiers[0].value = row["Base_SMILES"]
    new_reaction.inputs["base"].components[0].identifiers[1].value = row["Base"]

    # Update catalyst
    new_reaction.inputs["catalyst"].components[0].identifiers[0].value = row[
        "Catalyst_SMILES"
    ]
    new_reaction.inputs["catalyst"].components[0].identifiers[1].value = row["Catalyst"]

    # Update product_0 and record product yield and LC area count
    new_reaction.outcomes[0].products[0].identifiers[0].value = row["Product_SMILES"]
    new_reaction.outcomes[0].products[0].measurements[1].float_value.value = row["Prod"]
    if row["IS"]:
        new_reaction.outcomes[0].products[0].measurements[2].float_value.value = (
            row["Prod"] / row["IS"]
        )
    else:
        del new_reaction.outcomes[0].products[0].measurements[2]
    new_reaction.outcomes[0].analyses["UPLC"].data[
        "product LC area count"
    ].float_value = row["Prod"]

    # Update product_1 and record remaining electrophile yield and LC area count
    new_reaction.outcomes[0].products[1].identifiers[0].value = row[
        "Electrophile_SMILES"
    ]
    new_reaction.outcomes[0].products[1].measurements[1].float_value.value = row["ArBr"]
    if row["IS"]:
        new_reaction.outcomes[0].products[1].measurements[2].float_value.value = (
            row["ArBr"] / row["IS"]
        )
    else:
        del new_reaction.outcomes[0].products[1].measurements[2]
    new_reaction.outcomes[0].analyses["UPLC"].data[
        "electrophile LC area count"
    ].float_value = row["ArBr"]

    # Update product_2 and record remaining electrophile yield and LC area count
    new_reaction.outcomes[0].products[2].identifiers[0].value = row[
        "Nucleophile_SMILES"
    ]
    new_reaction.outcomes[0].products[2].measurements[1].float_value.value = row["Nu"]
    if row["IS"]:
        new_reaction.outcomes[0].products[2].measurements[2].float_value.value = (
            row["Nu"] / row["IS"]
        )
    else:
        del new_reaction.outcomes[0].products[2].measurements[2]
    new_reaction.outcomes[0].analyses["UPLC"].data[
        "nucleophile LC area count"
    ].float_value = row["Nu"]

    # Record internal standard LC area count
    new_reaction.outcomes[0].products[3].measurements[0].float_value.value = row["IS"]
    new_reaction.outcomes[0].analyses["UPLC"].data[
        "internal_standard LC area count"
    ].float_value = row["IS"]

    # Validate
    errors = validations.validate_message(new_reaction)
    for error in errors.errors:
        print(error)

    # Append
    reactions.append(new_reaction)
# Out:
# 1536it [00:13, 115.41it/s]

# %%
# Verify full dataset was written
print(f"Generated {len(reactions)} reactions")
# Out:
# Generated 1536 reactions

# %%
# Inspect random reaction from this set
random_index = np.random.default_rng().integers(len(reactions))
print(f"Reaction entry {random_index}:")
reactions[random_index]
# Out:
# Reaction entry 123:
# identifiers {
#   type: NAME
#   value: "Buchwald-Hartwig amination"
# }
# inputs {
#   key: "base"
#   value {
#     components {
#       identifiers {
#         type: SMILES
#         value: "CCN(CC)P1(=NC(C)(C)C)N(C)CCCN1C"
#       }
#       identifiers {
#         type: NAME
#         value: "BEMP 27"
#       }
#       amount {
#         moles {
#           value: 200.0
#           units: NANOMOLE
#         }
#       }
#       reaction_role: REAGENT
#       is_limiting: false
#     }
#     components {
#       identifiers {
#         type: SMILES
#         value: "CS(C)=O"
#       }
#       identifiers {
#         type: NAME
#         value: "DMSO"
#       }
#       amount {
#         volume {
#           value: 250.0
#           units: NANOLITER
#         }
#         volume_includes_solutes: true
#       }
#       reaction_role: SOLVENT
#       is_limiting: false
#     }
#     addition_order: 1
#   }
# }
# inputs {
#   key: "catalyst"
#   value {
#     components {
#       identifiers {
#         type: SMILES
#         value: "CC12CC3(C)OC(C)(CC(C)(O1)P3(C1=CC=CC=C1)->[Pd]1(OS(C)(=O)=O)<-NC3=C(C=CC=C3)C3=CC=CC=C31)O2"
#       }
#       identifiers {
#         type: NAME
#         value: "PPA Pd G3 34"
#       }
#       amount {
#         moles {
#           value: 10.0
#           units: NANOMOLE
#         }
#       }
#       reaction_role: REAGENT
#       is_limiting: false
#     }
#     components {
#       identifiers {
#         type: SMILES
#         value: "CS(C)=O"
#       }
#       identifiers {
#         type: NAME
#         value: "DMSO"
#       }
#       amount {
#         volume {
#           value: 250.0
#           units: NANOLITER
#         }
#         volume_includes_solutes: true
#       }
#       reaction_role: SOLVENT
#       is_limiting: false
#     }
#     addition_order: 1
#   }
# }
# inputs {
#   key: "electrophile"
#   value {
#     components {
#       identifiers {
#         type: SMILES
#         value: "Brc1cccnc1"
#       }
#       identifiers {
#         type: NAME
#         value: "bromide 22"
#       }
#       amount {
#         moles {
#           value: 100.0
#           units: NANOMOLE
#         }
#       }
#       reaction_role: REACTANT
#       is_limiting: true
#     }
#     components {
#       identifiers {
#         type: SMILES
#         value: "CS(C)=O"
#       }
#       identifiers {
#         type: NAME
#         value: "DMSO"
#       }
#       amount {
#         volume {
#           value: 250.0
#           units: NANOLITER
#         }
#         volume_includes_solutes: true
#       }
#       reaction_role: SOLVENT
#       is_limiting: false
#     }
#     addition_order: 1
#   }
# }
# inputs {
#   key: "nucleophile"
#   value {
#     components {
#       identifiers {
#         type: SMILES
#         value: "Nc1ccccc1"
#       }
#       identifiers {
#         type: NAME
#         value: "aniline S2"
#       }
#       amount {
#         moles {
#           value: 150.0
#           units: NANOMOLE
#         }
#       }
#       reaction_role: REACTANT
#       is_limiting: false
#     }
#     components {
#       identifiers {
#         type: SMILES
#         value: "CS(C)=O"
#       }
#       identifiers {
#         type: NAME
#         value: "DMSO"
#       }
#       amount {
#         volume {
#           value: 250.0
#           units: NANOLITER
#         }
#         volume_includes_solutes: true
#       }
#       reaction_role: SOLVENT
#       is_limiting: false
#     }
#     addition_order: 1
#   }
# }
# setup {
#   vessel {
#     type: WELL_PLATE
#     details: "Corning Echo qualified, Cat. No. 3730"
#     material {
#       type: PLASTIC
#       details: "Cyclic Olefin-Copolymer"
#     }
#     attachments {
#       type: MAT
#       details: "perfluoroalkoxy alkane (PFA) mat (Analytical-Sales, Cat. No. 96981)"
#     }
#     attachments {
#       type: MAT
#       details: "silicon rubber mat (Analytical-Sales, Cat. No. 96982)"
#     }
#     attachments {
#       type: CUSTOM
#       details: "clamp (Arctic White, Cat. No. AWSC-051001)"
#     }
#     volume {
#       value: 12.5
#       units: MICROLITER
#     }
#   }
#   is_automated: true
#   automation_platform: "Mosquito(R) HTS liquid handling robot; TTP Labtech native software; Free-Slate Library Studio"
#   environment {
#     type: GLOVE_BOX
#     details: "MBraun glovebox operating with a constant N2-purge (oxygen typically <5 ppm)"
#   }
# }
# conditions {
#   temperature {
#     control {
#       type: AMBIENT
#       details: "The plate was then allowed to sit at room temperature for 22 hours"
#     }
#   }
#   pressure {
#     control {
#       type: SEALED
#       details: "The 1536-well plates were covered by a perfluoroalkoxy alkane (PFA) mat (Analytical-Sales, Cat. No. 96981), followed by a silicon rubber mat (Analytical- Sales, Cat. No. 96982) and then secured with a clamp (Arctic White, Cat. No. AWSC-051001)"
#     }
#     atmosphere {
#       type: NITROGEN
#     }
#   }
#   stirring {
#     type: NONE
#   }
# }
# notes {
#   is_heterogeneous: false
#   is_sensitive_to_moisture: true
#   is_sensitive_to_oxygen: true
#   procedure_details: "The Mosquito was used to combine the source plate solutions by multi-aspiration of 250 nL of each of the four reaction components and then to dose the resulting reaction mixture (1 uL) into a 1536-well plate"
# }
# observations {
#   time {
#     value: 0.0
#     units: HOUR
#   }
#   comment: "fully dosed 1536 reaction well plate"
#   image {
#     bytes_value: "\211PNG\r\n\032\n\000\000\000\rIHDR\000\000\002\306\000\000\002\201\010\006\000\000\000T5ma\000\000\000\001sRGB\000\256\316\034\351\000\000\000\tpHYs\000\000\027\022\000\000\027\022\001g\237\322R\000\000@\000IDATx\001\354\275Y\226$9\232\245gnf>DDfFTVV\261\273\317i>4{\r\275\007\036.\205{\252\005\325[-\202\375\330d\363\0243\303\0073\343\375\356\305\025\201\210\212\252\r\3561\246\303L\004\300?\343\007\004\370\005**zu\3655}\365\300W\017|\365\300W\017|\365\300W\017|\365\300W\017|\365\300W\017\\\275\302\007\017\017\237\376we\377G\375q\177\177\177\365\376\375\307\253\353\353WWo\337\276\271R\365\352\356\356\223\321\327\327\327%s~s\223\372\335\235\210\224ZwE\'xIe\243\376\3600\200\301\210\307\205GO3W\210\267\214\017wwW\237\244\340V\312^MB\037D|/\334\326\362\255\272\233A\177\':R\353[*\332\263Z\261\367Eq{\3709\031\217\321\355\371~\251z\333\365\360\200\'\257\256^\275\362\260Q\237^\362\350\323\254E6r\253\243\022_UvT-\302\256\257\267}^D\371[o^\331\330\272\330\235f\250!\321v\377\360\261\344\316\257\007\374\312t\3647t\257\256\322\363\000_e,\331\266a\3612\246\027\341\226\265\234*s\000\356\207\264\342\217|\271\216\264P\3257\345yn^\037\035\351z\256\254\257\364\347=P?\237\247\010\346k?<\346\241\237\027\277\357\267K\375S\332K4/\265\376\251\262\237J\367R;\276(\237\346\371\273;\315\263\232\207o:\027vB\363D\247\031\2611\306\315mT\027\377dC\216\030\236\267^\234\252zp\274\362\2526O\004]\242&\320\027,\036\333\375\230\202eLt\031Z\030\344\033\326+\257SY\303\026\324\276mc-\273\037ko\307\370\335\307\217\216\347nno\256\2265r\021\262\223}(S\353\274\327\275\353\253.\343\367#n|\030q\325\315\353\321\367\225{7\214\330\313\033\370{\331\372pO{\272Zj|)nu*O\327\346\245>\230\311\312Fy\032>\303\212W\377M\340\377\023\034\211\000\202\2408\203\201\374a\t*\032\\\204\322\324\243h\257O\345\024\341\035%g\251\017\303\007&=\266T\316\026\366\\{\302\007\0218f#\337!G,\'\370\036\263#|\244z\332\376\225\341\022n\245\212\177\347\372\257\275\274o\327\276\3769\366WV\363\004\243\364\337\350\247e\374\\\326\262\360\037\220\025\327|!\251\212\352*\302p\235|#\240|\324WS\006\314\360\r\223xF\275\003n\207^\253\033\346\2027\371\343\024\033\362G+\'\355\177\224\343+\301K<\360\325\317/\361\332/\317\363\234~{\016\355s[\366T\331O\245{\256\376\237\204\236\371\260s\3422\261\215\202\'Vf\374\021\231\030\314\251\223i-Z\030\0138\310\237B\363\3345\230\030\350@\325~\3358\"\371\231a\027\307\204\333\240\223\335\252\274mj\276\330\032\300i\233\361\303\210\005Ox`\026\020\331\356\353E\330(\014\231;\245\265\367aQ\266\023\\\370\016\\\351\257\034\364Y\351\262\\/\235\265\360\214\302R\037\334a\253\250\344\203\306\201\361\247O\237$\213F\023\02038_y\307\024\233\226;\220q{\324\206T\332G\335E\220\330\311\333\343J3\347O\241\351\316\344\314\347r\235t\202\010\000\3317\262s\257\203\266^\017^.\2779UW\333\271\347\235i\237[\256\354\275\314\302\367\362\n\207~\317\263\247=W\257\214\342\317\311\031\233\277%\333\344\347\334\274\227\265\327\265\021\242J\351\217\350\212\203\207r\357J\227\271p1\302W\361^\364\223\353\033\331pI\\\373z\321\271\350\212\330\373;\021\351.\223\233C\031\' \271`\024\227\013\021Z\000#-Q\363\200\355\353k\303\006C\333U\031\251\267_\264O18\212\327\247\030;;\253\372\267\226w<\314c\340\267\326\206\257\366~\365\300W\017<\315\003\271\336\025P\215\330b\317\325\371 s-\330u\316\333\323>\277~<\317\256r\036\307?>O\r\031\315\306\334\357\240\rE/\232\267\267v\365S\366\365\346a\213OD\272\266\312\353\325R\305\237\245\257=S}\354\232\262\237KZ\333\273\355\207Wl\226j\375[b\250I\204\031]\237xf|\027\266\356\346\232\301\312\\\352\'\304\035\013\213\rC\\w\224\343\312\000#\222qE]\307\254\257\362\311\027\031!XdO\270\205|\310\330\004\306<>@\260\000#e\214$\210h\035\346\331p\312\004\306\344\357\336\275\025\035\333\377\303\212E\323i\241\206U\326\236\242\360\346\245\237\235\262\347\241\316\016\367\2711\330\217B\366\326UG\037\241\270\275\275u{\367\362K\267\207_\252\227\247\366\357i\213/\034_\003\303\367{\236=\3559|\203\276\312l\360\267\247\007/UN\225]\232\275\017\013\017\365z\336\353Z1k\251\274\325QL\341\373\374dp\357\215\251\200 ...
#     description: "fully dosed plate"
#     format: "png"
#   }
# }
# observations {
#   time {
#     value: 0.0
#     units: HOUR
#   }
#   comment: "clamped 1536-wp - perspective view"
#   image {
#     bytes_value: "\211PNG\r\n\032\n\000\000\000\rIHDR\000\000\002\274\000\000\001\263\010\006\000\000\000\315\004\304\013\000\000\000\001sRGB\000\256\316\034\351\000\000\000\tpHYs\000\000\027\022\000\000\027\022\001g\237\322R\000\000@\000IDATx\001\304\275I\223$Iz\246g\341\036\036KfVUV\025\320X\010\200C\n@\202\030R\204\007^)\344\205\007\376m^Fx\345\010\311\021\0222\300\000\203\356Fw\327\226K\354\036\301\347y_Us\217\254\314\256\306\010f\250\021f\272}\372m\372\351jj\346\'\013\356\325\237\376\317\377\333\371\371\313\257\376\362\277\377\037\227\327\177\360\237/\177\364/\377\247\345v9_\376\341\315\351\362\356\356ly\317\265\177X\226\373\307\223\345\345\366d\331l\226e\373p\273,O\373\345bC\306\tA\322\366\'\'\313\r\221\247\247ey\330\237.\217\304\367\340?\335\234,\247\370\027\'O\346\022\336[d\271[\356\271\223\006\374\311#\351\017\017\344=.\227\'\267\313\317>\337,_\277\336-\177\366G\257r\375\027\177\002\237/\227\345\362L|\313\262y\202>n\033L`y\222\202\216L\235\004\206{x|X\236\036\036\227\373\'|\350\334\336\301\327#<>n\244\276<>m\227;X\371\376\375\351\362\303\233\307\345\377\3707\327\313\337\377\352f\371\371?\276_\336?\"?\327\303\3119\234\235.\017\240\177\n\356Ag\277\013\025\361?!\327=\232\333?=\202s\217\374O\224SB\234e\266\367\224}\\n6\267\313\343\026\275\275\272[6\027w\313\305\357]/\'g\357\226\355\213\277\205\247_\242g\256\207o\227\307\307o\320\313\r\005\301\240|\020>\331\354\202\352iS\035\212:\371\320\222\316\0230\362\367\200\356\321T\3626\017\327f,\333\223-q\322\251G\335\323\335\203\322S\323\217\313\213G\374\207\247\345K\350|\201>\376\362\342g\313\227\'\027\313\037\334^.\027w\233e\367\355\375\262#\375\367^~\265\234\237\277X._}\276\354..\226\313?\370\375\345\364\263W\313\346\345+\370\277XN._,\017\247\350\004\372\233\335\031\374Rv{Z\361Ov\324\333~9\303\2306\324\305\331\323;\352\376j\331\356o\226\357\276\371%\327/\226\177\365\277\377\253\345\327\277\372\325\362\327\377\366\037\226\037\336\275_\336\276\275C\'\310s\263A\247\260\016\237\";\331Q\363\233\355\262AD\252s\271\217\021\235@{Y~\363\247/\227\373\317\317\226?\372\257\377\005<\236/\367?{\211\276O\226\357\367\327\261\201klw\017\375\307{pUk\370\206u\352\014[n\255qO\355%-\372E.\265\267!\242\014\013:;\321\340\371\177\200\206\215\343Q\206\217\334\t\366\237?M\006!\264\301G\205\331s\341\304\365\210\355\213#(\260a\264\227\370&\306f\031Z\022e0\237\325\311\207\366\377\345\325\351rN\003\374\223/\377p\371\331\353\257\227\377\365\177\370_\226\257?\377j\371o\377\370/\226W\273\027\313\313\345Ex>\005\247\024\225I\322\372\033\020\312\326\tu[\'V\343\215\375\370^\014\321\327Iu\265\354\261k\352\345\356\016\375\336\335-\277\372\326\272\374\315\362o\376\357\377ky\367\356\355\362\253_\376|y\361\362\305\362\331\253\027\313\237\377\305_,\177\376\347\177\276|\365\345\227\313\331nG\273{\340\272_\376\365\277\376?\251\353w\313\337\376\355\277[\256oo\223\276E\327\2733\332\236\372\302f.^\274X^`s_\177\375\365r\206\177~~\016\377\3667\007f\325\363\351\331\216>b\263\234\237\235/\347/.\3513.\227\355\356\024;\244\355\330y\234`\223\304Oh\017[\343\224y\23484(\2345\240\243V\202\377i\277\'M\330\203\263^?\346\254\337\203\203#\212\331\317\034\247\036\362\033\372\260\214\300\210\206k\371\330\217\364I\263\316t\223\347)?\335N\234\364fYu\250-=\315L|i\355\265\'\2346!\322\315)p\203^U\241u$ky\3006\245Q\376O\226\263St$,\365o{\274\271\271\003\337#\365v\203)<\000_Xm\314\372\321\rS_\353\212\0362\351\353\r6\252\266\366S\'\224{qyA\037r\212\235\234\321.\030[\356\3507\351\270\337\275\273\202\036t\356\221\001y\254\231\351\034kN\220e\272\231\263\205WY\331\355\250Y\002\033\354\3036\365(\236\007\375=MY\256\250)\024\030\333\020W\324S|\263MlH\354%\236\223e\213\315\264v\037\261U0`+\302Z\364\201\260N[Q+v\031\216\233\246\337\242\267o\277\375v\371\346\333_-\277\372\346\327\313\355\325\365r\205\016\037-\203\276O\320s(;X\341\266[\332(x\255\273\340Ba\332\251\362\244O\201\373{\372t\353z\037\034\224\221\td=\323\256a\312<\365\274\247=Q2Lj\037!\244\274$IF\337\242\366GT\001x\250\017\333\025\355\3453\332\325\331\351\226\366DI\332\220\\n(\244\316^\274z\265\234\2 ...
#     description: "sealed plate"
#     format: "png"
#   }
# }
# workups {
#   type: ADDITION
#   input {
#     components {
#       identifiers {
#         type: SMILES
#         value: "CC(=O)O"
#       }
#       identifiers {
#         type: NAME
#         value: "acetic acid"
#       }
#       amount {
#         volume {
#           value: 150.0
#           units: NANOLITER
#         }
#       }
#       reaction_role: WORKUP
#       is_limiting: false
#     }
#     components {
#       identifiers {
#         type: SMILES
#         value: "c1ccc(-c2ccccc2)cc1"
#       }
#       identifiers {
#         type: NAME
#         value: "biphenyl"
#       }
#       amount {
#         moles {
#           value: 3.0
#           units: NANOMOLE
#         }
#       }
#       reaction_role: INTERNAL_STANDARD
#       is_limiting: false
#     }
#     components {
#       identifiers {
#         type: SMILES
#         value: "CS(C)=O"
#       }
#       identifiers {
#         type: NAME
#         value: "DMSO"
#       }
#       amount {
#         volume {
#           value: 2.8499999046325684
#           units: MICROLITER
#         }
#         volume_includes_solutes: true
#       }
#       reaction_role: WORKUP
#       is_limiting: false
#     }
#   }
#   stirring {
#     type: AGITATION
#     details: "The Mosquito mixing feature was used three times"
#   }
#   is_automated: true
# }
# workups {
#   type: ALIQUOT
#   amount {
#     volume {
#       value: 1.0
#       units: MICROLITER
#     }
#   }
#   stirring {
#     type: AGITATION
#     details: "The Mosquito mixing feature was used three times"
#   }
#   is_automated: true
# }
# workups {
#   type: ADDITION
#   input {
#     components {
#       identifiers {
#         type: SMILES
#         value: "CS(C)=O"
#       }
#       identifiers {
#         type: NAME
#         value: "DMSO"
#       }
#       amount {
#         volume {
#           value: 75.0
#           units: MICROLITER
#         }
#       }
#       reaction_role: WORKUP
#       is_limiting: false
#     }
#   }
#   stirring {
#     type: AGITATION
#     details: "The Mosquito mixing feature was used three times"
#   }
#   is_automated: true
# }
# outcomes {
#   reaction_time {
#     value: 22.0
#     units: HOUR
#   }
#   products {
#     identifiers {
#       type: SMILES
#       value: "c1ccc(Nc2cccnc2)cc1"
#     }
#     is_desired_product: true
#     measurements {
#       analysis_key: "UPLC"
#       type: IDENTITY
#       uses_authentic_standard: true
#     }
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_authentic_standard: true
#       float_value {
#         value: 0.0
#       }
#     }
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_internal_standard: true
#       is_normalized: true
#       uses_authentic_standard: true
#       float_value {
#         value: 0.0
#       }
#     }
#     reaction_role: PRODUCT
#   }
#   products {
#     identifiers {
#       type: SMILES
#       value: "Brc1cccnc1"
#     }
#     is_desired_product: false
#     measurements {
#       analysis_key: "UPLC"
#       type: IDENTITY
#       uses_authentic_standard: true
#     }
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_authentic_standard: true
#       float_value {
#         value: 1102078.0
#       }
#     }
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_internal_standard: true
#       is_normalized: true
#       uses_authentic_standard: true
#       float_value {
#         value: 3.8089377880096436
#       }
#     }
#     reaction_role: REACTANT
#   }
#   products {
#     identifiers {
#       type: SMILES
#       value: "Nc1ccccc1"
#     }
#     is_desired_product: false
#     measurements {
#       analysis_key: "UPLC"
#       type: IDENTITY
#       uses_authentic_standard: true
#     }
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_authentic_standard: true
#       float_value {
#         value: 1372323.125
#       }
#     }
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_internal_standard: true
#       is_normalized: true
#       uses_authentic_standard: true
#       float_value {
#         value: 4.742943286895752
#       }
#     }
#     reaction_role: REACTANT
#   }
#   products {
#     identifiers {
#       type: NAME
#       value: "biphenyl"
#     }
#     identifiers {
#       type: SMILES
#       value: "c1ccc(-c2ccccc2)cc1"
#     }
#     is_desired_product: false
#     measurements {
#       analysis_key: "UPLC"
#       type: AREA
#       uses_authentic_standard: true
#       float_value {
#         value: 289339.96875
#       }
#     }
#     reaction_role: INTERNAL_STANDARD
#   }
#   analyses {
#     key: "UPLC"
#     value {
#       type: LC
#       details: "Column: Acquity UPLC BEH C18 1.7um 2.1x50mm (Part # 186002350), pH 3.5 Stock Solution: 12.6g ammonium formate + 7.9ml formic acid to 1L water, Mobile Phase A: 40ml pH 3.5 stock solution + 3960ml Water, Mobile Phase B: 40ml pH 3.5 stock solution + 360ml Water + 3600ml ACN, Strong Wash: 300ml IPA + 693ml ACN + 7ml pH 3.5 stock solution, Weak Wash: 99ml ACN + 891ml Water + 10ml pH 3.5 stock solution. The instrument was equipped with an SQD detector with electrospray ionization (ESI) source in the positive mode. High throughput data analysis to produce Excel spreadsheets was done with Virscidian Analytical StudioTM software."
#       data {
#         key: "electrophile LC area count"
#         value {
#           float_value: 1102078.0
#         }
#       }
#       data {
#         key: "internal_standard LC area count"
#         value {
#           float_value: 289339.96875
#         }
#       }
#       data {
#         key: "nucleophile LC area count"
#         value {
#           float_value: 1372323.125
#         }
#       }
#       data {
#         key: "product LC area count"
#         value {
#           float_value: 0.0
#         }
#       }
#       instrument_manufacturer: "Waters"
#     }
#   }
# }
# provenance {
#   city: "Rahway, NJ"
#   doi: "10.1126/science.1259203"
#   publication_url: "https://science.sciencemag.org/content/347/6217/49"
#   record_created {
#     time {
#       value: "02/23/2021, 17:39:55"
#     }
#     person {
#       name: "Michael R. Maser"
#       orcid: "0000-0001-7895-7804"
#       organization: "Caltech"
#       email: "mmaser@caltech.edu"
#     }
#   }
# }

# %% [markdown]
# ### Package reactions into a dataset

# %%
# Create dataset message containing reaction list
dataset = dataset_pb2.Dataset(
    name="HTE Pd-catalyzed cross-coupling screen",
    description="Reactions from Experiment 2 of DOI: 10.1126/science.1259203",
    reactions=reactions,
)

# Write reaction and dataset to file
# message_helpers.save_message(reaction, 'Santanilla_experiment2_reaction.pbtxt')
# message_helpers.save_message(dataset, 'Santanilla_experiment2_dataset.pbtxt')
# message_helpers.save_message(dataset, 'Santanilla_experiment2_dataset.pb')

# %%
# Validate dataset
validations.validate_message(dataset)
